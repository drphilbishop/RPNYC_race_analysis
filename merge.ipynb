# %%
import pandas as pd
import numpy as np
import datetime as dt
#import matplotlib
import os
import re
#import EAtools as ea

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)
#pd.set_option('display.max_columns',10000)
#pd.set_option('display.max_rows',10000)
#pd.set_option('display.max_colwidth',10000)
#pd.set_option('display.max_info_columns',10000)
#pd.set_option('display.notebook_repr_html',True)
#pd.set_option('display.expand_frame_repr', True)

datapath = 'C:\\Phil\\My Dropbox\\Sailing cmte\\Handicapping\\2012-13 season\\'
#datapath = '/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/2012-13 season/'

# Collect all file names into a variable called filenames 
filenames = os.listdir(datapath + "Proc'd CSVs")
#filenames
#['id13 Div1.csv',
# 'id13 Div2.csv',
# 'id13 Div3.csv',
# 'id20 Div1.csv',
# 'id20 Div2.csv'
#....]

# %%
racedatadict={}
for f in filenames:
    g = f.split(' ')[1].split('.')[0]
    if g == 'Div1':
        racedatadict[f.split(' ')[0]] = input_csv(datapath, f)
        print f, '  ', g
#racedatadict

# Put the dictionary into a pandas panel
racedata = pd.Panel(racedatadict)
#racedata['id13']
racedata

# %%
racedatadict={}
for f in filenames:
    g = f.split(' ')[1].split('.')[0]
    if g == 'Div1':
        racedatadict[f.split(' ')[0]] = pd.read_csv(datapath + "Proc'd CSVs/" + f, sep=',').set_index('Boat name')
#        print f, '  ', g
#racedatadict

# %%
g = ""
for f in filenames:
    if 'Div1' in f:
        g += f
g
# Out:
# 'id13 Div1.csvid20 Div1.csvid24 Div1.csvid25 Div1.csvid5 Div1.csvid50 Div1.csvid6 Div1.csvid65 Div1.csvid68 Div1.csvid69 Div1.csvid7 Div1.csvid70 Div1.csvid71 Div1.csv'

# %%
g={}

for f in filenames:
    if 'Div1' in f:
        g[f.split('Div')[0].replace(' ','')] = pd.read_csv(datapath + "Proc'd CSVs/" + f, sep=',').set_index('Boat name')
        #print g
g['id13']
# Out:
#                 TCF_id13_d1
# Boat name
# Andiamo               0.883
# Wedgetail             0.944
# Revs                  0.896
# The Guarantee         0.851
# Rocket Science          NaN

# %%
x = pd.Panel(g)

# %%
x
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 13 (items) x 13 (major_axis) x 13 (minor_axis)
# Items axis: id13 to id71
# Major_axis axis: Andiamo to Wedgetail
# Minor_axis axis: TCF_id13_d1 to TCF_id7_d1

# %%
x.sum(axis=0)
# Out:
#                      TCF_id13_d1  TCF_id20_d1  TCF_id24_d1  TCF_id25_d1  TCF_id50_d1  TCF_id5_d1  TCF_id65_d1  TCF_id68_d1  TCF_id69_d1  TCF_id6_d1  TCF_id70_d1  TCF_id71_d1  TCF_id7_d1
# Andiamo                    0.883        0.883        0.883        0.881          NaN       0.895          NaN          NaN          NaN       0.894          NaN          NaN       0.889
# Clear Vision                 NaN          NaN        0.833        0.831          NaN       0.826          NaN          NaN          NaN       0.830          NaN          NaN         NaN
# Drinks Trolley               NaN          NaN        0.826        0.823          NaN       0.824          NaN          NaN          NaN       0.824          NaN          NaN       0.825
# Fulmar                       NaN          NaN          NaN          NaN          NaN         NaN          NaN          NaN          NaN       0.780          NaN          NaN         NaN
# ...

# %%
x = pd.DataFrame(g)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-4fc6680dc94c> in <module>()
# ----> 1 x = pd.DataFrame(g,columns = g.keys())
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     395             mgr = self._init_mgr(data, index, columns, dtype=dtype, copy=copy)
#     396         elif isinstance(data, dict):
# --> 397             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     398         elif isinstance(data, ma.MaskedArray):
#     399             mask = ma.getmaskarray(data)
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in _init_dict(self, data, index, columns, dtype)
#     494
#     495             if index is None:
# --> 496                 index = extract_index(data.values())
#     497             else:
#     498                 index = _ensure_index(index)
#
# ...

# %%
x[x.items[2]]
# Out:
#             Boat name TCF_id13_d1 TCF_id20_d1 TCF_id24_d1 TCF_id25_d1 TCF_id50_d1 TCF_id5_d1 TCF_id65_d1 TCF_id68_d1 TCF_id69_d1 TCF_id6_d1 TCF_id70_d1 TCF_id71_d1 TCF_id7_d1
# 0      Rocket Science         NaN         NaN       0.822         NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN         NaN        NaN
# 1           Wedgetail         NaN         NaN       0.944         NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN         NaN        NaN
# 2         Magic Trick         NaN         NaN       0.892         NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN         NaN        NaN
# 3             Andiamo         NaN         NaN       0.883         NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN         NaN        NaN
# ...

# %%
#div1list = ['id5 Div1.csv',  'id6 Div1.csv',  'id7 Div1.csv',  'id13 Div1.csv', 'id20 Div1.csv', 'id24 Div1.csv', 'id25 Div1.csv', \
#            'id50 Div1.csv', 'id65 Div1.csv', 'id68 Div1.csv', 'id69 Div1.csv', 'id70 Div1.csv', 'id71 Div1.csv']
#div2list = ['id5 Div2.csv2', 'id6 Div2.csv',  'id7 Div2.csv',  'id13 Div2.csv', 'id20 Div2.csv', 'id24 Div2.csv', 'id25 Div2.csv', \
#            'id43 Div2.csv', 'id48 Div2.csv', 'id49 Div2.csv', 'id50 Div2.csv', 'id51 Div2.csv', 'id65 Div2.csv', 'id68 Div2.csv', \
#            'id69 Div2.csv', 'id70 Div2.csv', 'id71 Div2.csv']
#div2list

# %%
id5 = pd.read_csv(datapath + "Proc'd CSVs/" + "id5 Div3.csv", sep=',')
id6 = pd.read_csv(datapath + "Proc'd CSVs/" + "id6 Div3.csv", sep=',')
id7 = pd.read_csv(datapath + "Proc'd CSVs/" + "id7 Div3.csv", sep=',')
id13 = pd.read_csv(datapath + "Proc'd CSVs/" + "id13 Div3.csv", sep=',')
id20 = pd.read_csv(datapath + "Proc'd CSVs/" + "id20 Div3.csv", sep=',')
id24 = pd.read_csv(datapath + "Proc'd CSVs/" + "id24 Div3.csv", sep=',')
id43 = pd.read_csv(datapath + "Proc'd CSVs/" + "id43 Div3.csv", sep=',')
id48 = pd.read_csv(datapath + "Proc'd CSVs/" + "id48 Div3.csv", sep=',')
id50 = pd.read_csv(datapath + "Proc'd CSVs/" + "id50 Div3.csv", sep=',')
id65 = pd.read_csv(datapath + "Proc'd CSVs/" + "id65 Div3.csv", sep=',')
id68 = pd.read_csv(datapath + "Proc'd CSVs/" + "id68 Div3.csv", sep=',')
id69 = pd.read_csv(datapath + "Proc'd CSVs/" + "id69 Div3.csv", sep=',')
id71 = pd.read_csv(datapath + "Proc'd CSVs/" + "id71 Div3.csv", sep=',')

div3 = id5.merge(id6,how='outer').merge(id7,how='outer').merge(id13,how='outer').merge(id20,how='outer') \
          .merge(id24,how='outer').merge(id43,how='outer').merge(id48,how='outer') \
          .merge(id50,how='outer').merge(id65,how='outer') \
          .merge(id68,how='outer').merge(id69,how='outer').merge(id71,how='outer')

div3.to_csv('/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/' + 'Div3 2012-13.csv', sep = ',')

div3
# Out:
#          Boat name  TCF_id5_d3  TCF_id6_d3  TCF_id7_d3  TCF_id13_d3  TCF_id20_d3  TCF_id24_d3  TCF_id43_d3  TCF_id48_d3  TCF_id50_d3  TCF_id65_d3  TCF_id68_d3  TCF_id69_d3  TCF_id71_d3
# 0      Titus Canby       0.690       0.694       0.698        0.697        0.695        0.688        0.683        0.683        0.687        0.690        0.687        0.684        0.682
# 1        Rosschild       0.625       0.629       0.629          NaN        0.630        0.632          NaN          NaN        0.632          NaN          NaN          NaN        0.635
# 2        Wai-Aniwa       0.662       0.664       0.668        0.672        0.678        0.680        0.678        0.682        0.681        0.681        0.684        0.679        0.679
# 3    Saucy Sausage       0.634       0.634       0.632        0.631        0.631        0.627        0.626        0.622        0.620        0.624        0.628        0.633        0.636
# ...

# %%
id5 = pd.read_csv(datapath + "Proc'd CSVs/" + "id5 Div2.csv", sep=',')
id6 = pd.read_csv(datapath + "Proc'd CSVs/" + "id6 Div2.csv", sep=',')
id7 = pd.read_csv(datapath + "Proc'd CSVs/" + "id7 Div2.csv", sep=',')
id13 = pd.read_csv(datapath + "Proc'd CSVs/" + "id13 Div2.csv", sep=',')
id20 = pd.read_csv(datapath + "Proc'd CSVs/" + "id20 Div2.csv", sep=',')
id24 = pd.read_csv(datapath + "Proc'd CSVs/" + "id24 Div2.csv", sep=',')
id25 = pd.read_csv(datapath + "Proc'd CSVs/" + "id25 Div2.csv", sep=',')
id43 = pd.read_csv(datapath + "Proc'd CSVs/" + "id43 Div2.csv", sep=',')
id48 = pd.read_csv(datapath + "Proc'd CSVs/" + "id48 Div2.csv", sep=',')
id49 = pd.read_csv(datapath + "Proc'd CSVs/" + "id49 Div2.csv", sep=',')
id50 = pd.read_csv(datapath + "Proc'd CSVs/" + "id50 Div2.csv", sep=',')
id51 = pd.read_csv(datapath + "Proc'd CSVs/" + "id51 Div2.csv", sep=',')
id65 = pd.read_csv(datapath + "Proc'd CSVs/" + "id65 Div2.csv", sep=',')
id68 = pd.read_csv(datapath + "Proc'd CSVs/" + "id68 Div2.csv", sep=',')
id69 = pd.read_csv(datapath + "Proc'd CSVs/" + "id69 Div2.csv", sep=',')
id70 = pd.read_csv(datapath + "Proc'd CSVs/" + "id70 Div2.csv", sep=',')
id71 = pd.read_csv(datapath + "Proc'd CSVs/" + "id71 Div2.csv", sep=',')

div2 = id5.merge(id6,how='outer').merge(id7,how='outer').merge(id13,how='outer').merge(id20,how='outer') \
          .merge(id24,how='outer').merge(id25,how='outer').merge(id43,how='outer').merge(id48,how='outer') \
          .merge(id49,how='outer').merge(id50,how='outer').merge(id51,how='outer').merge(id65,how='outer') \
          .merge(id68,how='outer').merge(id69,how='outer').merge(id70,how='outer').merge(id71,how='outer')

div2.to_csv('/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/' + 'Div2 2012-13.csv', sep = ',')

div2
# Out:
#                    Boat name  TCF_id5_d2  TCF_id6_d2  TCF_id7_d2  TCF_id13_d2  TCF_id20_d2  TCF_id24_d2  TCF_id25_d2  TCF_id43_d2  TCF_id48_d2  TCF_id49_d2  TCF_id50_d2  TCF_id51_d2  TCF_id65_d2  TCF_id68_d2  TCF_id69_d2  TCF_id70_d2  TCF_id71_d2
# 0                Prime Mover       0.760       0.765       0.768        0.766        0.767        0.760        0.761        0.760        0.759        0.764        0.758          NaN        0.756        0.758        0.755        0.756        0.764
# 1              Eat My Shorts       0.733       0.737       0.741          NaN          NaN        0.740        0.746          NaN          NaN          NaN          NaN          NaN        0.746          NaN        0.747        0.747        0.740
# 2                      Gucci       0.752       0.755       0.756        0.753        0.757        0.758        0.759        0.764        0.764        0.763        0.768        0.771        0.769        0.768        0.765        0.767        0.767
# ...

# %%
id5 = pd.read_csv(datapath + "Proc'd CSVs/" + "id5 Div1.csv", sep=',')
id6 = pd.read_csv(datapath + "Proc'd CSVs/" + "id6 Div1.csv", sep=',')
id7 = pd.read_csv(datapath + "Proc'd CSVs/" + "id7 Div1.csv", sep=',')
id13 = pd.read_csv(datapath + "Proc'd CSVs/" + "id13 Div1.csv", sep=',')
id20 = pd.read_csv(datapath + "Proc'd CSVs/" + "id20 Div1.csv", sep=',')
id24 = pd.read_csv(datapath + "Proc'd CSVs/" + "id24 Div1.csv", sep=',')
id25 = pd.read_csv(datapath + "Proc'd CSVs/" + "id25 Div1.csv", sep=',')
id50 = pd.read_csv(datapath + "Proc'd CSVs/" + "id50 Div1.csv", sep=',')
id65 = pd.read_csv(datapath + "Proc'd CSVs/" + "id65 Div1.csv", sep=',')
id68 = pd.read_csv(datapath + "Proc'd CSVs/" + "id68 Div1.csv", sep=',')
id69 = pd.read_csv(datapath + "Proc'd CSVs/" + "id69 Div1.csv", sep=',')
id70 = pd.read_csv(datapath + "Proc'd CSVs/" + "id70 Div1.csv", sep=',')
id71 = pd.read_csv(datapath + "Proc'd CSVs/" + "id71 Div1.csv", sep=',')

div1 = id5.merge(id6,how='outer').merge(id7,how='outer').merge(id13,how='outer').merge(id20,how='outer') \
          .merge(id24,how='outer').merge(id25,how='outer').merge(id50,how='outer').merge(id65,how='outer') \
          .merge(id68,how='outer').merge(id69,how='outer').merge(id70,how='outer').merge(id71,how='outer')

div1.to_csv('/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/' + 'Div1 2012-13.csv', sep = ',')

div1
# Out:
#               Boat name  TCF_id5_d1  TCF_id6_d1  TCF_id7_d1  TCF_id13_d1  TCF_id20_d1  TCF_id24_d1  TCF_id25_d1  TCF_id50_d1  TCF_id65_d1  TCF_id68_d1  TCF_id69_d1  TCF_id70_d1  TCF_id71_d1
# 0          Clear Vision       0.826       0.830         NaN          NaN          NaN        0.833        0.831          NaN          NaN          NaN          NaN          NaN          NaN
# 1           Magic Trick       0.891       0.894       0.895          NaN          NaN        0.892        0.894        0.887        0.887          NaN          NaN          NaN          NaN
# 2         The Guarantee       0.845       0.847       0.852        0.851          NaN          NaN          NaN          NaN          NaN          NaN        0.847        0.850        0.842
# 3        Drinks Trolley       0.824       0.824       0.825          NaN          NaN        0.826        0.823          NaN          NaN          NaN          NaN          NaN          NaN
# ...

# %%
#df1.merge(df2,how='outer').merge(df3,how='outer')
new = pd.merge(df1, df2, how='outer')
new2 = pd.merge(new, df3, how='outer')
new2

# %%
df1 = pd.read_csv("id3.csv", sep=',')
df2 = pd.read_csv("id6.csv", sep=',')
df3 = pd.read_csv("id10.csv", sep=',')
df1,df2,df3
# Out:
# (                   Boat name    TCF
# 0             After Midnight  0.693
# 1             Youth Scheme 3  0.655
# 2              Eat My Shorts  0.695
# 3              Saucy Sausage  0.605
# 4                  88% Proof  0.720
# 5                  Incantare  0.671
# 6                 Testarossa  0.732
# 7                    Haumuri  0.597
# 8               Whistler III  0.690
# 9             Youth Scheme 4  0.655
# 10            White Cavalier  0.569
# 11            Youth Scheme 2  0.655
# 12                   Airship  0.715
# 13             Floating Free  0.704
# 14                     Gucci  0.737
# 15     Wellington Spirit Red  0.720
# 16                  Marishka  0.625
# 17  Wellington Spirit Purple  0.720
# 18                    Lizzie  0.400
# 19                 Cantilena  0.663
# 20                    Fulmar  0.688
# 21  Wellington Spirit Bronze  0.720,
#                     Boat name    TCF
# 0              Eat My Shorts  0.699
# 1                 Testarossa  0.736
# ...

# %%
#df1.rename(columns={"TCF": "TCF1"})  # rename TCF as TCF1 but doesn't change df1
df1.rename(columns={"TCF": "TCF3"}, inplace=True)  # permanently change column name
df2.rename(columns={"TCF": "TCF6"}, inplace=True)  # permanently change column name
df3.rename(columns={"TCF": "TCF10"}, inplace=True)  # permanently change column name

# %%
df2
# Out:
#                    Boat name   TCF6
# 0              Eat My Shorts  0.699
# 1                 Testarossa  0.736
# 2                  Incantare  0.675
# 3               Whistler III  0.691
# 4              Saucy Sausage  0.609
# 5                      Gucci  0.735
# 6                    Airship  0.714
# 7             Youth Scheme 3  0.659
# 8                   Marishka  0.620
# 9             After Midnight  0.697
# 10     Wellington Spirit Red  0.718
# 11           Montego Bay III  0.719
# 12                 88% Proof  0.724
# 13                   Haumuri  0.601
# 14  Wellington Spirit Purple  0.714
# 15                 Rosschild  0.620
# 16                 Cantilena  0.658
# 17  Wellington Spirit Bronze  0.714
# 18                   WiseGuy  0.675
# 19            White Cavalier  0.569
# 20                    Lizzie    NaN

# %%
#df1.merge(df2,how='outer').merge(df3,how='outer')
new = pd.merge(df1, df2, how='outer')
new2 = pd.merge(new, df3, how='outer')
new2
# Out:
#                    Boat name   TCF3   TCF6  TCF10
# 0             After Midnight  0.693  0.697  0.699
# 1             Youth Scheme 3  0.655  0.659  0.662
# 2              Eat My Shorts  0.695  0.699  0.705
# 3              Saucy Sausage  0.605  0.609  0.614
# 4                  88% Proof  0.720  0.724  0.721
# 5                  Incantare  0.671  0.675  0.682
# 6                 Testarossa  0.732  0.736  0.743
# 7                    Haumuri  0.597  0.601  0.598
# 8               Whistler III  0.690  0.691  0.695
# 9             Youth Scheme 4  0.655    NaN    NaN
# 10            White Cavalier  0.569  0.569  0.565
# 11            Youth Scheme 2  0.655    NaN    NaN
# 12                   Airship  0.715  0.714  0.715
# 13             Floating Free  0.704    NaN  0.702
# 14                     Gucci  0.737  0.735  0.736
# 15     Wellington Spirit Red  0.720  0.718  0.714
# 16                  Marishka  0.625  0.620  0.618
# 17  Wellington Spirit Purple  0.720  0.714  0.706
# ...

# %%
new
# Out:
#                    Boat name   TCF3   TCF6
# 0             After Midnight  0.693  0.697
# 1             Youth Scheme 3  0.655  0.659
# 2              Eat My Shorts  0.695  0.699
# 3              Saucy Sausage  0.605  0.609
# 4                  88% Proof  0.720  0.724
# 5                  Incantare  0.671  0.675
# 6                 Testarossa  0.732  0.736
# 7                    Haumuri  0.597  0.601
# 8               Whistler III  0.690  0.691
# 9             Youth Scheme 4  0.655    NaN
# 10            White Cavalier  0.569  0.569
# 11            Youth Scheme 2  0.655    NaN
# 12                   Airship  0.715  0.714
# 13             Floating Free  0.704    NaN
# 14                     Gucci  0.737  0.735
# 15     Wellington Spirit Red  0.720  0.718
# 16                  Marishka  0.625  0.620
# 17  Wellington Spirit Purple  0.720  0.714
# 18                    Lizzie  0.400    NaN
# 19                 Cantilena  0.663  0.658
# 20                    Fulmar  0.688    NaN
# ...

# %%
df2 - df1.merge(df2,how='outer')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-40287beb6652> in <module>()
# ----> 1 df2 - df1.merge(df2,how='outer')
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in f(self, other, axis, level, fill_value)
#     216     def f(self, other, axis=default_axis, level=None, fill_value=None):
#     217         if isinstance(other, DataFrame):    # Another DataFrame
# --> 218             return self._combine_frame(other, na_op, fill_value, level)
#     219         elif isinstance(other, Series):
#     220             return self._combine_series(other, na_op, fill_value, axis, level)
#
# C:\Python27\lib\site-packages\pandas\core\frame.pyc in _combine_frame(self, other, func, fill_value, level)
#    3839             result = {}
#    3840             for col in this:
# -> 3841                 result[col] = _arith_op(this[col].values, other[col].values)
# ...

# %%
pd.concat([df1, df2]).groupby(["items"], as_index=False)["value"].sum()
# Out:
#      items  value
# 0    item1      8
# 1   item10     14
# 2   item11     15
# 3    item2      2
# 4    item3      3
# 5    item4      8
# 6    item5      9
# 7    item6     14
# 8    item7     16
# 9    item8     18
# 10   item9     13

# %%
df2['value2'] = df2['value']
df2.pop('value')
# Out:
# 0     7
# 1     8
# 2     9
# 3    10
# 4    11
# 5    12
# 6    13
# 7    14
# 8    15
# Name: value, dtype: int64

# %%
df2
# Out:
#     items  value2
# 0   item1       7
# 1   item4       8
# 2   item5       9
# 3   item6      10
# 4   item7      11
# 5   item8      12
# 6   item9      13
# 7  item10      14
# 8  item11      15

# %%
df1.merge(df2)
# Out:
# Empty DataFrame
# Columns: [items, value]
# Index: []

# %%
a = [1, 2, 3]
b = [4, 5, 6]

c = a + b
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c = []
a = [1, 2, 3]
b = [4, 5, 6]

c += (a + b)
c
# Out:
# [1, 2, 3, 4, 5, 6]
