# %% [markdown]
# #### Use this code to read a CSV file containing race results as generated by Yacht Systems. You will
# need to specify infilename, i, s, r, d and f at the appropriate juncture. Be aware that the code
# may need to be edited/amended in certain circumstances - CSV file structure is different, more than
# one race per day, one race ID is associated with different race numbers for each division, etc.

# %%
#-------10--------20--------30--------40--------50--------60--------70--------80
import pandas as pd
import numpy as np
import datetime as dt
#import matplotlib
#import EAtools as ea
import os
import re

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)
#pd.set_option('display.max_columns',10000)
#pd.set_option('display.max_rows',10000)
#pd.set_option('display.max_colwidth',10000)
#pd.set_option('display.max_info_columns',10000)
#pd.set_option('display.notebook_repr_html',True)
#pd.set_option('display.expand_frame_repr', True)

datapath = 'C:\\Phil\\My Dropbox\\Sailing cmte\\Handicapping\\2013-14 season\\'
#datapath = '/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/2013-14 season/'

# %%
# Define functions - if these functions are used frequently, consider moving them into a package.

# Read selected columns from raw CSV file and make boat name the index
def input_csv(path,filename):
    raw_data = pd.read_csv(path + filename, sep=',', header=None, usecols=CSVcolNums)
    raw_data.columns = CSVcolHdrs
    raw_data = raw_data.set_index('Boat name')
    return raw_data


# Convert elapsed time (hh:mm:ss or mm:ss or <xxx>) to seconds as an integer
def et2seconds(x):
    if '<' in x:
        return np.nan    # np.nan is preferable to 'NaN', NaN, or 0
    else:
        if len(x) > 5:
            hours = int(x.split(':')[0])
            minutes = int(x.split(':')[1])
            seconds = int(x.split(':')[2])
            return seconds + minutes*60 + hours*60*60
        else:
            minutes = int(x.split(':')[0])
            seconds = int(x.split(':')[1])
            return seconds + minutes*60


# Extract division from Stuff field
def get_division(x):
    if 'Division' in x:
        return x.split('Division')[1].replace(' ','')[0]  # assumes returned value is a single character - will fail if div is not, 1, 2, 3, A, B, etc
    else:
        if 'Open, start' in x:
            return x.split(', start')[0]
        else:
            if 'Classics, start' in x:
                return x.split(', start')[0]
            else:
                return 'Combined'

# %%
# Take a quick look at a raw CSV file - need to select/deselect appropriate cols in CSV

infilename = 'id3 spring r3 results'

# Following list of colNums and colHdrs works fine on:
# - Divisional races
# - Winter series fully crewed
CSVcolNums = [1,3,5,7,9,28,29,30,31,32,35,41,45]
CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Stuff','Sail number','Boat design', \
              'Boat name','Elapsed time','TCF','PHRF','IRC']

q = input_csv(datapath + "Raw CSV data/", infilename + '.csv')
#q.head(5)
q

# Notes:
# - Edit '..\Handicapping\2013-14 season\Season summary (2013-14).xlsx'
# - Compare imported data with hard-copy printout from Yacht Systems
# - Make sure Elapsed time field begins with < if no time, e.g. <n/e>, <no entry>, <dnf>, <raf>, <osc>, <dns> etc
# - Check for duplicate boat names, i.e. incorrect spelling
# Out:
#                                          Race                      Date Wind direction Wind speed  ID                                   Stuff Sail number     Boat design Elapsed time    TCF   PHRF    IRC
# Boat name
# Blink                     Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405      110011         Shaw 12      2:03:09  0.950  0.980  0.000
# Revs                      Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405        8234         Ross 12      2:11:36  0.894  0.885  1.234
# Drinks Trolley            Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405        8737     Thompson 30      2:25:46  0.824  0.840  0.000
# Nedax Racing              Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405        8985     Thompson 30      2:24:24  0.832  0.840  0.000
# Rocket Science            Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405       T4159     Thomson 750      2:25:00  0.830  0.820  0.000
# Magic Trick               Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405        9198        Shaw 650      2:16:14  0.891  0.875  0.000
# Wedgetail                 Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405        9442     Welbourn 42      2:09:28  0.945  0.950  1.209
# The Guarantee             Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3             Division 1, start time 1405        8625      Ross 10.66      2:26:02  0.848  0.845  0.000
# WiseGuy                   Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        6585        Young 88      2:17:03  0.706    NaN  0.000
# Wellington Spirit Red     Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        9004        Farr MRX      2:14:40  0.758  0.790  0.000
# Blue Magic                Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        6716         Ross 35      2:18:14  0.739  0.735  0.955
# Gucci                     Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        6654       Warick 35      2:18:44  0.750  0.755  0.963
# Eat My Shorts             Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        5892       Farr 1020      2:21:01  0.742  0.745  0.000
# Airship                   Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        4953         Ross930      2:18:56  0.754  0.735  0.000
# Incantare                 Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13         881        Young 88      2:28:57  0.708  0.725  0.000
# Prime Mover               Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        6804       Farr 1104      2:20:16  0.761  0.765  0.000
# Whistler III              Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        5988        Young 88      2:26:31  0.730  0.725  0.950
# Wellington Spirit Bronze  Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        9005        Farr MRX      2:21:01  0.763  0.790  0.000
# Montego Bay III           Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3  Division 2, start time 1410, course 13        5477         Simpson      2:34:37  0.719  0.745  0.000
# St Laurence               Sring Series Race 3  Saturday, 5 October 2013              N       5-15   3                   Open, start time 1405        7569  Newick Val III      2:08:27  1.050    NaN  0.000

# %%
# Create a uniformly structured dataframe for the current race data

# Specify i for id, s for series name, r for race number and d for date - for the current set of results
i = "id3"      
s = "spring"
r = "r3"
d = "5 Oct"

data = input_csv(datapath + "Raw CSV data/", infilename + '.csv')
data = data.replace(0.00,nan)
data['Seconds'] = data['Elapsed time'].map(lambda x: et2seconds(x))
data['Div']     = data['Stuff'].map(lambda x: get_division(x))
data['Details'] = i + ' ' + s + ' ' + r + ' ' + d

# Identify desired columns - in order.
cols = ['Details', 'Div', 'Elapsed time', 'Seconds', 'TCF', 'PHRF', 'IRC']
#data.columns.tolist()

outfilename = i + ' All divs ' + s + ' ' + r
data[cols].to_csv(datapath + "Proc'd CSVs/" + outfilename + '.csv', sep = ',')

#data[cols].dtypes
#data[cols].sort(['Div','Seconds'])
data[cols]
# Out:
#                                       Details   Div Elapsed time  Seconds    TCF   PHRF    IRC
# Boat name
# Blink                     id3 spring r3 5 Oct     1      2:03:09     7389  0.950  0.980    NaN
# Revs                      id3 spring r3 5 Oct     1      2:11:36     7896  0.894  0.885  1.234
# Drinks Trolley            id3 spring r3 5 Oct     1      2:25:46     8746  0.824  0.840    NaN
# Nedax Racing              id3 spring r3 5 Oct     1      2:24:24     8664  0.832  0.840    NaN
# Rocket Science            id3 spring r3 5 Oct     1      2:25:00     8700  0.830  0.820    NaN
# Magic Trick               id3 spring r3 5 Oct     1      2:16:14     8174  0.891  0.875    NaN
# Wedgetail                 id3 spring r3 5 Oct     1      2:09:28     7768  0.945  0.950  1.209
# The Guarantee             id3 spring r3 5 Oct     1      2:26:02     8762  0.848  0.845    NaN
# WiseGuy                   id3 spring r3 5 Oct     2      2:17:03     8223  0.706    NaN    NaN
# Wellington Spirit Red     id3 spring r3 5 Oct     2      2:14:40     8080  0.758  0.790    NaN
# Blue Magic                id3 spring r3 5 Oct     2      2:18:14     8294  0.739  0.735  0.955
# Gucci                     id3 spring r3 5 Oct     2      2:18:44     8324  0.750  0.755  0.963
# Eat My Shorts             id3 spring r3 5 Oct     2      2:21:01     8461  0.742  0.745    NaN
# Airship                   id3 spring r3 5 Oct     2      2:18:56     8336  0.754  0.735    NaN
# Incantare                 id3 spring r3 5 Oct     2      2:28:57     8937  0.708  0.725    NaN
# Prime Mover               id3 spring r3 5 Oct     2      2:20:16     8416  0.761  0.765    NaN
# Whistler III              id3 spring r3 5 Oct     2      2:26:31     8791  0.730  0.725  0.950
# Wellington Spirit Bronze  id3 spring r3 5 Oct     2      2:21:01     8461  0.763  0.790    NaN
# Montego Bay III           id3 spring r3 5 Oct     2      2:34:37     9277  0.719  0.745    NaN
# St Laurence               id3 spring r3 5 Oct  Open      2:08:27     7707  1.050    NaN    NaN

# %%
# Create a separate dataframe for each division and write it to a CSV file

# Edit f according to divisions present in col Div above.
f = ['div1', 'div2', 'div3', 'divClassics','divOpen']

for x in f:
    div = x.split('div')[1]
    outfilename = i + ' ' + x + ' ' + s + ' ' + r
    x = data[cols][data['Div'] == div]
    x.to_csv(datapath + "Proc'd CSVs/" + outfilename + '.csv', sep = ',')
    print '\n', div, '  ', outfilename
    print x
# Out:
# 1    id3 div1 spring r3
#                             Details Div Elapsed time  Seconds    TCF   PHRF    IRC
# Boat name
# Blink           id3 spring r3 5 Oct   1      2:03:09     7389  0.950  0.980    NaN
# Revs            id3 spring r3 5 Oct   1      2:11:36     7896  0.894  0.885  1.234
# Drinks Trolley  id3 spring r3 5 Oct   1      2:25:46     8746  0.824  0.840    NaN
# Nedax Racing    id3 spring r3 5 Oct   1      2:24:24     8664  0.832  0.840    NaN
# Rocket Science  id3 spring r3 5 Oct   1      2:25:00     8700  0.830  0.820    NaN
# Magic Trick     id3 spring r3 5 Oct   1      2:16:14     8174  0.891  0.875    NaN
# Wedgetail       id3 spring r3 5 Oct   1      2:09:28     7768  0.945  0.950  1.209
# The Guarantee   id3 spring r3 5 Oct   1      2:26:02     8762  0.848  0.845    NaN
#
# 2    id3 div2 spring r3
#                                       Details Div Elapsed time  Seconds    TCF   PHRF    IRC
# Boat name
# WiseGuy                   id3 spring r3 5 Oct   2      2:17:03     8223  0.706    NaN    NaN
# Wellington Spirit Red     id3 spring r3 5 Oct   2      2:14:40     8080  0.758  0.790    NaN
# Blue Magic                id3 spring r3 5 Oct   2      2:18:14     8294  0.739  0.735  0.955
# Gucci                     id3 spring r3 5 Oct   2      2:18:44     8324  0.750  0.755  0.963
# Eat My Shorts             id3 spring r3 5 Oct   2      2:21:01     8461  0.742  0.745    NaN
# Airship                   id3 spring r3 5 Oct   2      2:18:56     8336  0.754  0.735    NaN
# Incantare                 id3 spring r3 5 Oct   2      2:28:57     8937  0.708  0.725    NaN
# Prime Mover               id3 spring r3 5 Oct   2      2:20:16     8416  0.761  0.765    NaN
# Whistler III              id3 spring r3 5 Oct   2      2:26:31     8791  0.730  0.725  0.950
# Wellington Spirit Bronze  id3 spring r3 5 Oct   2      2:21:01     8461  0.763  0.790    NaN
# Montego Bay III           id3 spring r3 5 Oct   2      2:34:37     9277  0.719  0.745    NaN
#
# 3    id3 div3 spring r3
# Empty DataFrame
# Columns: [Details, Div, Elapsed time, Seconds, TCF, PHRF, IRC]
# Index: []
#
# Classics    id3 divClassics spring r3
# Empty DataFrame
# Columns: [Details, Div, Elapsed time, Seconds, TCF, PHRF, IRC]
# Index: []
#
# Open    id3 divOpen spring r3
#                          Details   Div Elapsed time  Seconds   TCF  PHRF  IRC
# Boat name
# St Laurence  id3 spring r3 5 Oct  Open      2:08:27     7707  1.05   NaN  NaN

# %% [markdown]
# ##### Misc crap beyond this point

# %%
# Write out a file of boat details for boats that showed up to race

# Define outcome for boats that showed up
def outcome(x):
    if '<' in x:
        return x
    else:
        return 'Finished'
    

# See http://stackoverflow.com/questions/17002186/merging-multiple-unaligned-data-frames-into-single-pandas-data-frame
# The next line was replaced with the one that follows it because merging wouldn't work when all those cols existed in the dataframe
#boatcols = ['Boat design', 'Sail number']
boatcols = []
boatdata = data[boatcols]
boatdata[d] = data['Elapsed time'].map(lambda x: outcome(x))
boatdata.to_csv(datapath + "Boats/" + 'Boats out on ' + d + '.csv', sep = ',')
boatdata
# Out:
#                               28 Sep
# Boat name
# The Guarantee               Finished
# Revs                        Finished
# Whistler III                Finished
# Incantare                   Finished
# Airship                     Finished
# WiseGuy                     Finished
# Wellington Spirit Bronze    Finished
# Wellington Spirit Red       Finished
# Gucci                       Finished
# Cantilena                   Finished
# Titus Canby                 Finished
# Saucy Sausage               Finished
# Marangi                   <no entry>

# %%
#masterboatdata = pd.read_csv(datapath + "Boats/" + 'Boats out on 28 Sep.csv', index_col = [0,1,2], sep=',')
#newboatdata    = pd.read_csv(datapath + "Boats/" + 'Boats out on 5 Oct.csv', index_col = [0,1,2], sep=',')
masterboatdata = pd.read_csv(datapath + "Boats/" + 'Boats out on 28 Sep.csv', sep=',')
newboatdata    = pd.read_csv(datapath + "Boats/" + 'Boats out on 5 Oct.csv', usecols = [0,3], sep=',')


#oldboatdata = raw_data = pd.read_csv(datapath + "Boats/" + 'Boats out on 5 Oct.csv', sep=',')
#oldboatdata = oldboatdata.set_index('Boat name')
newboatdata
masterboatdata
# Out:
#                    Boat name      28 Sep
# 0              The Guarantee    Finished
# 1                       Revs    Finished
# 2               Whistler III    Finished
# 3                  Incantare    Finished
# 4                    Airship    Finished
# 5                    WiseGuy    Finished
# 6   Wellington Spirit Bronze    Finished
# 7      Wellington Spirit Red    Finished
# 8                      Gucci    Finished
# 9                  Cantilena    Finished
# 10               Titus Canby    Finished
# 11             Saucy Sausage    Finished
# 12                   Marangi  <no entry>

# %%
mergeboatdata = masterboatdata.merge(newboatdata, how = 'outer')
#mergeboatdata.set_index('Boat name')
mergeboatdata
#div3.to_csv('/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/' + 'Div3 2012-13.csv', sep = ',')
# Out:
#                    Boat name      28 Sep       5-Oct
# 0              The Guarantee    Finished    Finished
# 1                       Revs    Finished    Finished
# 2               Whistler III    Finished    Finished
# 3                  Incantare    Finished    Finished
# 4                    Airship    Finished    Finished
# 5                    WiseGuy    Finished    Finished
# 6   Wellington Spirit Bronze    Finished    Finished
# 7      Wellington Spirit Red    Finished    Finished
# 8                      Gucci    Finished    Finished
# 9                  Cantilena    Finished         NaN
# 10               Titus Canby    Finished         NaN
# 11             Saucy Sausage    Finished    Finished
# 12                   Marangi  <no entry>  <no entry>
# 13            Rocket Science         NaN    Finished

# %%
mergeboatdata.count()
# Out:
# Boat name    14
# 28 Sep       13
# 5-Oct        12
# dtype: int64
