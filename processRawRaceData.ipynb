# %% [markdown]
# #### Use this code to read a CSV file containing race results. Specify infilename, h, s, r, and d at the appropriate juncture. Be aware that the code
# may need to be edited/amended in certain circumstances - CSV file structure is different, more than
# one race per day, different race numbers for each division, etc.

# %%
#-------10--------20--------30--------40--------50--------60--------70--------80
import pandas as pd
import numpy as np
import datetime as dt
import functions as fn
#import matplotlib
import os
import re

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)
#pd.set_option('display.max_columns',10000)
#pd.set_option('display.max_rows',10000)
#pd.set_option('display.max_colwidth',10000)
#pd.set_option('display.max_info_columns',10000)
#pd.set_option('display.notebook_repr_html',True)
#pd.set_option('display.expand_frame_repr', True)

datapath = 'C:\\Phil\\My Dropbox\\Sailing cmte\\Handicapping\\2013-14 season\\'
#datapath = '/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/2013-14 season/'

# %%
# Take a quick look at a raw CSV file from Yacht Systems
# - need to select/deselect appropriate cols in CSV

infilename = 'Christmas23Nov'

# Following list of colNums and colHdrs works fine on:
# - Divisional races
# - Winter series fully crewed
#CSVcolNums = [1,3,5,7,9,28,29,30,31,32,35,37,41,45]
#CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Stuff','Sail number','Boat design', \
#              'Boat name','Elapsed time','TCFapplied','Rank','PHRF','IRC']

# Following list of colNums and colHdrs works fine on manually constructed CSVs for combined fleet races:
#CSVcolNums = [0,1,2,3,4,5]
#CSVcolHdrs = ['Boat name','Elapsed time','Rank','TCFapplied','PHRF','IRC']

# Following list of colNums and colHdrs works fine on manually constructed CSVs for divisional races:
CSVcolNums = [0,1,2,3,4,5,6,7]
CSVcolHdrs = ['Boat name','Race','Div','Elapsed time','Rank','TCFapplied','PHRF','IRC']

# Following list of colNums and colHdrs works fine on Island Bay races:
#CSVcolNums = [1,3,5,7,9,26,27,28,33,36,38,40,44]
#CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Sail number','Boat design', \
#              'Boat name','Elapsed time','TCFapplied','Rank','PHRF','IRC']

q = pd.read_csv(datapath+"Raw CSV data/"+infilename+'.csv', sep=',', header=None, usecols=CSVcolNums)
q.columns = CSVcolHdrs
#q.head(5)
q

# Read selected columns from raw CSV file and make boat name the index
#def input_csv(path,filename,CSVcolNums,CSVcolHdrs):
#    raw_data = pd.read_csv(path + filename, sep=',', header=None, usecols=CSVcolNums)
#    raw_data.columns = CSVcolHdrs
#    raw_data = raw_data.set_index('Boat name')
#    return raw_data



# Notes:
# - Edit '..\Handicapping\2013-14 season\Season summary (2013-14).xlsx'
# - Compare imported data with hard-copy printout from Yacht Systems
# - Make sure Elapsed time field begins with < if no time, e.g. <n/e>, <no entry>, <dnf>, <raf>, <osc>, <dns> etc
# - Check for duplicate boat names, i.e. incorrect spelling
# Out:
#                    Boat name Race  Div Elapsed time  Rank  TCFapplied   PHRF    IRC
# 0             Rocket Science   r2    1      0:41:37     1       0.802  0.820    NaN
# 1                Magic Trick   r2    1      0:38:14     2       0.885  0.875    NaN
# 2              The Guarantee   r2    1      0:42:16     3       0.829  0.845    NaN
# 3                  Wedgetail   r2    1      0:37:14     4       0.944  0.950  1.209
# 4                 Ran Tan II   r2    1      0:36:05     5       0.995  1.040    NaN
# 5             Drinks Trolley   r2    1      0:43:01     6       0.836  0.840    NaN
# 6               Nedax Racing   r2    1      0:44:09     7       0.828  0.840    NaN
# 7                       Revs   r2    1      0:41:11     8       0.904  0.885  1.234
# 8                      Blink   r2    1      0:39:46     9       0.960  0.980    NaN
# 9             After Midnight   r2    2      0:32:55     1       0.723  0.715    NaN
# 10              Whistler III   r2    2      0:32:43     2       0.730  0.725  0.950
# 11                     Gucci   r2    2      0:31:54     3       0.754  0.755  0.963
# 12             Eat My Shorts   r2    2      0:33:42     4       0.733  0.745    NaN
# 13                   Wiseguy   r2    2      0:35:00     5       0.711    NaN    NaN
# 14                Blue Magic   r2    2      0:33:42     6       0.746  0.735  0.955
# 15             Floating Free   r2    2      0:35:42     7       0.706    NaN    NaN
# 16                   Airship   r2    2      0:33:57     8       0.752  0.735    NaN
# 17                 Incantare   r2    2      0:37:40     9       0.701  0.725    NaN
# 18  Wellington Spirit Bronze   r2    2      0:39:31    10       0.745  0.790    NaN
# 19                      Brix   r2    2      0:40:35    11       0.730    NaN    NaN
# 20               Prime Mover   r2    2      0:46:35    12       0.746  0.765  0.963
# 21            Revenue Cutter   r2    3      1:51:17     1       0.643    NaN    NaN
# 22               Titus Canby   r2    3      1:46:21     2       0.686  0.690    NaN
# 23                 Rosschild   r2    3      1:55:35     3       0.639  0.680    NaN
# 24                  Marishka   r2    3      2:00:25     4       0.614  0.650    NaN
# 25             Saucy Sausage   r2    3      2:03:05     5       0.623  0.630    NaN
# 26             Blurred Image   r2    3      1:56:18     6       0.685    NaN    NaN
# 27            White Cavalier   r2    3      2:23:37     7       0.562    NaN    NaN
# 28                 Wai-Aniwa   r2    3      2:01:24     8       0.674  0.690    NaN
# 29                   Haumuri   r2    3      2:10:09     9       0.672  0.665    NaN
# 30            Drinks Trolley   r3    1      1:46:31     1       0.833  0.840    NaN
# 31                      Revs   r3    1      1:42:36     2       0.897  0.885  1.234
# 32                     Blink   r3    1      1:37:50     3       0.954  0.980    NaN
# 33              Nedax Racing   r3    1      1:57:07     4       0.824  0.840    NaN
# 34            Rocket Science   r3    1      2:02:14     5       0.801  0.820    NaN
# 35             The Guarantee   r3    1      1:58:41     6       0.828  0.845    NaN
# 36               Magic Trick   r3    1      1:50:37     7       0.889  0.875    NaN
# 37                Ran Tan II   r3    1      1:41:55     8       0.994  1.040    NaN
# 38                 Wedgetail   r3    1      1:48:25     9       0.944  0.950  1.209
# 39                   Wiseguy   r3    2      2:20:19     1       0.707    NaN    NaN
# 40                      Brix   r3    2      2:17:39     2       0.725    NaN    NaN
# 41                   Airship   r3    2      2:18:03     3       0.751  0.735    NaN
# 42              Whistler III   r3    2      2:28:35     4       0.737  0.725  0.950
# 43             Floating Free   r3    2      2:38:29     5       0.706    NaN    NaN
# 44            After Midnight   r3    2      2:34:18     6       0.728  0.715    NaN
# 45                 Incantare   r3    2      2:47:50     7       0.695  0.725    NaN
# 46               Prime Mover   r3    2      2:37:56     8       0.743  0.765  0.963
# 47             Eat My Shorts   r3    2      2:39:49     9       0.739  0.745    NaN
# 48                     Gucci   r3    2      2:37:53    10       0.761  0.755  0.963
# 49  Wellington Spirit Bronze   r3    2      2:46:49    11       0.739  0.790    NaN
# 50                Blue Magic   r3    2      2:48:18    12       0.743  0.735  0.955

# %%
# Create a uniformly structured dataframe for the current race data

# Specify h for handicap type, s for series name (see p84 Almanac),
# r for race number and d for date - for the current set of results
h = "Championship"
s = "Christmas"
r = "r1"
d = "23/11/2013"

data = pd.read_csv(datapath+"Raw CSV data/"+infilename+'.csv', sep=',', header=None, usecols=CSVcolNums)
data.columns = CSVcolHdrs
data = data.replace(0.00,nan)

data['Date'] = d
data['Handicap'] = h
data['Series'] = s
#data['Race'] = r
#data['Div']  = 'Combined'
#data['Div'] = data['Stuff'].map(lambda x: fn.get_division(x))
data['ETsecs'] = data['Elapsed time'].map(lambda x: fn.et2seconds(x))

# Overwrite some records...
#data['Race'][data['Div']=='3'] = 'r3'
#data['Race'][data['Div']=='Open'] = 'r2'
#data['Handicap'][data['Div']=='Classics'] = 'Classics'
#data['Series'][data['Div']=='Classics'] = 'Classics'
#data['Race'][data['Div']=='Classics'] = 'r1'
#data['Div'][data['Div']=='Classics'] = 'Combined'
#data.ix[['Lizzie','Loloma'],'Series'] = 'Classics'
#data.ix[['Lizzie','Loloma'],'Race'] = 'r2'

# Identify desired columns - in order.
cols = ['Date','Handicap','Series','Race','Div','Boat name','Elapsed time','ETsecs','Rank','TCFapplied','PHRF','IRC']
#data.columns.tolist()

outfilename = infilename
data[cols].to_csv(datapath+"Proc'd CSVs/"+outfilename+'.csv', sep = ',')
data[cols]
# Out:
#           Date      Handicap     Series Race  Div                 Boat name Elapsed time  ETsecs  Rank  TCFapplied   PHRF    IRC
# 0   23/16/2013  Championship  Christmas   r2    1            Rocket Science      0:41:37    2497     1       0.802  0.820    NaN
# 1   23/16/2013  Championship  Christmas   r2    1               Magic Trick      0:38:14    2294     2       0.885  0.875    NaN
# 2   23/16/2013  Championship  Christmas   r2    1             The Guarantee      0:42:16    2536     3       0.829  0.845    NaN
# 3   23/16/2013  Championship  Christmas   r2    1                 Wedgetail      0:37:14    2234     4       0.944  0.950  1.209
# 4   23/16/2013  Championship  Christmas   r2    1                Ran Tan II      0:36:05    2165     5       0.995  1.040    NaN
# 5   23/16/2013  Championship  Christmas   r2    1            Drinks Trolley      0:43:01    2581     6       0.836  0.840    NaN
# 6   23/16/2013  Championship  Christmas   r2    1              Nedax Racing      0:44:09    2649     7       0.828  0.840    NaN
# 7   23/16/2013  Championship  Christmas   r2    1                      Revs      0:41:11    2471     8       0.904  0.885  1.234
# 8   23/16/2013  Championship  Christmas   r2    1                     Blink      0:39:46    2386     9       0.960  0.980    NaN
# 9   23/16/2013  Championship  Christmas   r2    2            After Midnight      0:32:55    1975     1       0.723  0.715    NaN
# 10  23/16/2013  Championship  Christmas   r2    2              Whistler III      0:32:43    1963     2       0.730  0.725  0.950
# 11  23/16/2013  Championship  Christmas   r2    2                     Gucci      0:31:54    1914     3       0.754  0.755  0.963
# 12  23/16/2013  Championship  Christmas   r2    2             Eat My Shorts      0:33:42    2022     4       0.733  0.745    NaN
# 13  23/16/2013  Championship  Christmas   r2    2                   Wiseguy      0:35:00    2100     5       0.711    NaN    NaN
# 14  23/16/2013  Championship  Christmas   r2    2                Blue Magic      0:33:42    2022     6       0.746  0.735  0.955
# 15  23/16/2013  Championship  Christmas   r2    2             Floating Free      0:35:42    2142     7       0.706    NaN    NaN
# 16  23/16/2013  Championship  Christmas   r2    2                   Airship      0:33:57    2037     8       0.752  0.735    NaN
# 17  23/16/2013  Championship  Christmas   r2    2                 Incantare      0:37:40    2260     9       0.701  0.725    NaN
# 18  23/16/2013  Championship  Christmas   r2    2  Wellington Spirit Bronze      0:39:31    2371    10       0.745  0.790    NaN
# 19  23/16/2013  Championship  Christmas   r2    2                      Brix      0:40:35    2435    11       0.730    NaN    NaN
