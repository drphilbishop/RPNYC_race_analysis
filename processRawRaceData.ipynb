# %% [markdown]
# #### Use this code to read a CSV file containing race results as generated by Yacht Systems. You will
# need to specify infilename, i, s, r, d and f at the appropriate juncture. Be aware that the code
# may need to be edited/amended in certain circumstances - CSV file structure is different, more than
# one race per day, one race ID is associated with different race numbers for each division, etc.

# %%
#-------10--------20--------30--------40--------50--------60--------70--------80
import pandas as pd
import numpy as np
import datetime as dt
#import matplotlib
#import EAtools as ea
import os
import re

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)
#pd.set_option('display.max_columns',10000)
#pd.set_option('display.max_rows',10000)
#pd.set_option('display.max_colwidth',10000)
#pd.set_option('display.max_info_columns',10000)
#pd.set_option('display.notebook_repr_html',True)
#pd.set_option('display.expand_frame_repr', True)

datapath = 'C:\\Phil\\My Dropbox\\Sailing cmte\\Handicapping\\2013-14 season\\'
#datapath = '/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/2013-14 season/'

# %%
# Define functions - if these functions are used frequently, consider moving them into a package.

# Read selected columns from raw CSV file and make boat name the index
def input_csv(path,filename):
    raw_data = pd.read_csv(path + filename, sep=',', header=None, usecols=CSVcolNums)
    raw_data.columns = CSVcolHdrs
    raw_data = raw_data.set_index('Boat name')
    return raw_data


# Convert elapsed time (hh:mm:ss or mm:ss or <xxx>) to seconds as an integer
def et2seconds(x):
    if '<' in x:
        return np.nan    # np.nan is preferable to 'NaN', NaN, or 0
    else:
        if len(x) > 5:
            hours = int(x.split(':')[0])
            minutes = int(x.split(':')[1])
            seconds = int(x.split(':')[2])
            return seconds + minutes*60 + hours*60*60
        else:
            minutes = int(x.split(':')[0])
            seconds = int(x.split(':')[1])
            return seconds + minutes*60


# Extract division from Stuff field
def get_division(x):
    if 'Division' in x:
        return x.split('Division')[1].replace(' ','')[0]  # assumes returned value is a single character - will fail if div is not, 1, 2, 3, A, B, etc
    else:
        if 'Open, start' in x:
            return x.split(', start')[0]
        else:
            if 'Classics, start' in x:
                return x.split(', start')[0]
            else:
                return 'Combined'

# %%
# Take a quick look at a raw CSV file - need to select/deselect appropriate cols in CSV

infilename = 'id2 spring r2 results'

# Following list of colNums and colHdrs works fine on:
# - Divisional races
# - Winter series fully crewed
CSVcolNums = [1,3,5,7,9,28,29,30,31,32,35,41,45]
CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Stuff','Sail number','Boat design', \
              'Boat name','Elapsed time','TCF','PHRF','IRC']

q = input_csv(datapath + "Raw CSV data/", infilename + '.csv')
#q.head(5)
q

# Notes:
# - Edit '..\Handicapping\2013-14 season\Season summary (2013-14).xlsx'
# - Compare imported data with hard-copy printout from Yacht Systems
# - Make sure Elapsed time field begins with < if no time, e.g. <n/e>, <no entry>, <dnf>, <raf>, <osc>, <dns> etc
# - Check for duplicate boat names, i.e. incorrect spelling
# Out:
#                                          Race                      Date Wind direction Wind speed  ID                        Stuff Sail number    Boat design Elapsed time    TCF   PHRF    IRC
# Boat name
# Drinks Trolley            Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315        8737    Thompson 30        23:56  0.824  0.840  0.000
# Wedgetail                 Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315        9442    Welbourn 42        21:09  0.945  0.950  1.209
# Revs                      Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315        8234        Ross 12        22:26  0.894  0.885  1.234
# Magic Trick               Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315        9198       Shaw 650        22:48  0.891  0.875  0.000
# Nedax Racing              Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315        8985    Thompson 30        24:45  0.832  0.840  0.000
# Rocket Science            Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315       T4159    Thomson 750        25:28  0.830  0.820  0.000
# The Guarantee             Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315        8625     Ross 10.66        24:59  0.848  0.845  0.000
# Blink                     Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 1, start time 1315      110011        Shaw 12        23:05  0.950  0.980  0.000
# Blue Magic                Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        6716        Ross 35        26:50  0.739  0.735  0.955
# Incantare                 Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320         881       Young 88        28:17  0.708  0.725  0.000
# Whistler III              Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        5988       Young 88        27:28  0.730  0.725  0.950
# WiseGuy                   Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        6585       Young 88        29:14  0.706    NaN  0.000
# Wellington Spirit Red     Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        9004       Farr MRX        27:33  0.758  0.790  0.000
# Airship                   Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        4953        Ross930        27:49  0.754  0.735  0.000
# Gucci                     Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        6654      Warick 35        28:24  0.750  0.755  0.963
# Floating Free             Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        5903      Farr 1020        30:21  0.705    NaN  0.000
# Wellington Spirit Bronze  Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        9005       Farr MRX        28:14  0.763  0.790  0.000
# Prime Mover               Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        6804      Farr 1104        28:50  0.761  0.765  0.000
# Eat My Shorts             Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        5892      Farr 1020        30:05  0.742  0.745  0.000
# Montego Bay III           Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 2, start time 1320        5477        Simpson        34:27  0.719  0.745  0.000
# Titus Canby               Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 3, start time 1325        1505           Farr      3:33:39  0.689  0.690  0.000
# Revenue Cutter            Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 3, start time 1325        4845    Davidson 35      3:55:08  0.630    NaN  0.000
# Saucy Sausage             Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 3, start time 1325        3465    Stratus 474      3:56:48  0.626  0.630  0.000
# Haumuri                   Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 3, start time 1325        8949       Cropp 45      3:42:36  0.678  0.665  0.000
# White Cavalier            Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2  Division 3, start time 1325        3248    IOR 1/2 ton      < dnf >    NaN    NaN  0.000
# Lizzie                    Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2    Classics, start time 1330         114         Bailey      3:03:29  0.400    NaN  0.000
# Rona                      Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2    Classics, start time 1330           7  Logan A Class      2:36:36  0.580    NaN  0.000
# Loloma                    Sprng Series Race 2  Saturday, 5 October 2013              N       5-15   2    Classics, start time 1330          24        Classic      3:14:21  0.490    NaN  0.000

# %%
# Create a uniformly structured dataframe for the current race data

# Specify i for id, s for series name, r for race number and d for date - for the current set of results
i = "id3"      
s = "Spring"
r = "r3"
d = "5 Oct"

data = input_csv(datapath + "Raw CSV data/", infilename + '.csv')
data = data.replace(0.00,nan)
data['Seconds'] = data['Elapsed time'].map(lambda x: et2seconds(x))
data['Div']     = data['Stuff'].map(lambda x: get_division(x))
data['Details'] = i + ' ' + s + ' ' + r + ' ' + d
data['Race'] = s + ' ' + r

# Identify desired columns - in order.
cols = ['Div', 'Race', 'Details', 'Elapsed time', 'Seconds', 'TCF', 'PHRF', 'IRC']
#data.columns.tolist()

outfilename = 'All divs ' + s + ' ' + r
data[cols].to_csv(datapath + "Proc'd CSVs/" + outfilename + '.csv', sep = ',')

#data[cols].dtypes
#data[cols].sort(['Div','Seconds'])
data[cols]
# Out:
#                            Div       Race              Details Elapsed time  Seconds    TCF   PHRF    IRC
# Boat name
# Blink                        1  Spring r3  id3 Spring r3 5 Oct      2:03:09     7389  0.950  0.980    NaN
# Revs                         1  Spring r3  id3 Spring r3 5 Oct      2:11:36     7896  0.894  0.885  1.234
# Drinks Trolley               1  Spring r3  id3 Spring r3 5 Oct      2:25:46     8746  0.824  0.840    NaN
# Nedax Racing                 1  Spring r3  id3 Spring r3 5 Oct      2:24:24     8664  0.832  0.840    NaN
# Rocket Science               1  Spring r3  id3 Spring r3 5 Oct      2:25:00     8700  0.830  0.820    NaN
# Magic Trick                  1  Spring r3  id3 Spring r3 5 Oct      2:16:14     8174  0.891  0.875    NaN
# Wedgetail                    1  Spring r3  id3 Spring r3 5 Oct      2:09:28     7768  0.945  0.950  1.209
# The Guarantee                1  Spring r3  id3 Spring r3 5 Oct      2:26:02     8762  0.848  0.845    NaN
# WiseGuy                      2  Spring r3  id3 Spring r3 5 Oct      2:17:03     8223  0.706    NaN    NaN
# Wellington Spirit Red        2  Spring r3  id3 Spring r3 5 Oct      2:14:40     8080  0.758  0.790    NaN
# Blue Magic                   2  Spring r3  id3 Spring r3 5 Oct      2:18:14     8294  0.739  0.735  0.955
# Gucci                        2  Spring r3  id3 Spring r3 5 Oct      2:18:44     8324  0.750  0.755  0.963
# Eat My Shorts                2  Spring r3  id3 Spring r3 5 Oct      2:21:01     8461  0.742  0.745    NaN
# Airship                      2  Spring r3  id3 Spring r3 5 Oct      2:18:56     8336  0.754  0.735    NaN
# Incantare                    2  Spring r3  id3 Spring r3 5 Oct      2:28:57     8937  0.708  0.725    NaN
# Prime Mover                  2  Spring r3  id3 Spring r3 5 Oct      2:20:16     8416  0.761  0.765    NaN
# Whistler III                 2  Spring r3  id3 Spring r3 5 Oct      2:26:31     8791  0.730  0.725  0.950
# Wellington Spirit Bronze     2  Spring r3  id3 Spring r3 5 Oct      2:21:01     8461  0.763  0.790    NaN
# Montego Bay III              2  Spring r3  id3 Spring r3 5 Oct      2:34:37     9277  0.719  0.745    NaN
# St Laurence               Open  Spring r3  id3 Spring r3 5 Oct      2:08:27     7707  1.050    NaN    NaN

# %%
# Create a separate dataframe for each division and write it to a CSV file

# Edit f according to divisions present in col Div above.
#f = ['div1', 'div2', 'div3', 'divClassics','divOpen']
f = ['div1', 'div2', 'div3', 'divOpen']

for x in f:
    div = x.split('div')[1]
    outfilename = i + ' ' + x + ' ' + s + ' ' + r
    x = data[cols][data['Div'] == div]
    x.to_csv(datapath + "Proc'd CSVs/" + outfilename + '.csv', sep = ',')
    print '\n', div, '  ', outfilename
    print x
# Out:
# 1    id3 div1 Spring r3
#                Div       Race              Details Elapsed time  Seconds    TCF   PHRF    IRC
# Boat name
# Blink            1  Spring r3  id3 Spring r3 5 Oct      2:03:09     7389  0.950  0.980    NaN
# Revs             1  Spring r3  id3 Spring r3 5 Oct      2:11:36     7896  0.894  0.885  1.234
# Drinks Trolley   1  Spring r3  id3 Spring r3 5 Oct      2:25:46     8746  0.824  0.840    NaN
# Nedax Racing     1  Spring r3  id3 Spring r3 5 Oct      2:24:24     8664  0.832  0.840    NaN
# Rocket Science   1  Spring r3  id3 Spring r3 5 Oct      2:25:00     8700  0.830  0.820    NaN
# Magic Trick      1  Spring r3  id3 Spring r3 5 Oct      2:16:14     8174  0.891  0.875    NaN
# Wedgetail        1  Spring r3  id3 Spring r3 5 Oct      2:09:28     7768  0.945  0.950  1.209
# The Guarantee    1  Spring r3  id3 Spring r3 5 Oct      2:26:02     8762  0.848  0.845    NaN
#
# 2    id3 div2 Spring r3
#                          Div       Race              Details Elapsed time  Seconds    TCF   PHRF    IRC
# Boat name
# WiseGuy                    2  Spring r3  id3 Spring r3 5 Oct      2:17:03     8223  0.706    NaN    NaN
# Wellington Spirit Red      2  Spring r3  id3 Spring r3 5 Oct      2:14:40     8080  0.758  0.790    NaN
# Blue Magic                 2  Spring r3  id3 Spring r3 5 Oct      2:18:14     8294  0.739  0.735  0.955
# Gucci                      2  Spring r3  id3 Spring r3 5 Oct      2:18:44     8324  0.750  0.755  0.963
# Eat My Shorts              2  Spring r3  id3 Spring r3 5 Oct      2:21:01     8461  0.742  0.745    NaN
# Airship                    2  Spring r3  id3 Spring r3 5 Oct      2:18:56     8336  0.754  0.735    NaN
# Incantare                  2  Spring r3  id3 Spring r3 5 Oct      2:28:57     8937  0.708  0.725    NaN
# Prime Mover                2  Spring r3  id3 Spring r3 5 Oct      2:20:16     8416  0.761  0.765    NaN
# Whistler III               2  Spring r3  id3 Spring r3 5 Oct      2:26:31     8791  0.730  0.725  0.950
# Wellington Spirit Bronze   2  Spring r3  id3 Spring r3 5 Oct      2:21:01     8461  0.763  0.790    NaN
# Montego Bay III            2  Spring r3  id3 Spring r3 5 Oct      2:34:37     9277  0.719  0.745    NaN
#
# 3    id3 div3 Spring r3
# Empty DataFrame
# Columns: [Div, Race, Details, Elapsed time, Seconds, TCF, PHRF, IRC]
# Index: []
#
# Open    id3 divOpen Spring r3
#               Div       Race              Details Elapsed time  Seconds   TCF  PHRF  IRC
# Boat name
# St Laurence  Open  Spring r3  id3 Spring r3 5 Oct      2:08:27     7707  1.05   NaN  NaN

# %% [markdown]
# ##### Misc crap beyond this point

# %%
# Write out a file of boat details for boats that showed up to race

# Define outcome for boats that showed up
def outcome(x):
    if '<' in x:
        return x
    else:
        return 'Finished'
    

# See http://stackoverflow.com/questions/17002186/merging-multiple-unaligned-data-frames-into-single-pandas-data-frame
# The next line was replaced with the one that follows it because merging wouldn't work when all those cols existed in the dataframe
#boatcols = ['Boat design', 'Sail number']
boatcols = []
boatdata = data[boatcols]
boatdata[d] = data['Elapsed time'].map(lambda x: outcome(x))
boatdata.to_csv(datapath + "Boats/" + 'Boats out on ' + d + '.csv', sep = ',')
boatdata
# Out:
#                               28 Sep
# Boat name
# The Guarantee               Finished
# Revs                        Finished
# Whistler III                Finished
# Incantare                   Finished
# Airship                     Finished
# WiseGuy                     Finished
# Wellington Spirit Bronze    Finished
# Wellington Spirit Red       Finished
# Gucci                       Finished
# Cantilena                   Finished
# Titus Canby                 Finished
# Saucy Sausage               Finished
# Marangi                   <no entry>

# %%
#masterboatdata = pd.read_csv(datapath + "Boats/" + 'Boats out on 28 Sep.csv', index_col = [0,1,2], sep=',')
#newboatdata    = pd.read_csv(datapath + "Boats/" + 'Boats out on 5 Oct.csv', index_col = [0,1,2], sep=',')
masterboatdata = pd.read_csv(datapath + "Boats/" + 'Boats out on 28 Sep.csv', sep=',')
newboatdata    = pd.read_csv(datapath + "Boats/" + 'Boats out on 5 Oct.csv', usecols = [0,3], sep=',')


#oldboatdata = raw_data = pd.read_csv(datapath + "Boats/" + 'Boats out on 5 Oct.csv', sep=',')
#oldboatdata = oldboatdata.set_index('Boat name')
newboatdata
masterboatdata
# Out:
#                    Boat name      28 Sep
# 0              The Guarantee    Finished
# 1                       Revs    Finished
# 2               Whistler III    Finished
# 3                  Incantare    Finished
# 4                    Airship    Finished
# 5                    WiseGuy    Finished
# 6   Wellington Spirit Bronze    Finished
# 7      Wellington Spirit Red    Finished
# 8                      Gucci    Finished
# 9                  Cantilena    Finished
# 10               Titus Canby    Finished
# 11             Saucy Sausage    Finished
# 12                   Marangi  <no entry>

# %%
mergeboatdata = masterboatdata.merge(newboatdata, how = 'outer')
#mergeboatdata.set_index('Boat name')
mergeboatdata
#div3.to_csv('/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/' + 'Div3 2012-13.csv', sep = ',')
# Out:
#                    Boat name      28 Sep       5-Oct
# 0              The Guarantee    Finished    Finished
# 1                       Revs    Finished    Finished
# 2               Whistler III    Finished    Finished
# 3                  Incantare    Finished    Finished
# 4                    Airship    Finished    Finished
# 5                    WiseGuy    Finished    Finished
# 6   Wellington Spirit Bronze    Finished    Finished
# 7      Wellington Spirit Red    Finished    Finished
# 8                      Gucci    Finished    Finished
# 9                  Cantilena    Finished         NaN
# 10               Titus Canby    Finished         NaN
# 11             Saucy Sausage    Finished    Finished
# 12                   Marangi  <no entry>  <no entry>
# 13            Rocket Science         NaN    Finished

# %%
mergeboatdata.count()
# Out:
# Boat name    14
# 28 Sep       13
# 5-Oct        12
# dtype: int64
