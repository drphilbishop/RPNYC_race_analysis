# %% [markdown]
# #### Use this code to read a CSV file containing race results. Specify infilename, h, s, r, and d at the appropriate juncture. Be aware that the code
# may need to be edited/amended in certain circumstances - CSV file structure is different, more than
# one race per day, different race numbers for each division, etc.

# %%
#-------10--------20--------30--------40--------50--------60--------70--------80
import pandas as pd
import numpy as np
import datetime as dt
import functions as fn
#import matplotlib
import os
import re

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)
#pd.set_option('display.max_columns',10000)
#pd.set_option('display.max_rows',10000)
#pd.set_option('display.max_colwidth',10000)
#pd.set_option('display.max_info_columns',10000)
#pd.set_option('display.notebook_repr_html',True)
#pd.set_option('display.expand_frame_repr', True)

datapath = 'C:\\Phil\\My Dropbox\\Sailing cmte\\Handicapping\\2013-14 season\\'
#datapath = '/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/2013-14 season/'

# %%
# Take a quick look at a raw CSV file from Yacht Systems
# - need to select/deselect appropriate cols in CSV

infilename = 'IslandBayChamp2Nov'

# Following list of colNums and colHdrs works fine on:
# - Divisional races
# - Winter series fully crewed
#CSVcolNums = [1,3,5,7,9,28,29,30,31,32,35,37,41,45]
#CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Stuff','Sail number','Boat design', \
#              'Boat name','Elapsed time','TCFapplied','Rank','PHRF','IRC']

# Following list of colNums and colHdrs works fine on manually constructed CSVs for combined fleet races:
#CSVcolNums = [0,1,2,3,4,5]
#CSVcolHdrs = ['Boat name','Elapsed time','Rank','TCFapplied','PHRF','IRC']

# Following list of colNums and colHdrs works fine on manually constructed CSVs for divisional races:
CSVcolNums = [0,1,2,3,4,5,6,7]
CSVcolHdrs = ['Boat name','Race','Div','Elapsed time','RankAppld','TCFapplied','PHRF','IRC']

# Following list of colNums and colHdrs works fine on Island Bay races:
#CSVcolNums = [1,3,5,7,9,26,27,28,33,36,38,40,44]
#CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Sail number','Boat design', \
#              'Boat name','Elapsed time','TCFapplied','Rank','PHRF','IRC']

q = pd.read_csv(datapath+"Raw CSV data/"+infilename+'.csv', sep=',', header=None, usecols=CSVcolNums)
q.columns = CSVcolHdrs
#q.head(5)
q

# Read selected columns from raw CSV file and make boat name the index
#def input_csv(path,filename,CSVcolNums,CSVcolHdrs):
#    raw_data = pd.read_csv(path + filename, sep=',', header=None, usecols=CSVcolNums)
#    raw_data.columns = CSVcolHdrs
#    raw_data = raw_data.set_index('Boat name')
#    return raw_data



# Notes:
# - Edit '..\Handicapping\2013-14 season\Season summary (2013-14).xlsx'
# - Compare imported data with hard-copy printout from Yacht Systems
# - Make sure Elapsed time field begins with < if no time, e.g. <n/e>, <no entry>, <dnf>, <raf>, <osc>, <dns> etc
# - Check for duplicate boat names, i.e. incorrect spelling
# Out:
#           Boat name Race   Div Elapsed time  Rank  TCFapplied   PHRF    IRC
# 0       Magic Trick   r1     1      2:32:16     1       0.882  0.875    NaN
# 1             Blink   r1     1      2:23:00     2       0.944  0.980    NaN
# 2        Ran Tan II   r1     1      2:23:37     3       0.994  1.040    NaN
# 3    Drinks Trolley   r1     1      2:53:47     4       0.833  0.840    NaN
# 4              Revs   r1     1      2:40:52     5       0.899  0.885  1.234
# 5         Wedgetail   r1     1      2:33:40     6       0.945  0.950  1.209
# 6     The Guarantee   r1     1      2:56:41     7       0.836  0.845    NaN
# 7    Rocket Science   r1     1      3:02:12     8       0.816  0.820    NaN
# 8   Montego Bay III   r1     2      3:10:25     1       0.701  0.745    NaN
# 9     Floating Free   r1     2      3:21:28     2       0.702    NaN    NaN
# 10    Eat My Shorts   r1     2      3:16:10     3       0.732  0.745    NaN
# 11   After Midnight   r1     2      3:28:15     4       0.724  0.715    NaN
# 12       Blue Magic   r1     2      3:17:11     5       0.749  0.735  0.955
# 13          Wiseguy   r1     2      3:31:05     6       0.717    NaN    NaN
# 14      Prime Mover   r1     2      3:16:35     7       0.745  0.765  0.963
# 15            Gucci   r1     2      3:17:20     8       0.747  0.755  0.963
# 16     Whistler III   r1     2      3:28:36     9       0.736  0.725  0.950
# 17        Incantare   r1     2      3:34:11    10       0.713  0.725    NaN
# 18          Airship   r1     2      3:24:50    11       0.756  0.735    NaN
# 19          Charlie   r1     3      4:04:39     1       0.580    NaN    NaN
# 20        Rosschild   r1     3      3:49:24     2       0.635  0.680    NaN
# 21          Maranui   r1     3      4:22:32     3       0.550    NaN    NaN
# 22   White Cavalier   r1     3      4:17:30     4       0.568    NaN    NaN
# 23    Saucy Sausage   r1     3      3:58:33     5       0.629  0.630    NaN
# 24      Titus Canby   r1     3      3:41:32     6       0.691  0.690    NaN
# 25      St Laurence   r1  Open      2:45:12     1       1.034    NaN    NaN

# %%
# Create a uniformly structured dataframe for the current race data

# Specify h for handicap type, s for series name (see p84 Almanac),
# r for race number and d for date - for the current set of results
h = "Championship"
s = "Island Bay"
r = "r1"
d = "2/11/2013"

data = pd.read_csv(datapath+"Raw CSV data/"+infilename+'.csv', sep=',', header=None, usecols=CSVcolNums)
data.columns = CSVcolHdrs
data = data.replace(0.00,nan)

data['Date'] = d
data['Handicap'] = h
data['Series'] = s
data['Race'] = r
#data['Div']  = 'Combined'
#data['Div'] = data['Stuff'].map(lambda x: fn.get_division(x))
data['ETsecs'] = data['Elapsed time'].map(lambda x: fn.et2seconds(x))

# Overwrite some records...
#data['Race'][data['Div']=='3'] = 'r3'
#data['Race'][data['Div']=='Open'] = 'r2'
#data['Handicap'][data['Div']=='Classics'] = 'Classics'
#data['Series'][data['Div']=='Classics'] = 'Classics'
#data['Race'][data['Div']=='Classics'] = 'r1'
#data['Div'][data['Div']=='Classics'] = 'Combined'
#data.ix[['Lizzie','Loloma'],'Series'] = 'Classics'
#data.ix[['Lizzie','Loloma'],'Race'] = 'r2'

# Identify desired columns - in order.
cols = ['Date','Handicap','Series','Race','Div','Boat name','Elapsed time','ETsecs','RankAppld','TCFapplied','PHRF','IRC']
#data.columns.tolist()

outfilename = infilename
data[cols].to_csv(datapath+"Proc'd CSVs/"+outfilename+'.csv', sep = ',')
data[cols]
# Out:
#          Date      Handicap      Series Race   Div        Boat name Elapsed time  ETsecs  Rank  TCFapplied   PHRF    IRC
# 0   2/11/2013  Championship  Island Bay   r1     1      Magic Trick      2:32:16    9136     1       0.882  0.875    NaN
# 1   2/11/2013  Championship  Island Bay   r1     1            Blink      2:23:00    8580     2       0.944  0.980    NaN
# 2   2/11/2013  Championship  Island Bay   r1     1       Ran Tan II      2:23:37    8617     3       0.994  1.040    NaN
# 3   2/11/2013  Championship  Island Bay   r1     1   Drinks Trolley      2:53:47   10427     4       0.833  0.840    NaN
# 4   2/11/2013  Championship  Island Bay   r1     1             Revs      2:40:52    9652     5       0.899  0.885  1.234
# 5   2/11/2013  Championship  Island Bay   r1     1        Wedgetail      2:33:40    9220     6       0.945  0.950  1.209
# 6   2/11/2013  Championship  Island Bay   r1     1    The Guarantee      2:56:41   10601     7       0.836  0.845    NaN
# 7   2/11/2013  Championship  Island Bay   r1     1   Rocket Science      3:02:12   10932     8       0.816  0.820    NaN
# 8   2/11/2013  Championship  Island Bay   r1     2  Montego Bay III      3:10:25   11425     1       0.701  0.745    NaN
# 9   2/11/2013  Championship  Island Bay   r1     2    Floating Free      3:21:28   12088     2       0.702    NaN    NaN
# 10  2/11/2013  Championship  Island Bay   r1     2    Eat My Shorts      3:16:10   11770     3       0.732  0.745    NaN
# 11  2/11/2013  Championship  Island Bay   r1     2   After Midnight      3:28:15   12495     4       0.724  0.715    NaN
# 12  2/11/2013  Championship  Island Bay   r1     2       Blue Magic      3:17:11   11831     5       0.749  0.735  0.955
# 13  2/11/2013  Championship  Island Bay   r1     2          Wiseguy      3:31:05   12665     6       0.717    NaN    NaN
# 14  2/11/2013  Championship  Island Bay   r1     2      Prime Mover      3:16:35   11795     7       0.745  0.765  0.963
# 15  2/11/2013  Championship  Island Bay   r1     2            Gucci      3:17:20   11840     8       0.747  0.755  0.963
# 16  2/11/2013  Championship  Island Bay   r1     2     Whistler III      3:28:36   12516     9       0.736  0.725  0.950
# 17  2/11/2013  Championship  Island Bay   r1     2        Incantare      3:34:11   12851    10       0.713  0.725    NaN
# 18  2/11/2013  Championship  Island Bay   r1     2          Airship      3:24:50   12290    11       0.756  0.735    NaN
# 19  2/11/2013  Championship  Island Bay   r1     3          Charlie      4:04:39   14679     1       0.580    NaN    NaN
# 20  2/11/2013  Championship  Island Bay   r1     3        Rosschild      3:49:24   13764     2       0.635  0.680    NaN
# 21  2/11/2013  Championship  Island Bay   r1     3          Maranui      4:22:32   15752     3       0.550    NaN    NaN
# 22  2/11/2013  Championship  Island Bay   r1     3   White Cavalier      4:17:30   15450     4       0.568    NaN    NaN
# 23  2/11/2013  Championship  Island Bay   r1     3    Saucy Sausage      3:58:33   14313     5       0.629  0.630    NaN
# 24  2/11/2013  Championship  Island Bay   r1     3      Titus Canby      3:41:32   13292     6       0.691  0.690    NaN
# 25  2/11/2013  Championship  Island Bay   r1  Open      St Laurence      2:45:12    9912     1       1.034    NaN    NaN
