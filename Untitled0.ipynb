# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib
#import EAtools as ea
import os
import re

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)
pd.set_option('display.multi_sparse', True)

data1 = pd.read_csv('Test data\\race1.csv', sep=',',index_col=[0,1,2])
#data1.set_index('Boat name')
data2 = pd.read_csv('Test data\\race2.csv', sep=',',index_col=[0,1,2])
data = data1.append(data2)
#data.set_index(['Boat name','Details','Div'])
data.sort()
#data.sort(['Boat name ','Div'])
# Out:
#                                                   Elapsed time  Seconds    TCF   PHRF    IRC
# Boat name                Details              Div
# Airship                  id1 spring r1 28 Sep 2        2:25:28     8728  0.743  0.735    NaN
#                          id2 spring r2 5 Oct  2        2:25:28     8728  0.743  0.735    NaN
# Cantilena                id1 spring r1 28 Sep 3        2:03:17     7397  0.633    NaN    NaN
#                          id2 spring r2 5 Oct  3        2:03:17     7397  0.633    NaN    NaN
# Gucci                    id1 spring r1 28 Sep 2        2:38:16     9496  0.762  0.755  0.963
#                          id2 spring r2 5 Oct  2        2:38:16     9496  0.762  0.755  0.963
# Incantare                id1 spring r1 28 Sep 2        2:34:37     9277  0.697  0.725    NaN
#                          id2 spring r2 5 Oct  2        2:34:37     9277  0.697  0.725    NaN
# ...

# %%
data['TCF'].plot()
