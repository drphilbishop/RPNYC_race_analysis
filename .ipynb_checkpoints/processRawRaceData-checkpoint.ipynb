# %% [markdown]
# #### Use this code to read a CSV file containing race results. Specify infilename, h, s, r, and d at the appropriate juncture. Be aware that the code
# may need to be edited/amended in certain circumstances - CSV file structure is different, more than
# one race per day, different race numbers for each division, etc.

# %%
#-------10--------20--------30--------40--------50--------60--------70--------80
import pandas as pd
import numpy as np
import datetime as dt
import functions as fn
#import matplotlib
import os
import re

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)
#pd.set_option('display.max_columns',10000)
#pd.set_option('display.max_rows',10000)
#pd.set_option('display.max_colwidth',10000)
#pd.set_option('display.max_info_columns',10000)
#pd.set_option('display.notebook_repr_html',True)
#pd.set_option('display.expand_frame_repr', True)

windows = 'C:\\Phil\\My Dropbox'
mac = '/Users/PhilBishop/Dropbox'
datapath = os.path.join(windows, 'Sailing cmte', 'Handicapping', '2013-14 season')
datapath
# Out:
# 'C:\\Phil\\My Dropbox\\Sailing cmte\\Handicapping\\2013-14 season'

# %%
# Take a quick look at a raw CSV file from Yacht Systems
# - need to select/deselect appropriate cols in CSV

infilename = 'Winter27Jul'

# Following list of colNums and colHdrs works fine on:
# - Divisional races
# - Winter series fully crewed
#CSVcolNums = [1,3,5,7,9,28,29,30,31,32,35,37,41,45]
#CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Stuff','Sail number','Boat design', \
#              'Boat name','Elapsed time','TCFapplied','Rank','PHRF','IRC']

# Following list of colNums and colHdrs works fine on manually constructed CSVs for combined fleet races:
# (incl rum races if  commas are added for fake PHRF and IRC columns.
#CSVcolNums = [0,1,2,3,4,5]
#CSVcolHdrs = ['Boat name','Elapsed time','RankAppld','TCFapplied','PHRF','IRC']

# Following list of colNums and colHdrs works fine on manually constructed CSVs for divisional races:
CSVcolNums = [0,1,2,3,4,5,6,7]
CSVcolHdrs = ['Boat name','Race','Div','Elapsed time','TCFapplied','RankAppld','PHRF','IRC']
#CSVcolNums = [0,1,2,3,4,5]
#CSVcolHdrs = ['Boat name','Race','Elapsed time','TCFapplied','RankAppld']
#CSVcolHdrs = ['Boat name','Race','Elapsed time','PHRF','RankAppld']

# Following list of colNums and colHdrs works fine on Island Bay races:
#CSVcolNums = [1,3,5,7,9,26,27,28,33,36,38,40,44]
#CSVcolHdrs = ['Race','Date','Wind direction','Wind speed','ID','Sail number','Boat design', \
#              'Boat name','Elapsed time','TCFapplied','Rank','PHRF','IRC']

q = pd.read_csv(datapath+"/Raw CSV data/"+infilename+'.csv', sep=',', header=None, usecols=CSVcolNums)
q.columns = CSVcolHdrs
#q.tail(5)
q

# Read selected columns from raw CSV file and make boat name the index
#def input_csv(path,filename,CSVcolNums,CSVcolHdrs):
#    raw_data = pd.read_csv(path + filename, sep=',', header=None, usecols=CSVcolNums)
#    raw_data.columns = CSVcolHdrs
#    raw_data = raw_data.set_index('Boat name')
#    return raw_data



# Notes:
# - Edit '..\Handicapping\2013-14 season\Season summary (2013-14).xlsx'
# - Compare imported data with hard-copy printout from Yacht Systems
# - Make sure Elapsed time field begins with < if no time, e.g. <n/e>, <no entry>, <dnf>, <raf>, <osc>, <dns> etc
# - Check for duplicate boat names, i.e. incorrect spelling
# Out:
#                         Boat name Race Div Elapsed time  TCFapplied  RankAppld   PHRF    IRC
# 0                            Revs   r4   A      1:19:24       0.895          1  0.900    NaN
# 1                   The Guarantee   r4   A      1:25:17       0.845          2  0.840    NaN
# 2                  Rocket Science   r4   A      1:32:03       0.801          3  0.820    NaN
# 3                  Drinks Trolley   r4   A      1:29:01       0.834          4  0.840    NaN
# 4                       Wedgetail   r4   A      1:17:18       0.962          5  0.945  1.209
# 5                     Badonkadonk   r4   A        <dnf>         NaN        NaN    NaN    NaN
# 6                     Magic Trick   r4   A        <dnf>         NaN        NaN    NaN    NaN
# 7                   Floating Free   r4   B      1:04:38       0.703          1    NaN    NaN
# 8                           Gucci   r4   B      1:01:42       0.744          2  0.745  0.963
# 9           Wellington Spirit Red   r4   B      1:00:43       0.769          3    NaN    NaN
# 10                  Eat My Shorts   r4   B      1:04:15       0.729          4  0.740    NaN
# 11                   Liquid Asset   r4   B      1:10:41       0.665          5    NaN    NaN
# 12                 Winter Program   r4   B      1:08:24       0.688          6    NaN    NaN
# 13                     Testarossa   r4   B      1:00:31       0.783          7  0.772    NaN
# 14                        Wiseguy   r4   B      1:09:27       0.684          8    NaN    NaN
# 15                 Stepping Stone   r4   B      1:04:11       0.742          9    NaN    NaN
# 16                 After Midnight   r4   B      1:06:24       0.720         10  0.725    NaN
# 17                    Titus Canby   r4   B      1:10:42       0.678         11  0.690    NaN
# 18                  Saucy Sausage   r4   B      1:16:32       0.629         12  0.635    NaN
# 19  Keith Taylor Charitable Trust   r4   B      1:09:06       0.700         13    NaN    NaN
# 20                  Partners Life   r4   B      1:09:40       0.700         14    NaN    NaN
# 21                        Charlie   r4   B      1:23:46       0.583         15    NaN    NaN
# 22                Montego Bay III   r4   B      1:09:44       0.703         16    NaN    NaN
# 23                      Incantare   r4   B      1:09:43       0.703         17  0.725    NaN
# 24                            Aon   r4   B      1:10:48       0.695         18    NaN    NaN
# 25                   Whistler III   r4   B      1:08:42       0.721         19  0.740  0.950
# 26                      Illusions   r4   B      1:15:34       0.660         20  0.670    NaN
# 27                  Black Diamond   r4   B      1:02:44       0.808         21  0.800  1.006
# 28                        Am Meer   r4   B      1:10:10       0.728         22  0.730    NaN
# 29                       Marishka   r4   B      1:22:38       0.618         23  0.650    NaN
# 30                      Rosschild   r4   B      1:22:20       0.621         24  0.680    NaN
# 31       Wellington Spirit Bronze   r4   B      1:11:58       0.733         25    NaN    NaN

# %%
# Create a uniformly structured dataframe for the current race data

# Specify h for handicap type, s for series name (see p84 Almanac),
# r for race number and d for date - for the current set of results
h = "Fleet"
s = "Winter"
r = ""
d = "27/07/2014"

data = pd.read_csv(datapath+"/Raw CSV data/"+infilename+'.csv', sep=',', header=None, usecols=CSVcolNums)
data.columns = CSVcolHdrs
data = data.replace(0.00,nan)

data['Date'] = d
data['Handicap'] = h
data['Series'] = s
#data['Race'] = r
#data['Div']  = 'Combined'
data['resetTCF'] = 0      # 1 to reset TCF, 0 otherwise
data['TCFalgo'] = 1       # 1 for method E
data['Scoring'] = 1       # 1 for TCF, 2 for PHRF, 3 for IRC
#data['TCFapplied']  = 'NaN'
#data['PHRF'] = data['TCFapplied']
#data['TCFapplied']  = 'NaN'
#data['IRC']  = 'NaN'
#data['Div'] = data['Stuff'].map(lambda x: fn.get_division(x))
data['ETsecs'] = data['Elapsed time'].map(lambda x: fn.et2seconds(x))

# Overwrite some records...
#data['Race'][data['Div']=='3'] = 'r3'
#data['Race'][data['Div']=='Open'] = 'r2'
#data['Handicap'][data['Div']=='Classics'] = 'Classics'
#data['Series'][data['Div']=='Classics'] = 'Classics'
#data['Race'][data['Div']=='Classics'] = 'r5'
#data['Div'][data['Div']=='Classics'] = 'Combined'
#data.ix[['21','22','23'],'Series'] = 'Classics'
#data.ix[['Lizzie','Loloma','Rona'],'Div'] = 'Combined'
#data.ix[['Lizzie','Loloma'],'Race'] = 'r2'

# Identify desired columns - in order.
cols = ['Date','Handicap','Series','Race','Div','Boat name','resetTCF','TCFalgo','Scoring', \
        'Elapsed time','ETsecs','RankAppld','TCFapplied','PHRF','IRC']
#data.columns.tolist()

outfilename = infilename
data[cols].to_csv(datapath+"/Proc'd CSVs/"+outfilename+'.csv', sep = ',',index = False)
data[cols]
# Out:
#           Date Handicap  Series Race Div                      Boat name  resetTCF  TCFalgo  Scoring Elapsed time  ETsecs  RankAppld  TCFapplied   PHRF    IRC
# 0   27/07/2014    Fleet  Winter   r4   A                           Revs         0        1        1      1:19:24    4764          1       0.895  0.900    NaN
# 1   27/07/2014    Fleet  Winter   r4   A                  The Guarantee         0        1        1      1:25:17    5117          2       0.845  0.840    NaN
# 2   27/07/2014    Fleet  Winter   r4   A                 Rocket Science         0        1        1      1:32:03    5523          3       0.801  0.820    NaN
# 3   27/07/2014    Fleet  Winter   r4   A                 Drinks Trolley         0        1        1      1:29:01    5341          4       0.834  0.840    NaN
# 4   27/07/2014    Fleet  Winter   r4   A                      Wedgetail         0        1        1      1:17:18    4638          5       0.962  0.945  1.209
# 5   27/07/2014    Fleet  Winter   r4   A                    Badonkadonk         0        1        1        <dnf>     NaN        NaN         NaN    NaN    NaN
# 6   27/07/2014    Fleet  Winter   r4   A                    Magic Trick         0        1        1        <dnf>     NaN        NaN         NaN    NaN    NaN
# 7   27/07/2014    Fleet  Winter   r4   B                  Floating Free         0        1        1      1:04:38    3878          1       0.703    NaN    NaN
# 8   27/07/2014    Fleet  Winter   r4   B                          Gucci         0        1        1      1:01:42    3702          2       0.744  0.745  0.963
