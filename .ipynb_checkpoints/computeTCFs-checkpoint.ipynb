# %% [markdown]
# ### computeTCFs - code to read in a CSV file of RPNYC race results and apply the TCF updating procedure.

# %%
# Assign parameter values required by the TCF update formula
numSeeds = 2.
numFinished = 4.
pctFinished = 0.5
numPastPerfs = 4.
loClamp = .03
upClamp = .03    

inputDataFile = 'All_results2014-15.csv'
ostype = 'win'  # Enter mac or win

import pandas as pd
import datetime as dt
from functions import *
import os

pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.width',10000)
pd.set_option('display.max_columns',10000)
pd.set_option('display.max_rows',10000)
pd.set_option('display.max_colwidth',10000)
pd.set_option('display.max_info_columns',10000)
pd.set_option('display.max_seq_items',100)
pd.set_option('display.multi_sparse', True)

if ostype == 'win':
    dataPathAndFile = os.getcwd() + '\\Data\\' + inputDataFile
else:
    dataPathAndFile = os.getcwd() + '/Data/' + inputDataFile

print dataPathAndFile
# Out:
# C:\Users\bishopp\Dropbox\Python\Sailing\Data\All_results2014-15_withStLinOpen.csv

# %%
# Read the input data file
df = Read_CSV(dataPathAndFile)

# Initialise dicts to be keyed by a boatname-handicap tuple
newTCFvalue = {}                # dict for storing newTCF
TCFclampHistoryAndSeeds = {}    # dict for storing seeded and clamped TCFs
currentAlgo = {}                # dict for storing current scoring algorithm type

# Loop through every row in the transposed dataframe and establish keyed lists (avoids KeyError)
for index,row in df.T.iteritems():
    # Create a set of unique keys for boat-handicap tuples    
    key = row['Boat name'], row['Handicap']    
    # Create three empty lists indexed on key
    newTCFvalue[key] = []   
    TCFclampHistoryAndSeeds[key] = []
    currentAlgo[key] = []    

# Index the input data by date, handicap, series, race, and div, then sort it
df = df.set_index(['Date','Handicap','Series','Race','Div']).sort()

# Establish a new dataframe for collecting up TCF updates
dfTCF = pd.DataFrame()

df.head(50)
# Out:
#                                                              Boat name  resetTCF  TCFalgo  Scoring Start  Finish Elapsed time  ETsecs  RankAppld  TCFapplied   PHRF    IRC
# Date       Handicap     Series  Race         Div
# 2014-09-20 Fleet        Special Ambassador's Combined          Airship         0        2        1  1315  140333      0:48:33    2913          1       0.734  0.753    NaN
#                                              Combined   Helter Skelter         0        2        1  1315  135904      0:44:04    2644          2       0.840    NaN    NaN
#                                              Combined        Rosschild         0        2        1  1315  141642      1:01:42    3702          3       0.611  0.680    NaN
#                                              Combined          Haumuri         0        2        1  1315  141311      0:58:11    3491          4       0.649  0.665    NaN
#                                              Combined       Testarossa         0        2        1  1315  140312      0:48:12    2892          5       0.790  0.772    NaN
#                                              Combined            Gucci         0        2        1  1315  140553      0:50:53    3053          6       0.751  0.745  0.963
#                                              Combined          Wiseguy         0        2        1  1315  141022      0:55:22    3322          7       0.691  0.725    NaN
#                                              Combined          Charlie         0        2        1  1315  142042      1:05:42    3942          8       0.586    NaN    NaN
#                                              Combined        Illusions         0        2        1  1315  141337      0:58:37    3517          9       0.657  0.670    NaN
#                                              Combined   After Midnight         0        2        1  1315  140855      0:53:55    3235         10       0.721  0.725    NaN
#                                              Combined    Eat My Shorts         0        2        1  1315  140747      0:52:47    3167         11       0.739  0.740    NaN
#                                              Combined        Wedgetail         0        2        1  1315  145535      0:40:35    2435         12       0.962  0.945  1.209
#                                              Combined   White Cavalier         0        2        1  1315  142510      1:10:10    4210         13       0.561  0.650    NaN
#                                              Combined    The Guarantee         0        2        1  1315  140216      0:47:16    2836         14       0.856  0.840    NaN
#                                              Combined               CU         0        2        1  1315  140617      0:51:17    3077         15       0.790    NaN    NaN
#                                              Combined      Titus Canby         0        2        1  1315  141405      0:59:05    3545         16       0.688  0.690    NaN
#                                              Combined        Wai Aniwa         0        2        1  1315  141720      1:02:20    3740         17       0.660  0.690    NaN
#                                              Combined      Prime Mover         0        2        1  1315  141044      0:55:44    3344         18       0.746  0.762  0.964
#                                              Combined  Young Nicholson         0        2        1  1315  140616      0:51:16    3076         19       0.820    NaN    NaN
#                                              Combined            Blink         0        2        1  1315  140114      0:46:14    2774         20       0.938  0.960    NaN
#                                              Combined             Revs         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN
#                                              Combined         Marishka         0        2        1   NaN     NaN   <no entry>     NaN        NaN         NaN    NaN    NaN
# 2014-09-27 Championship Spring  r1           1               Wedgetail         0        2        1  1315  152034      2:05:34    7534          1       0.954  0.945  1.209
#                                              1           The Guarantee         0        2        1  1315  155134      2:36:34    9394          2       0.829  0.840    NaN
#                                              1          Helter Skelter         0        2        1  1315  154902      2:34:02    9242          3       0.845    NaN    NaN
#                                              1             Magic Trick         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN
#                                              1                    Revs         0        2        1   NaN     NaN        <dnf>     NaN        NaN         NaN    NaN    NaN
#                                              1                   Blink         0        2        1   NaN     NaN        <ocs>     NaN        NaN         NaN    NaN    NaN
#                                              2             Prime Mover         0        2        1  1320       1      2:13:03    7983          1       0.755  0.762  0.964
#                                              2           Eat My Shorts         0        2        1  1320       1      2:21:22    8482          2       0.726  0.740    NaN
#                                              2         Montego Bay III         0        2        1  1320       1      2:27:00    8820          3       0.700    NaN    NaN
#                                              2              Testarossa         0        2        1  1320       1      2:14:04    8044          4       0.775  0.772    NaN
#                                              2            Whistler III         0        2        1  1320       1      2:21:48    8508          5       0.743  0.740  0.950
#                                              2                 Wiseguy         0        2        1  1320       1      2:32:54    9174          6       0.694  0.725    NaN
#                                              2                   Gucci         0        2        1  1320       1      2:19:48    8388          7       0.764  0.745  0.963
#                                              2          After Midnight         0        2        1  1320       1      2:28:59    8939          8       0.723  0.725    NaN
#                                              2           Floating Free         0        2        1  1320       1      2:33:15    9195          9       0.710    NaN    NaN
#                                              2                 Airship         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN
#                                              2                    Brix         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN
#                                              2                      CU         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN
#                                              3          White Cavalier         0        2        1  1325  160436      2:39:36    9576          1       0.555  0.650    NaN
#                                              3           Saucy Sausage         0        2        1  1325  154955      2:24:55    8695          2       0.627  0.635    NaN
#                                              3                 Maranui         0        2        1  1325  161215      2:47:15   10035          3       0.548    NaN    NaN
#                                              3             Titus Canby         0        2        1  1325  154334      2:18:34    8314          4       0.677  0.690    NaN
#                                              3               Wai Aniwa         0        2        1  1325  154534      2:20:34    8434          5       0.672  0.690    NaN
#                                              3                Marishka         0        2        1  1325  160638      2:41:38    9698          6       0.609  0.650    NaN
#                                              3               Rosschild         0        2        1  1325  160252      2:37:52    9472          7       0.632  0.680    NaN
#                                              3                 Haumuri         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN
#                                              3               Illusions         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN
#                                              3          Revenue Cutter         0        2        1   NaN     NaN        <dnc>     NaN        NaN         NaN    NaN    NaN

# %%
# Iterate through the input data file (df) on each unique index value, i.e. date-handicap-
# series-race-div. At each iterate, apply the various functions and collect results into a
# dataframe called 'results'.
for index, results in df.groupby(level=(0,1,2,3,4)):   
    
    key = index[1]    
        
    # Compute TCFactual (what the TCF should've been on the day)
    results['TCFactual'] = results.apply(TCFactual,axis=1,indexKey=key,newTCFvalue=newTCFvalue)
    
    # Compute corrected time using TCFactual (1), PHRF (2) or IRC (3) - depends on value of Scoring
    results['corrSecs'] = results.apply(corrSecs,axis=1)
        
    # Compute rank based on corrected time and compare with rank applied on the day
    results['Rank'] = results['corrSecs'].rank(ascending=True)  
    results['rankDiff'] = results.apply(rankDiff,axis=1)
    
    # Compute PHRF and IRC rankings    
    scoring = results.Scoring.unique()[0]  # Get the unique scoring method for this race (either 1, 2, or 3)
    if scoring == 1 or scoring == 2:
        results['PHRF x ETsecs'] = results['PHRF'] * results['ETsecs']
        results['rankPHRF'] = results['PHRF x ETsecs'].rank(ascending=True)
    if scoring == 1 or scoring == 3:
        results['IRC x ETsecs'] = results['IRC'] * results['ETsecs'] 
        results['rankIRC'] = results['IRC x ETsecs'].rank(ascending=True)

    # Figure out the reference boat and reference time
    results['refTime'] = results.groupby(level=(0,1,2,3,4)).apply(ref_boat)
    
    # Replace reftime value with nan for boats that do not race 
    results['refTime'] = results.apply(adjustRefTime,axis=1)                
        
    # Compute TCFst, pctMvmt, TCFclmp
    results['TCFst']   = results.apply(TCFst,axis=1)
    results['pctMvmt'] = results.apply(pctMvmt,axis=1)
    results['TCFclmp'] = results.apply(lambda x: TCFclmp(x,loClamp=loClamp,upClamp=upClamp),axis=1)
    
    # Check if there is a change of scoring algorithm 
    results.apply(checkNewScoringAlgorithms, axis=1, race=results, indexKey=key, currentAlgo=currentAlgo)
    
    # If history of clamped TCFs is empty (coz boat has done no races or scoring algorithm has changed),
    # add seed values; otherwise add TCFclmp
    results.apply(updateTCFclampAndSeed,axis=1,race=results,indexKey=key,TCFclampHistoryAndSeeds=TCFclampHistoryAndSeeds)  
        
    # Compute newTCF        
    results['newTCF'] = results.apply(newTCF,axis=1,race=results,indexKey=key,TCFclampHistoryAndSeeds=TCFclampHistoryAndSeeds, \
                                      newTCFvalue=newTCFvalue)
    
    # Compute the difference between TCFapplied and TCFactual
    results['TCFdiff'] = results.apply(TCFdiff,axis=1)

    # If rank is NaN then fill with 0
    results['Rank'].fillna(0, inplace=True) # Only need fillna in a rank column when 0 finishes
    
    # Sort race by the appropriate column (ascending)
    if scoring == 1:        
        results = results.set_index(['Rank'],append=True).sort()
    elif scoring == 2:
        results['Rank'] = np.nan
        results = results.set_index(['rankPHRF'],append=True).sort()
    elif scoring == 3:
        results['Rank'] = np.nan
        results = results.set_index(['rankIRC'],append=True).sort()

    # Reset the index after sorting
    results = results.reset_index()

    # Now, append the race dataframe to the dfTCF dataframe
    dfTCF = dfTCF.append(results)

# %%
# Set column order for dfTCF
cols=['Boat name','resetTCF','TCFalgo','Scoring','Elapsed time','ETsecs','corrSecs','refTime','RankAppld','Rank','rankDiff', \
      'PHRF','rankPHRF','IRC','rankIRC','TCFapplied','TCFactual','TCFdiff','TCFst','pctMvmt','TCFclmp','newTCF']
    
# Reindex dfTCF, sorting by index
dfTCF = dfTCF.set_index(['Date','Handicap','Series','Race','Div']).reindex(columns=cols).sort().reset_index()

# Reset index, apply date-to-string conversion to get short month format, and then reindex without sorting
dfTCF.reset_index(inplace=True)
dfTCF['Date'] = dfTCF['Date'].map(lambda x: str(x.day) + ' ' + dt.datetime.strftime(x,'%b'))
dfTCF = dfTCF.set_index(['Date','Handicap','Series','Race','Div']).reindex(columns=cols)

dfTCF.head()
# Out:
#                                                     Boat name  resetTCF  TCFalgo  Scoring Elapsed time  ETsecs  corrSecs  refTime  RankAppld  Rank rankDiff   PHRF  rankPHRF  IRC  rankIRC  TCFapplied  TCFactual  TCFdiff  TCFst  pctMvmt TCFclmp  newTCF
# Date   Handicap Series  Race         Div
# 20 Sep Fleet    Special Ambassador's Combined            Revs         0        2        1        <dnc>     NaN       NaN      NaN        NaN     0      NaN    NaN       NaN  NaN      NaN         NaN        NaN      NaN    NaN      NaN     NaN     NaN
#                                      Combined        Marishka         0        2        1   <no entry>     NaN       NaN      NaN        NaN     0      NaN    NaN       NaN  NaN      NaN         NaN        NaN      NaN    NaN      NaN     NaN     NaN
#                                      Combined         Airship         0        2        1      0:48:33    2913      2138     2332          1     1        -  0.753         1  NaN      NaN       0.734      0.734        0  0.801     9.13   0.756   0.741
#                                      Combined  Helter Skelter         0        2        1      0:44:04    2644      2220     2332          2     2        -    NaN       NaN  NaN      NaN       0.840      0.840        0  0.882     5.00   0.865   0.847
#                                      Combined       Rosschild         0        2        1      1:01:42    3702      2261     2332          3     3        -  0.680        12  NaN      NaN       0.611      0.611        0  0.630     3.11   0.629   0.616

# %%
# Save new dataframe to csv
dfTCF[cols].to_csv('AllTCFs.csv', sep = ',')

# %%
# Extract the most recently updated or used TCF/PHRF/IRC for each boat by handicap
lastTCF_df = pd.DataFrame()
dfTCF = dfTCF.reset_index()

for index, df in dfTCF.groupby(['Handicap','Boat name']):    
    df = df.dropna(subset=['newTCF']).tail(1)    
    df = df[['Date','Handicap','Boat name','newTCF','PHRF','IRC']]    
    lastTCF_df = lastTCF_df.append(df.reset_index(drop=True))      
lastTCF_df.reset_index(drop=True,inplace=True)

lastTCF_df.to_csv('MostRecentTCFs.csv', sep = ',')
lastTCF_df.head(12)
# Out:
#       Date          Handicap        Boat name  newTCF   PHRF    IRC
# 0   14 Mar  Central Triangle            Blink   1.014  1.022  1.362
# 1   14 Mar  Central Triangle         Crusader   1.014  1.022  1.371
# 2   14 Mar  Central Triangle            Gucci   0.748  0.758  0.963
# 3   14 Mar  Central Triangle      Jive Talkin   0.860  0.870    NaN
# 4   14 Mar  Central Triangle  Montego Bay III   0.741  0.761    NaN
# 5   14 Mar  Central Triangle             Revs   0.863  0.895    NaN
# 6   14 Mar  Central Triangle    Satellite Spy   0.887  0.892    NaN
# 7   28 Mar      Championship   After Midnight   0.734  0.725    NaN
# 8   28 Mar      Championship          Airship   0.760  0.753  1.031
# 9   11 Oct      Championship      Badonkadonk   0.837  0.865    NaN
# 10  28 Mar      Championship            Blink   0.964  0.960  1.362
# 11  28 Feb      Championship    Blurred Image   0.681    NaN    NaN

# %%
# Show history of seeds and clamped TCFs for all boats and handicap types
TCFclampHistoryAndSeeds
# Out:
# {('After Midnight', 'Championship'): [0.723,
#   0.723,
#   0.707,
#   0.707,
#   0.735,
#   0.741,
#   0.74,
#   0.732,
#   0.733,
#   0.721,
#   0.745,
#   0.744,
#   0.758,
#   0.744,
#   0.728,
#   0.746,
#   0.721,
#   0.738],
#  ('After Midnight', 'Fleet'): [0.721,
#   0.721,
#   0.721,
#   0.701,
#   0.736,
#   0.711,
#   0.712,
#   0.695,
#   0.698,
#   0.727,
#   0.729,
#   0.708,
#   0.714,
#   0.731,
#   0.713],
#  ('After Midnight', 'PNR'): [0.745,
#   0.745,
#   0.73,
#   0.741,
#   0.718,
#   0.711,
#   0.703,
#   0.724,
#   0.717,
#   0.734],
#  ('After Midnight', 'PNR_asPublished'): [0.745,
#   0.745,
#   0.73,
#   0.741,
#   0.718,
#   0.711,
#   0.703,
#   0.724,
#   0.717,
#   0.734],
#  ('After Midnight', 'Rum'): [0.706, 0.706, 0.685, 0.721],
#  ('After Midnight', 'Two-handed'): [0.713, 0.713, 0.734, 0.741],
#  ('Agilita', 'Rum'): [],
#  ('Airship', 'Championship'): [0.748,
#   0.748,
#   0.726,
#   0.763,
#   0.725,
#   0.762,
#   0.724,
#   0.762,
#   0.769,
#   0.776,
#   0.777,
#   0.791,
#   0.795,
#   0.761,
#   0.766,
#   0.757,
#   0.748],
#  ('Airship', 'Fleet'): [0.734, 0.734, 0.756, 0.763, 0.726],
#  ('Airship', 'PNR'): [0.785,
#   0.785,
#   0.79,
#   0.786,
#   0.763,
#   0.757,
#   0.749,
#   0.786,
#   0.791,
#   0.796],
#  ('Airship', 'PNR_asPublished'): [0.785,
#   0.785,
#   0.79,
#   0.786,
#   0.763,
#   0.757,
#   0.749,
#   0.786,
#   0.791,
#   0.796],
#  ('Badonkadonk', 'Championship'): [0.845, 0.845, 0.82],
#  ('Badonkadonk', 'Fleet'): [],
#  ('Black Diamond', 'PNR'): [0.81,
#   0.81,
#   0.807,
#   0.811,
#   0.789,
#   0.788,
#   0.82,
#   0.827,
#   0.833],
#  ('Black Diamond', 'PNR_asPublished'): [0.81,
#   0.81,
#   0.807,
#   0.811,
#   0.789,
#   0.788,
#   0.82,
#   0.827,
#   0.833],
#  ('Blink', 'Central Triangle'): [0.99, 0.99, 1.02, 1.029, 1.017],
#  ('Blink', 'Championship'): [0.978, 0.978, 0.978, 0.949, 0.955],
#  ('Blink', 'Fleet'): [0.98, 0.98, 0.98],
#  ('Blink', 'Offshore'): [1.007, 1.007, 0.977, 1.028],
#  ('Blink', 'PNR'): [0.978,
#   0.978,
#   1.006,
#   0.956,
#   1.007,
#   0.989,
#   0.958,
#   0.951,
#   0.962],
#  ('Blink', 'PNR_asPublished'): [0.978,
#   0.978,
#   1.006,
#   0.956,
#   1.007,
#   0.989,
#   0.958,
#   0.951,
#   0.962],
#  ('Blink', 'Rum'): [0.942, 0.942, 0.97, 0.921, 0.915, 0.962],
#  ('Blink', 'Two-handed'): [0.973, 0.973, 0.944],
#  ('Blurred Image', 'Championship'): [0.679,
#   0.679,
#   0.679,
#   0.661,
#   0.694,
#   0.675,
#   0.686,
#   0.68],
#  ('Blurred Image', 'Fleet'): [0.683, 0.683, 0.703, 0.71, 0.696, 0.677, 0.71],
#  ('Brix', 'Championship'): [0.704,
#   0.704,
#   0.683,
#   0.689,
#   0.694,
#   0.693,
#   0.692,
#   0.67,
#   0.676,
#   0.702],
#  ('Brix', 'Fleet'): [0.685, 0.685, 0.706, 0.691, 0.684],
#  ('Brix', 'PNR'): [0.682,
#   0.682,
#   0.671,
#   0.693,
#   0.666,
#   0.658,
#   0.691,
#   0.696,
#   0.682],
#  ('Brix', 'PNR_asPublished'): [0.682,
#   0.682,
#   0.671,
#   0.693,
#   0.666,
#   0.658,
#   0.691,
#   0.696,
#   0.682],
#  ('Brix', 'Rum'): [0.705, 0.705, 0.705],
#  ('CU', 'Championship'): [0.8,
#   0.8,
#   0.776,
#   0.769,
#   0.766,
#   0.754,
#   0.745,
#   0.735,
#   0.727,
#   0.719,
#   0.71,
#   0.745],
#  ('CU', 'Fleet'): [0.79, 0.79, 0.766, 0.76, 0.758, 0.745, 0.736, 0.727],
#  ('CU', 'PNR'): [0.723, 0.723, 0.706, 0.714, 0.695],
#  ('CU', 'PNR_asPublished'): [0.723, 0.723, 0.706, 0.714, 0.695],
#  ('CU', 'Rum'): [0.785, 0.785, 0.809, 0.773, 0.782, 0.769, 0.78, 0.779],
#  ('Charlie', 'Championship'): [0.581, 0.581, 0.586, 0.578],
#  ('Charlie', 'Fleet'): [0.586, 0.586, 0.592, 0.594, 0.604],
#  ('Charlie', 'Rum'): [0.591,
#   0.591,
#   0.609,
#   0.578,
#   0.592,
#   0.598,
#   0.611,
#   0.581,
#   0.611,
#   0.582],
#  ('Crusader', 'Central Triangle'): [0.99, 0.99, 1.02, 1.029, 1.018],
#  ('Crusader', 'Fleet'): [0.975, 0.975, 0.996],
#  ('Crusader', 'Offshore'): [0.999, 0.999, 1.029],
#  ('Crusader', 'PNR'): [0.973, 0.973, 0.944, 0.935, 0.936],
#  ('Crusader', 'PNR_asPublished'): [0.973, 0.973, 0.944, 0.935, 0.936],
#  ('Drinks Trolley', 'Championship'): [],
#  ('Drinks Trolley', 'Fleet'): [0.831, 0.831, 0.806],
#  ('Drinks Trolley', 'Rum'): [],
#  ('Eat My Shorts', 'Championship'): [0.726,
#   0.726,
#   0.745,
#   0.754,
#   0.739,
#   0.762,
#   0.741,
#   0.748,
#   0.748,
#   0.744,
#   0.741,
#   0.749,
#   0.737,
#   0.74,
#   0.742],
#  ('Eat My Shorts', 'Fleet'): [0.739,
#   0.739,
#   0.736,
#   0.738,
#   0.738,
#   0.741,
#   0.739,
#   0.717,
#   0.721],
#  ('Eat My Shorts', 'Rum'): [0.738,
#   0.738,
#   0.76,
#   0.723,
#   0.739,
#   0.739,
#   0.731,
#   0.757,
#   0.763],
#  ('Excel', 'Fleet'): [0.711, 0.711, 0.724],
#  ('Floating Free', 'Championship'): [0.71,
#   0.71,
#   0.689,
#   0.7,
#   0.723,
#   0.728,
#   0.708,
#   0.734],
#  ('Floating Free', 'Fleet'): [0.713, 0.713, 0.705, 0.721, 0.692],
#  ('Floating Free', 'Two-handed'): [0.72, 0.72, 0.705],
#  ('Flying Fox', 'Fleet'): [0.771, 0.771, 0.764],
#  ('Flying Machine', 'PNR'): [0.74,
#   0.74,
#   0.762,
#   0.769,
#   0.758,
#   0.769,
#   0.765,
#   0.767,
#   0.767,
#   0.747],
#  ('Flying Machine', 'PNR_asPublished'): [0.74,
#   0.74,
#   0.762,
#   0.769,
#   0.758,
#   0.769,
#   0.765,
#   0.767,
#   0.767,
#   0.747],
#  ('Galatea', 'Classics'): [],
#  ('Galatea', 'Rum'): [],
#  ('Gucci', 'Central Triangle'): [0.758, 0.758, 0.735, 0.728, 0.765],
#  ('Gucci', 'Championship'): [0.764,
#   0.764,
#   0.754,
#   0.753,
#   0.753,
#   0.752,
#   0.731,
#   0.768,
#   0.775,
#   0.782,
#   0.744,
#   0.739,
#   0.757,
#   0.762,
#   0.755],
#  ('Gucci', 'Fleet'): [0.751,
#   0.751,
#   0.764,
#   0.732,
#   0.749,
#   0.726,
#   0.75,
#   0.752,
#   0.734],
#  ('Gucci', 'Offshore'): [0.752, 0.752, 0.773, 0.735],
#  ('Gucci', 'PNR'): [0.755,
#   0.755,
#   0.777,
#   0.764,
#   0.754,
#   0.771,
#   0.769,
#   0.744,
#   0.736,
#   0.767],
#  ('Gucci', 'PNR_asPublished'): [0.755,
#   0.755,
#   0.777,
#   0.764,
#   0.754,
#   0.771,
#   0.769,
#   0.744,
#   0.736,
#   0.767],
#  ('Gucci', 'Rum'): [0.735, 0.735, 0.757],
#  ('Haumuri', 'Championship'): [0.656,
#   0.656,
#   0.636,
#   0.665,
#   0.634,
#   0.629,
#   0.622,
#   0.615,
#   0.608,
#   0.618,
#   0.636,
#   0.622,
#   0.641],
#  ('Haumuri', 'Fleet'): [0.649, 0.649, 0.668, 0.635, 0.63, 0.663],
#  ('Haumuri', 'PNR'): [0.617,
#   0.617,
#   0.636,
#   0.605,
#   0.628,
#   0.615,
#   0.639,
#   0.606,
#   0.6,
#   0.614],
#  ('Haumuri', 'PNR_asPublished'): [0.617,
#   0.617,
#   0.636,
#   0.605,
#   0.628,
#   0.615,
#   0.639,
#   0.606,
#   0.6,
#   0.614],
#  ('Haumuri', 'Rum'): [0.65, 0.65, 0.67],
#  ('Helter Skelter', 'Championship'): [0.845,
#   0.845,
#   0.82,
#   0.862,
#   0.844,
#   0.822,
#   0.836,
#   0.811,
#   0.855,
#   0.859,
#   0.866,
#   0.862,
#   0.83,
#   0.852,
#   0.877],
#  ('Helter Skelter', 'Fleet'): [0.84, 0.84, 0.865, 0.822, 0.835],
#  ('Helter Skelter', 'PNR'): [0.857,
#   0.857,
#   0.831,
#   0.824,
#   0.865,
#   0.821,
#   0.838,
#   0.861,
#   0.845],
#  ('Helter Skelter', 'PNR_asPublished'): [0.857,
#   0.857,
#   0.831,
#   0.824,
#   0.865,
#   0.821,
#   0.838,
#   0.861,
#   0.845],
#  ('Ibis', 'Rum'): [0.68, 0.68, 0.66, 0.687, 0.662, 0.672, 0.651, 0.683],
#  ('Illusions', 'Central Triangle'): [],
#  ('Illusions', 'Championship'): [0.658,
#   0.658,
#   0.678,
#   0.684,
#   0.682,
#   0.676,
#   0.669,
#   0.676,
#   0.656,
#   0.669,
#   0.654,
#   0.663],
#  ('Illusions', 'Fleet'): [0.657, 0.657, 0.663, 0.659, 0.646],
#  ('Illusions', 'Offshore'): [0.673, 0.673, 0.653],
#  ('Illusions', 'PNR'): [0.663,
#   0.663,
#   0.646,
#   0.638,
#   0.67,
#   0.642,
#   0.651,
#   0.64,
#   0.643,
#   0.659],
#  ('Illusions', 'PNR_asPublished'): [0.663,
#   0.663,
#   0.646,
#   0.638,
#   0.67,
#   0.642,
#   0.651,
#   0.64,
#   0.643,
#   0.659],
#  ('Illusions', 'Rum'): [0.683, 0.683, 0.682, 0.663, 0.697, 0.682, 0.662],
#  ('Incantare', 'Championship'): [0.684,
#   0.684,
#   0.705,
#   0.709,
#   0.676,
#   0.692,
#   0.694,
#   0.678,
#   0.674,
#   0.702,
#   0.667,
#   0.687,
#   0.699],
#  ('Incantare', 'Fleet'): [0.701, 0.701, 0.706, 0.704],
#  ('Incantare', 'PNR'): [0.688,
#   0.688,
#   0.667,
#   0.662,
#   0.695,
#   0.679,
#   0.671,
#   0.696,
#   0.677,
#   0.702],
#  ('Incantare', 'PNR_asPublished'): [0.688,
#   0.688,
#   0.667,
#   0.662,
#   0.695,
#   0.679,
#   0.671,
#   0.696,
#   0.677,
#   0.702],
#  ('Incantare', 'Rum'): [0.705, 0.705, 0.684],
#  ('Jive Talkin', 'Central Triangle'): [0.86, 0.86, 0.86, 0.859, 0.86],
#  ('Jive Talkin', 'Offshore'): [0.86, 0.86, 0.86],
#  ('Jive Talkin', 'PNR'): [0.87,
#   0.87,
#   0.844,
#   0.836,
#   0.845,
#   0.829,
#   0.866,
#   0.846,
#   0.854],
#  ('Jive Talkin', 'PNR_asPublished'): [0.87,
#   0.87,
#   0.844,
#   0.836,
#   0.845,
#   0.829,
#   0.866,
#   0.846,
#   0.854],
#  ('La Quintessence', 'Championship'): [0.707, 0.707, 0.686],
#  ('La Quintessence', 'Fleet'): [0.703, 0.703, 0.682],
#  ('Lizzie', 'Classics'): [],
#  ('Loloma', 'Classics'): [],
#  ('Mabel', 'Classics'): [],
#  ('Magic Trick', 'Championship'): [0.909,
#   0.909,
#   0.896,
#   0.892,
#   0.928,
#   0.89,
#   0.876,
#   0.886,
#   0.891],
#  ('Magic Trick', 'Fleet'): [0.881, 0.881, 0.907],
#  ('Magic Trick', 'PNR'): [0.889,
#   0.889,
#   0.874,
#   0.871,
#   0.875,
#   0.851,
#   0.862,
#   0.851],
#  ('Magic Trick', 'PNR_asPublished'): [0.889,
#   0.889,
#   0.874,
#   0.871,
#   0.875,
#   0.851,
#   0.862,
#   0.851],
#  ('Marangi', 'Championship'): [0.58,
#   0.58,
#   0.597,
#   0.603,
#   0.609,
#   0.616,
#   0.605,
#   0.607],
#  ('Marangi', 'Fleet'): [0.6, 0.6, 0.618, 0.622, 0.629, 0.637],
#  ('Maranui', 'Championship'): [0.548, 0.548, 0.561, 0.541, 0.533],
#  ('Maranui', 'Fleet'): [],
#  ('Marishka', 'Championship'): [0.609,
#   0.609,
#   0.591,
#   0.622,
#   0.59,
#   0.61,
#   0.594,
#   0.619,
#   0.615,
#   0.593,
#   0.588,
#   0.596],
#  ('Marishka', 'Fleet'): [0.603, 0.603, 0.602, 0.605, 0.619, 0.594],
#  ('Montego Bay III', 'Central Triangle'): [0.748, 0.748, 0.726, 0.763, 0.728],
#  ('Montego Bay III', 'Championship'): [0.7,
#   0.7,
#   0.717,
#   0.707,
#   0.724,
#   0.725,
#   0.739,
#   0.747,
#   0.755,
#   0.758,
#   0.731],
#  ('Montego Bay III', 'Fleet'): [0.698, 0.698, 0.719, 0.725, 0.711],
#  ('Montego Bay III', 'Offshore'): [0.741, 0.741, 0.763, 0.726],
#  ('Montego Bay III', 'Rum'): [0.72, 0.72, 0.742, 0.705, 0.716],
#  ('Montego Bay III', 'Two-handed'): [0.722, 0.722, 0.739],
#  ('Nedax Racing', 'Rum'): [],
#  ('Nedax Racing', 'Two-handed'): [0.825, 0.825, 0.85],
#  ('Port Nic 1', 'Championship'): [0.68, 0.68, 0.66],
#  ('Port Nic 1', 'Fleet'): [],
#  ('Port Nic 1', 'Rum'): [0.68, 0.68, 0.66, 0.67, 0.692],
#  ('Port Nic 2', 'Championship'): [0.68, 0.68, 0.66, 0.654],
#  ('Port Nic 2', 'Fleet'): [0.68, 0.68, 0.66],
#  ('Port Nic 2', 'Rum'): [0.674, 0.674, 0.694, 0.7],
#  ('Prime Mover', 'Championship'): [0.755,
#   0.755,
#   0.778,
#   0.785,
#   0.763,
#   0.769,
#   0.748,
#   0.742,
#   0.749,
#   0.742,
#   0.769,
#   0.775,
#   0.749,
#   0.774,
#   0.758,
#   0.762,
#   0.74],
#  ('Prime Mover', 'Fleet'): [0.746, 0.746, 0.724, 0.732, 0.736, 0.757, 0.728],
#  ('Prime Mover', 'Offshore'): [0.775, 0.775, 0.775],
#  ('Prime Mover', 'PNR'): [0.764,
#   0.764,
#   0.754,
#   0.758,
#   0.737,
#   0.77,
#   0.733,
#   0.727,
#   0.72,
#   0.712],
#  ('Prime Mover', 'PNR_asPublished'): [0.764,
#   0.764,
#   0.754,
#   0.758,
#   0.737,
#   0.77,
#   0.733,
#   0.727,
#   0.72,
#   0.712],
#  ('Revenue Cutter', 'Championship'): [0.643, 0.643, 0.643, 0.624, 0.642],
#  ('Revenue Cutter', 'Fleet'): [0.645, 0.645, 0.645],
#  ('Revs', 'Central Triangle'): [0.885, 0.885, 0.858, 0.851, 0.859],
#  ('Revs', 'Championship'): [0.908,
#   0.908,
#   0.887,
#   0.902,
#   0.882,
#   0.921,
#   0.882,
#   0.919,
#   0.876,
#   0.895,
#   0.896,
#   0.888,
#   0.888,
#   0.88,
#   0.876,
#   0.883],
#  ('Revs', 'Fleet'): [0.89, 0.89, 0.917, 0.871, 0.905],
#  ('Revs', 'Offshore'): [0.885, 0.885, 0.858, 0.851],
#  ('Revs', 'PNR'): [0.888,
#   0.888,
#   0.888,
#   0.888,
#   0.888,
#   0.895,
#   0.916,
#   0.9,
#   0.899],
#  ('Revs', 'PNR_asPublished'): [0.888,
#   0.888,
#   0.888,
#   0.888,
#   0.888,
#   0.895,
#   0.916,
#   0.9,
#   0.899],
#  ('Rosschild', 'Championship'): [0.632,
#   0.632,
#   0.613,
#   0.639,
#   0.621,
#   0.611,
#   0.603,
#   0.633,
#   0.639,
#   0.643,
#   0.65],
#  ('Rosschild', 'Fleet'): [0.611, 0.611, 0.629],
#  ('Rosschild', 'Rum'): [0.644, 0.644, 0.644, 0.625, 0.619, 0.613],
#  ('Saffron', 'Championship'): [0.685, 0.685, 0.664],
#  ('Saffron', 'Fleet'): [0.682, 0.682, 0.662],
#  ('Saffron', 'Rum'): [0.695, 0.695, 0.674],
#  ('Satellite Spy', 'Central Triangle'): [0.885, 0.885, 0.912, 0.893, 0.867],
#  ('Satellite Spy', 'Offshore'): [0.893, 0.893, 0.92],
#  ('Satellite Spy', 'PNR'): [0.883,
#   0.883,
#   0.908,
#   0.917,
#   0.906,
#   0.911,
#   0.913,
#   0.887,
#   0.909],
#  ('Satellite Spy', 'PNR_asPublished'): [0.883,
#   0.883,
#   0.908,
#   0.917,
#   0.906,
#   0.911,
#   0.913,
#   0.887,
#   0.909],
#  ('Saucy Sausage', 'Championship'): [0.627, 0.627, 0.646, 0.625, 0.64],
#  ('Saucy Sausage', 'Fleet'): [0.628, 0.628, 0.61],
#  ('Saucy Sausage', 'Two-handed'): [0.635, 0.635, 0.626],
#  ('Shemara', 'Classics'): [],
#  ('St Laurence', 'Championship'): [],
#  ('St Laurence', 'Fleet'): [1.037, 1.037, 1.006, 1.059, 1.005],
#  ('St Laurence', 'PNR'): [1.004,
#   1.004,
#   1.034,
#   1.029,
#   1.05,
#   1.061,
#   1.011,
#   1.005,
#   0.996],
#  ('St Laurence', 'PNR_asPublished'): [1.004,
#   1.004,
#   1.034,
#   1.029,
#   1.05,
#   1.061,
#   1.011,
#   1.005,
#   0.996],
#  ('Stepping Stone', 'Championship'): [0.743,
#   0.743,
#   0.745,
#   0.766,
#   0.772,
#   0.735,
#   0.753,
#   0.753,
#   0.731],
#  ('Stepping Stone', 'Fleet'): [0.74, 0.74, 0.74],
#  ('Stepping Stone', 'PNR'): [0.753,
#   0.753,
#   0.761,
#   0.754,
#   0.746,
#   0.753,
#   0.753,
#   0.73,
#   0.735],
#  ('Stepping Stone', 'PNR_asPublished'): [0.753,
#   0.753,
#   0.761,
#   0.754,
#   0.746,
#   0.753,
#   0.753,
#   0.73,
#   0.735],
#  ('Structural Analysis', 'Championship'): [0.773, 0.773, 0.787, 0.754],
#  ('Structural Analysis', 'Fleet'): [0.765, 0.765, 0.742],
#  ('Synfinity', 'PNR'): [0.72,
#   0.72,
#   0.698,
#   0.692,
#   0.685,
#   0.677,
#   0.668,
#   0.69,
#   0.686,
#   0.678],
#  ('Synfinity', 'PNR_asPublished'): [0.72,
#   0.72,
#   0.698,
#   0.692,
#   0.685,
#   0.677,
#   0.668,
#   0.69,
#   0.686,
#   0.678],
#  ('Tarun', 'Rum'): [0.58, 0.58, 0.576],
#  ('Testarossa', 'Championship'): [0.775,
#   0.775,
#   0.786,
#   0.795,
#   0.774,
#   0.774,
#   0.803,
#   0.767,
#   0.801,
#   0.792,
#   0.765,
#   0.76,
#   0.751,
#   0.744,
#   0.78,
#   0.784,
#   0.786,
#   0.775],
#  ('Testarossa', 'Fleet'): [0.79, 0.79, 0.807, 0.799, 0.801],
#  ('Testarossa', 'PNR'): [0.757,
#   0.757,
#   0.754,
#   0.779,
#   0.775,
#   0.775,
#   0.759,
#   0.746,
#   0.781,
#   0.743],
#  ('Testarossa', 'PNR_asPublished'): [0.757,
#   0.757,
#   0.754,
#   0.779,
#   0.775,
#   0.775,
#   0.759,
#   0.746,
#   0.781,
#   0.743],
#  ('The Guarantee', 'Championship'): [0.829,
#   0.829,
#   0.829,
#   0.854,
#   0.837,
#   0.832,
#   0.812,
#   0.849,
#   0.842,
#   0.836,
#   0.84],
#  ('The Guarantee', 'Fleet'): [0.856, 0.856, 0.83, 0.832, 0.838, 0.864],
#  ('The Guarantee', 'Offshore'): [],
#  ('The Guarantee', 'PNR'): [0.836,
#   0.836,
#   0.851,
#   0.857,
#   0.845,
#   0.835,
#   0.819,
#   0.862,
#   0.831],
#  ('The Guarantee', 'PNR_asPublished'): [0.836,
#   0.836,
#   0.851,
#   0.857,
#   0.845,
#   0.835,
#   0.819,
#   0.862,
#   0.831],
#  ('Titus Canby', 'Championship'): [0.677,
#   0.677,
#   0.677,
#   0.688,
#   0.674,
#   0.668,
#   0.68,
#   0.677,
#   0.677,
#   0.696,
#   0.702,
#   0.711,
#   0.718,
#   0.685,
#   0.681],
#  ('Titus Canby', 'Fleet'): [0.688, 0.688, 0.667, 0.689, 0.67, 0.659, 0.652],
#  ('Titus Canby', 'PNR'): [0.706,
#   0.706,
#   0.685,
#   0.68,
#   0.672,
#   0.698,
#   0.67,
#   0.66,
#   0.694,
#   0.689],
#  ('Titus Canby', 'PNR_asPublished'): [0.706,
#   0.706,
#   0.685,
#   0.68,
#   0.672,
#   0.698,
#   0.67,
#   0.66,
#   0.694,
#   0.689],
#  ('Titus Canby', 'Two-handed'): [0.687, 0.687, 0.677, 0.684],
#  ('Tortimony', 'Championship'): [0.625, 0.625, 0.606],
#  ('Tortimony', 'Fleet'): [0.61, 0.61, 0.603],
#  ('Tortimony', 'Rum'): [0.62,
#   0.62,
#   0.618,
#   0.6,
#   0.614,
#   0.595,
#   0.589,
#   0.6,
#   0.616,
#   0.621,
#   0.59,
#   0.586],
#  ('Tracer', 'PNR'): [0.54,
#   0.54,
#   0.556,
#   0.561,
#   0.556,
#   0.536,
#   0.565,
#   0.571,
#   0.562],
#  ('Tracer', 'PNR_asPublished'): [0.54,
#   0.54,
#   0.556,
#   0.561,
#   0.556,
#   0.536,
#   0.565,
#   0.571,
#   0.562],
#  ('Tracer', 'Rum'): [0.57, 0.57, 0.587],
#  ('Transition', 'Offshore'): [],
#  ('Vandetta', 'Rum'): [],
#  ('Wai Aniwa', 'Championship'): [0.672,
#   0.672,
#   0.667,
#   0.664,
#   0.673,
#   0.679,
#   0.672,
#   0.69],
#  ('Wai Aniwa', 'Fleet'): [0.66, 0.66, 0.64, 0.674],
#  ('Wai Aniwa', 'Offshore'): [0.68, 0.68, 0.7],
#  ('Wai Aniwa', 'Rum'): [0.653, 0.653, 0.653, 0.653],
#  ('Wai Aniwa', 'Two-handed'): [0.687, 0.687, 0.681],
#  ('Wedgetail', 'Championship'): [0.954,
#   0.954,
#   0.963,
#   0.941,
#   0.923,
#   0.954,
#   0.945,
#   0.972,
#   0.951,
#   0.95,
#   0.925,
#   0.948,
#   0.94,
#   0.97,
#   0.969,
#   0.929],
#  ('Wedgetail', 'Fleet'): [0.962, 0.962, 0.958, 0.948, 0.928, 0.976, 0.954],
#  ('Wedgetail', 'Offshore'): [],
#  ('Wedgetail', 'PNR'): [0.942,
#   0.942,
#   0.965,
#   0.972,
#   0.957,
#   0.959,
#   0.95,
#   0.952,
#   0.956],
#  ('Wedgetail', 'PNR_asPublished'): [0.942,
#   0.942,
#   0.965,
#   0.972,
#   0.957,
#   0.959,
#   0.95,
#   0.952,
#   0.956],
#  ('Whistler III', 'Championship'): [0.743,
#   0.743,
#   0.743,
#   0.745,
#   0.725,
#   0.744,
#   0.734,
#   0.759,
#   0.745,
#   0.722,
#   0.717,
#   0.737,
#   0.738,
#   0.728],
#  ('Whistler III', 'Fleet'): [0.718, 0.718, 0.74, 0.745, 0.729, 0.71, 0.739],
#  ('Whistler III', 'PNR'): [0.732,
#   0.732,
#   0.732,
#   0.731,
#   0.735,
#   0.74,
#   0.744,
#   0.716,
#   0.728,
#   0.713],
#  ('Whistler III', 'PNR_asPublished'): [0.732,
#   0.732,
#   0.732,
#   0.731,
#   0.735,
#   0.74,
#   0.744,
#   0.716,
#   0.728,
#   0.713],
#  ('Whistler III', 'Rum'): [0.74, 0.74, 0.762],
#  ('White Cavalier', 'Championship'): [0.555,
#   0.555,
#   0.572,
#   0.575,
#   0.565,
#   0.566,
#   0.552,
#   0.547,
#   0.552,
#   0.554,
#   0.551,
#   0.543,
#   0.556],
#  ('White Cavalier', 'Fleet'): [0.561,
#   0.561,
#   0.554,
#   0.559,
#   0.542,
#   0.558,
#   0.571,
#   0.575,
#   0.581,
#   0.576],
#  ('White Cavalier', 'PNR'): [0.549,
#   0.549,
#   0.565,
#   0.571,
#   0.577,
#   0.583,
#   0.59,
#   0.59,
#   0.59],
#  ('White Cavalier', 'PNR_asPublished'): [0.549,
#   0.549,
#   0.565,
#   0.571,
#   0.577,
#   0.583,
#   0.59,
#   0.59,
#   0.59],
#  ('White Cavalier', 'Rum'): [0.581, 0.581, 0.565, 0.587, 0.596, 0.602, 0.572],
#  ('White Cavalier', 'Two-handed'): [0.584, 0.584, 0.584, 0.566],
#  ('Wiseguy', 'Championship'): [0.694,
#   0.694,
#   0.689,
#   0.692,
#   0.713,
#   0.698,
#   0.711,
#   0.689,
#   0.696,
#   0.714],
#  ('Wiseguy', 'Fleet'): [0.691,
#   0.691,
#   0.702,
#   0.673,
#   0.704,
#   0.693,
#   0.672,
#   0.666,
#   0.679],
#  ('Wiseguy', 'Offshore'): [],
#  ('Wiseguy', 'PNR'): [0.699, 0.699, 0.701, 0.714, 0.704, 0.693, 0.681, 0.687],
#  ('Wiseguy', 'PNR_asPublished'): [0.699,
#   0.699,
#   0.701,
#   0.714,
#   0.704,
#   0.693,
#   0.681,
#   0.687],
#  ('Wiseguy', 'Rum'): [0.697, 0.697, 0.718],
#  ('XTSea', 'Rum'): [0.765, 0.765, 0.788, 0.795],
#  ('Young Nicholson', 'Fleet'): [0.82, 0.82, 0.795, 0.789]}

# %%
# Show history of seeds and clamped TCFs for specified boat and handicap type
TCFclampHistoryAndSeeds[('Airship','Championship')]
# Out:
# [0.748,
#  0.748,
#  0.726,
#  0.763,
#  0.725,
#  0.762,
#  0.724,
#  0.762,
#  0.769,
#  0.776,
#  0.777,
#  0.791,
#  0.795,
#  0.761,
#  0.766,
#  0.757,
#  0.748]

# %%
# Test out dataframes
testboatname='Airship'
testhandicap='Championship'


dfTCF = dfTCF.reset_index()

testdf = dfTCF[dfTCF['Boat name']==testboatname][['Boat name','Date','Div','TCFalgo','Scoring','Handicap', \
                                                  'TCFapplied','TCFactual','TCFclmp','newTCF']]
testdf = testdf[testdf['Handicap']==testhandicap]
scoring = testdf['TCFalgo'].values[0]

testdf
# Out:
#      Boat name    Date Div  TCFalgo  Scoring      Handicap  TCFapplied  TCFactual TCFclmp  newTCF
# 28     Airship  27 Sep   2        2        1  Championship         NaN        NaN     NaN     NaN
# 67     Airship   4 Oct   2        2        1  Championship       0.748      0.748   0.726   0.741
# 91     Airship  11 Oct   2        2        1  Championship       0.741      0.741   0.763   0.747
# 136    Airship  18 Oct   2        2        1  Championship       0.747      0.747   0.725   0.740
# 208    Airship   8 Nov   2        2        1  Championship       0.740      0.740   0.762   0.746
# 319    Airship  29 Nov   2        2        1  Championship       0.746      0.746   0.724   0.740
# 344    Airship   6 Dec   2        2        1  Championship       0.740      0.740   0.762   0.747
# 366    Airship   6 Dec   2        2        1  Championship       0.747      0.747   0.769   0.753
# 446    Airship  31 Jan   2        2        1  Championship       0.753      0.753   0.776   0.762
# 470    Airship  31 Jan   2        2        1  Championship       0.762      0.762   0.777   0.768
# 491    Airship  31 Jan   2        2        1  Championship       0.768      0.768   0.791   0.778
# 513    Airship  31 Jan   2        2        1  Championship       0.778      0.778   0.795   0.785
# 1029   Airship  28 Feb   2        2        1  Championship       0.785      0.785   0.761   0.779
# 1136   Airship  21 Mar   2        2        1  Championship       0.780      0.779   0.766   0.775
# 1150   Airship  21 Mar   2        2        1  Championship       0.776      0.775   0.757   0.769
# 1178   Airship  28 Mar   2        2        1  Championship       0.769      0.769   0.748   0.760

# %%
#Test out dataframes
testboatname='Blink'
testhandicap='Fleet'

testdf = dfTCF[dfTCF['Boat name']==testboatname][['Boat name','Date','Div','TCFalgo','Scoring','Handicap', \
                                                  'TCFapplied','TCFactual','TCFclmp','newTCF']]
testdf = testdf[testdf['Handicap']==testhandicap]
scoring = testdf['TCFalgo'].values[0]

testdf
# Out:
#     Boat name    Date       Div  TCFalgo  Scoring Handicap  TCFapplied  TCFactual TCFclmp  newTCF
# 21      Blink  20 Sep  Combined        2        1    Fleet       0.938      0.938    0.91    0.93
# 189     Blink   5 Nov  Combined        2        1    Fleet       0.930      0.930   0.902    0.93
# 275     Blink   8 Nov  Combined        2        1    Fleet       0.930      0.930   0.902    0.92
# 390     Blink  13 Dec  Combined        2        1    Fleet       0.980      0.980    0.98    0.98

# %%
#Test out dataframes
testboatname='Blink'
testhandicap='Championship'

testdf = dfTCF[dfTCF['Boat name']==testboatname][['Boat name','Date','Div','TCFalgo','Scoring','Handicap', \
                                                  'TCFapplied','TCFactual','TCFclmp','newTCF']]
testdf = testdf[testdf['Handicap']==testhandicap]
scoring = testdf['TCFalgo'].values[0]

testdf
# Out:
#      Boat name    Date Div  TCFalgo  Scoring      Handicap  TCFapplied  TCFactual TCFclmp  newTCF
# 24       Blink  27 Sep   1        2        1  Championship         NaN        NaN     NaN     NaN
# 52       Blink   4 Oct   1        2        1  Championship       0.934      0.934   0.962   0.942
# 82       Blink  11 Oct   1        2        1  Championship         NaN        NaN     NaN     NaN
# 116      Blink  18 Oct   1        2        1  Championship         NaN        NaN     NaN     NaN
# 203      Blink   8 Nov   1        2        1  Championship       0.942      0.942   0.914   0.935
# 307      Blink  29 Nov   1        2        1  Championship       0.935      0.935   0.945   0.938
# 338      Blink   6 Dec   1        2        1  Championship       0.940      0.938   0.938   0.938
# 362      Blink   6 Dec   1        2        1  Championship       0.934      0.938   0.943   0.940
# 440      Blink  31 Jan   1        2        1  Championship         NaN        NaN     NaN     NaN
# 1129     Blink  21 Mar   1        2        1  Championship       0.978      0.978   0.978   0.978
# 1145     Blink  21 Mar   1        2        1  Championship       0.978      0.978   0.949   0.969
# 1170     Blink  28 Mar   1        2        1  Championship       0.969      0.969   0.955   0.964
