# %% [markdown]
# #### TCFanalysis - code to read in a CSV file of RPNYC race results and check that the TCF updating procedure has been applied correctly.

# %%
import pandas as pd
import datetime as dt
from functions import *

pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.line_width',10000)
pd.set_option('display.max_columns',10000)
pd.set_option('display.max_rows',10000)
pd.set_option('display.max_colwidth',10000)
pd.set_option('display.max_info_columns',10000)
pd.set_option('display.height',1000)
pd.set_option('display.max_seq_items',100)
pd.set_option('display.multi_sparse', True)

datapath = 'C:\\Phil\\My Dropbox\\Python\\Sailing\\Data\\'
#datapath = '/Users/PhilBishop/Dropbox/Python/Sailing/Data/'

filename = 'All_results2013-14.csv'


# Set parameter values for TCF update formula
numSeeds = 2.
numFinished = 4.
pctFinished = 0.5
loClamp = .03
upClamp = .03

# %%
# Read input CSV file
df = pd.read_csv(datapath+filename,sep=',',parse_dates=True,dayfirst=True)

# Convert date format from dd/mm/yyyy to yyyy-mm-dd
df['Date'] = df['Date'].map(lambda x: dt.date(day=int(x.split('/')[0]),month=int(x.split('/')[1]),year=int(x.split('/')[2])))

# Initialise dicts keyed by a boatname-handicap tuple
newTCFvalue = {}                # dict for storing newTCF
TCFclampHistoryAndSeeds = {}    # dict for storing seed TCFs and clamped TCFs

# Loop through every row in the transposed dataframe and establish keyed lists
for index,row in df.T.iteritems():

    # Create a set of unique keys for boat-handicap tuples    
    key = row['Boat name'], row['Handicap']    

    # For each key value, create two empty lists
    newTCFvalue[key] = []   
    TCFclampHistoryAndSeeds[key] = []

# Index the dataframe by date, handicap, series, race and div, and sort
df = df.set_index(['Date','Handicap','Series','Race','Div']).sort()

# Make a new dataframe for appending new TCF results to
dfTCF = pd.DataFrame()

# Iterate through the raw/original dataframe on each unique race, indexed on date-handicap-series-race-div
# At each iterate, collect results into 'race'
for index, race in df.groupby(level=(0,1,2,3,4)):   
    
    key = index[1]   
    
    # Compute TCFactual (what the TCF should've been on the day)
    race['TCFactual'] = race.apply(TCFactual,axis=1,indexKey=key,newTCFvalue=newTCFvalue)
    
    # Compute corrected time, corrSecs, using TCFactual
    race['corrSecs'] = race.apply(corrSecs,axis=1)
        
    # Compute rank based on corrected time
    race['Rank'] = race['corrSecs'].rank(ascending=True)

    # Figure out the reference boat and reference time
    race['refTime'] = race.groupby(level=(0,1,2,3,4)).apply(ref_boat)
    
    # Replace reftime value with nan for boats that do not race 
    race['refTime'] = race.apply(adjustRefTime,axis=1)                
        
    # Compute TCFst, pctMvmt, TCFclmp
    race['TCFst']   = race.apply(TCFst,axis=1)
    race['pctMvmt'] = race.apply(pctMvmt,axis=1)
    race['TCFclmp'] = race.apply(lambda x: TCFclmp(x,loClamp=loClamp,upClamp=upClamp),axis=1)
    
    # If history of clamped TCFs is empty (coz boat has done no races), add see seed values; O/wise add TCFclmp
    race.apply(updateTCFclampAndSeed,axis=1,race=race,indexKey=key,TCFclampHistoryAndSeeds=TCFclampHistoryAndSeeds)  
    
    # Compute newTCF
    race['newTCF'] = race.apply(newTCF,axis=1,race=race,indexKey=key,TCFclampHistoryAndSeeds=TCFclampHistoryAndSeeds,newTCFvalue=newTCFvalue)
    
    # Compute the difference between newTCF and TCFapplied
    race['TCFdiff'] = race.apply(TCFdiff,axis=1)

    # Sort race by rank (ascending)
    race = race.set_index(['Rank'],append=True).sort()
    
    # Now, append the race dataframe to the dfTCF dataframe
    dfTCF = dfTCF.append(race.reset_index())
    
# Set column order for dfTCF
cols=['Boat name','Elapsed time','ETsecs','corrSecs','Rank','refTime','PHRF','IRC','TCFapplied','TCFactual',\
      'TCFst','pctMvmt','TCFclmp','newTCF','TCFdiff']
    
# Reindex dfTCF, sorting by index
dfTCF = dfTCF.set_index(['Date','Handicap','Series','Race','Div']).reindex(columns=cols).sort().reset_index()

# Reset index, apply date-to-string conversion to get short month format, and then reindex without sorting
dfTCF.reset_index(inplace=True)
dfTCF['Date'] = dfTCF['Date'].map(lambda x: str(x.day) + ' ' + dt.datetime.strftime(x,'%b'))
dfTCF = dfTCF.set_index(['Date','Handicap','Series','Race','Div']).reindex(columns=cols)

# %%
dfTCF.tail(35)
# Out:
#                                                              Boat name Elapsed time  ETsecs  corrSecs  Rank  refTime   PHRF    IRC  TCFapplied  TCFactual  TCFst  pctMvmt  TCFclmp  newTCF  TCFdiff
# Date   Handicap     Series     Race Div
# 23 Nov Championship Christmas  r2   3                        Rosschild      1:55:35    6935      4424     3     4645  0.680    NaN       0.639      0.638  0.670     5.02    0.657   0.644    0.001
#                                     3                         Marishka      2:00:25    7225      4436     4     4645  0.650    NaN       0.614      0.614  0.643     4.72    0.632   0.618    0.000
#                                     3                    Saucy Sausage      2:03:05    7385      4645     5     4645  0.630    NaN       0.623      0.629  0.629     0.00    0.629   0.629   -0.006
#                                     3                   White Cavalier      2:23:37    8617      4859     6     4645    NaN    NaN       0.562      0.564  0.539    -4.43    0.547   0.558   -0.002
#                                     3                    Blurred Image      1:56:18    6978      4884     7     4645    NaN    NaN       0.685      0.700  0.666    -4.86    0.679   0.696   -0.015
#                                     3                        Wai-Aniwa      2:01:24    7284      4909     8     4645  0.690    NaN       0.674      0.674  0.638    -5.34    0.654   0.670    0.000
#                                     3                          Haumuri      2:10:09    7809      5239     9     4645  0.665    NaN       0.672      0.671  0.595   -11.33    0.651   0.665    0.001
#                                r3   1                   Drinks Trolley      1:46:31    6391      5342     1     5867  0.840    NaN       0.833      0.836  0.918     9.81    0.861   0.839   -0.003
#                                     1                             Revs      1:42:36    6156      5540     2     5867  0.885  1.234       0.897      0.900  0.953     5.89    0.927   0.903   -0.003
#                                     1                            Blink      1:37:50    5870      5570     3     5867  0.980    NaN       0.954      0.949  1.000     5.37    0.977   0.950    0.005
#                                     1                     Nedax Racing      1:57:07    7027      5790     4     5867  0.840    NaN       0.824      0.824  0.835     1.33    0.835   0.826    0.000
#                                     1                      Magic Trick      1:50:37    6637      5867     5     5867  0.875    NaN       0.889      0.884  0.884     0.00    0.884   0.883    0.005
#                                     1                    The Guarantee      1:58:41    7121      5946     6     5867  0.845    NaN       0.828      0.835  0.824    -1.32    0.824   0.830   -0.007
#                                     1                   Rocket Science      2:02:14    7334      5947     7     5867  0.820    NaN       0.801      0.811  0.800    -1.36    0.800   0.806   -0.010
#                                     1                        Wedgetail      1:48:25    6505      6166     8     5867  0.950  1.209       0.944      0.948  0.902    -4.85    0.920   0.941   -0.004
#                                     1                       Ran Tan II      1:41:55    6115      6255     9     5867  1.040    NaN       0.994      1.023  0.960    -6.16    0.992   1.009   -0.029
#                                     2                             Brix      2:17:39    8259      5987     1     6767    NaN    NaN       0.725      0.725  0.819    12.97    0.747   0.728    0.000
#                                     2                          Wiseguy      2:20:19    8419      6011     2     6767    NaN    NaN       0.707      0.714  0.804    12.61    0.735   0.714   -0.007
#                                     2                          Airship      2:18:03    8283      6261     3     6767  0.735    NaN       0.751      0.756  0.817     8.07    0.779   0.761   -0.005
#                                     2                     Whistler III      2:28:35    8915      6597     4     6767  0.725  0.950       0.737      0.740  0.759     2.57    0.759   0.750   -0.003
#                                     2                    Floating Free      2:38:29    9509      6665     5     6767    NaN    NaN       0.706      0.701  0.712     1.57    0.712   0.703    0.005
#                                     2                   After Midnight      2:34:18    9258      6767     6     6767  0.715    NaN       0.728      0.731  0.731     0.00    0.731   0.735   -0.003
#                                     2                    Eat My Shorts      2:39:49    9589      7009     7     6767  0.745    NaN       0.739      0.731  0.706    -3.42    0.709   0.729    0.008
#                                     2                      Prime Mover      2:37:56    9476      7031     8     6767  0.765  0.963       0.743      0.742  0.714    -3.77    0.720   0.736    0.001
#                                     2                        Incantare      2:47:50   10070      7059     9     6767  0.725    NaN       0.695      0.701  0.672    -4.14    0.680   0.695   -0.006
#                                     2                            Gucci      2:37:53    9473      7199    10     6767  0.755  0.963       0.761      0.760  0.714    -6.05    0.737   0.758    0.001
#                                     2         Wellington Spirit Bronze      2:46:49   10009      7386    11     6767  0.790    NaN       0.739      0.738  0.676    -8.40    0.716   0.732    0.001
#                                     2                       Blue Magic      2:48:18   10098      7512    12     6767  0.735  0.955       0.743      0.744  0.670    -9.95    0.722   0.737   -0.001
# 27 Nov Twilight     Twilight 1 r4   Combined              Whistler III      1:00:02    3602      2651     1     2677  0.725  0.950       0.735      0.736  0.743     0.95    0.743   0.741   -0.001
#                                     Combined                Blue Magic      1:00:04    3604      2663     2     2677  0.735  0.955       0.739      0.739  0.743     0.54    0.743   0.741    0.000
#                                     Combined                     Gucci      0:59:19    3559      2665     3     2677  0.755  0.963       0.749      0.749  0.752     0.40    0.752   0.749    0.000
#                                     Combined            After Midnight      1:01:44    3704      2677     4     2677  0.715    NaN       0.723      0.723  0.723     0.00    0.723   0.725    0.000
#                                     Combined             Eat My Shorts      1:01:27    3687      2735     5     2677  0.745    NaN       0.740      0.742  0.726    -2.16    0.726   0.740   -0.002
#                                     Combined       Structural Analysis      0:57:39    3459      2736     6     2677    NaN    NaN       0.788      0.791  0.774    -2.15    0.774   0.789   -0.003
#                                     Combined  Wellington Spirit Bronze      1:00:22    3622      2752     7     2677  0.790    NaN       0.760      0.760  0.739    -2.76    0.739   0.755    0.000

# %%
dfTCF[cols].to_csv('AllTCFs.csv', sep = ',')

# %%
#TCFclampHistoryAndSeeds
