# %% [markdown]
# #### TCFanalysis - code to read in a CSV file of RPNYC race results and check that the TCF updating procedure has been applied correctly.

# %%
import pandas as pd
import datetime as dt
from functions import *
import os

pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.line_width',10000)
pd.set_option('display.max_columns',10000)
pd.set_option('display.max_rows',10000)
pd.set_option('display.max_colwidth',10000)
pd.set_option('display.max_info_columns',10000)
pd.set_option('display.height',1000)
pd.set_option('display.max_seq_items',100)
pd.set_option('display.multi_sparse', True)


filename = 'All_results2013-14.csv'
windows = 'C:\\Phil\\My Dropbox'
mac = '/Users/PhilBishop/Dropbox'

datapath = os.path.join(windows, 'Python', 'Sailing', 'Data')

# Set parameter values for TCF update formula
numSeeds = 2.
numFinished = 4.
pctFinished = 0.5
loClamp = .03
upClamp = .03

# %%
# Read input CSV file
df = pd.read_csv(datapath+'/'+filename,sep=',',parse_dates=True,dayfirst=True)

# Convert date format from dd/mm/yyyy to yyyy-mm-dd
df['Date'] = df['Date'].map(lambda x: dt.date(day=int(x.split('/')[0]), \
                                         month=int(x.split('/')[1]), \
                                         year=int(x.split('/')[2])))

# Initialise dicts to be keyed by a boatname-handicap tuple
newTCFvalue = {}                # dict for storing newTCF
TCFclampHistoryAndSeeds = {}    # dict for storing seed TCFs and clamped TCFs

# Loop through every row in the transposed dataframe and establish keyed lists
for index,row in df.T.iteritems():

    # Create a set of unique keys for boat-handicap tuples    
    key = row['Boat name'], row['Handicap']    

    # For each key value, create two empty lists
    newTCFvalue[key] = []   
    TCFclampHistoryAndSeeds[key] = []

# Index the dataframe by date, handicap, series, race, and div, and sort it
df = df.set_index(['Date','Handicap','Series','Race','Div']).sort()

# Make a new dataframe for appending new TCF results to
dfTCF = pd.DataFrame()

# Iterate through the raw/original dataframe on each unique race, indexed on date-handicap-
# series-race-div. At each iterate, collect results into a dataframe called 'race'.
for index, race in df.groupby(level=(0,1,2,3,4)):   
    
    key = index[1]   
    
    # Compute TCFactual (what the TCF should've been on the day)
    race['TCFactual'] = race.apply(TCFactual,axis=1,indexKey=key,newTCFvalue=newTCFvalue)
    
    # Compute corrected time, corrSecs, using TCFactual
    race['corrSecs'] = race.apply(corrSecs,axis=1)
        
    # Compute rank based on corrected time and compare with rank applied on the day
    race['Rank'] = race['corrSecs'].rank(ascending=True)
    race['rankDiff'] = race.apply(rankDiff,axis=1)

    # Figure out the reference boat and reference time
    race['refTime'] = race.groupby(level=(0,1,2,3,4)).apply(ref_boat)
    
    # Replace reftime value with nan for boats that do not race 
    race['refTime'] = race.apply(adjustRefTime,axis=1)                
        
    # Compute TCFst, pctMvmt, TCFclmp
    race['TCFst']   = race.apply(TCFst,axis=1)
    race['pctMvmt'] = race.apply(pctMvmt,axis=1)
    race['TCFclmp'] = race.apply(lambda x: TCFclmp(x,loClamp=loClamp,upClamp=upClamp),axis=1)
    
    # If history of clamped TCFs is empty (coz boat has done no races), add seed values; Otherwise add TCFclmp
    race.apply(updateTCFclampAndSeed,axis=1,race=race,indexKey=key,TCFclampHistoryAndSeeds=TCFclampHistoryAndSeeds)  
    
    # Compute newTCF
    race['newTCF'] = race.apply(newTCF,axis=1,race=race,indexKey=key,TCFclampHistoryAndSeeds=TCFclampHistoryAndSeeds,newTCFvalue=newTCFvalue)
    
    # Compute the difference between TCFapplied and TCFactual
    race['TCFdiff'] = race.apply(TCFdiff,axis=1)

    # Sort race by rank (ascending)
    race = race.set_index(['Rank'],append=True).sort()
    
    # Now, append the race dataframe to the dfTCF dataframe
    dfTCF = dfTCF.append(race.reset_index())
    
# Set column order for dfTCF
cols=['Boat name','Elapsed time','ETsecs','corrSecs','refTime','RankAppld','Rank','rankDiff','PHRF','IRC', \
      'TCFapplied','TCFactual','TCFdiff','TCFst','pctMvmt','TCFclmp','newTCF']
    
# Reindex dfTCF, sorting by index
dfTCF = dfTCF.set_index(['Date','Handicap','Series','Race','Div']).reindex(columns=cols).sort().reset_index()

# Reset index, apply date-to-string conversion to get short month format, and then reindex without sorting
dfTCF.reset_index(inplace=True)
dfTCF['Date'] = dfTCF['Date'].map(lambda x: str(x.day) + ' ' + dt.datetime.strftime(x,'%b'))
dfTCF = dfTCF.set_index(['Date','Handicap','Series','Race','Div']).reindex(columns=cols)
# Out:
# ('Whistler III', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.179
# newTCF: 0.7245
# ('Incantare', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.112
# newTCF: 0.70225
# ('Airship', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.251
# newTCF: 0.7485
# ('Wiseguy', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.118
# newTCF: 0.706
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.296
# newTCF: 0.7665
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.287
# newTCF: 0.76425
# ('Gucci', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.263
# newTCF: 0.75625
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.496
# newTCF: 0.83
# ('Wedgetail', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.85
# newTCF: 0.94875
# ('Revs', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.693
# newTCF: 0.89675
# ('Magic Trick', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.673
# newTCF: 0.891
# ('Nedax Racing', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.485
# newTCF: 0.82925
# ('Rocket Science', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.465
# newTCF: 0.82375
# ('The Guarantee', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.519
# newTCF: 0.84175
# ('Blink', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.821
# newTCF: 0.94275
# ('Blue Magic', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.239
# newTCF: 0.7445
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.835
# newTCF: 0.7074
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.925
# newTCF: 0.7298
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.838
# newTCF: 0.7088
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.051
# newTCF: 0.763
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.007
# newTCF: 0.751
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.004
# newTCF: 0.752
# ('Floating Free', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.103
# newTCF: 0.702
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.041
# newTCF: 0.7616
# ('Prime Mover', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.26
# newTCF: 0.75525
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.204
# newTCF: 0.7365
# ('Montego Bay III', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.135
# newTCF: 0.7135
# ('Titus Canby', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.075
# newTCF: 0.691
# ('Revenue Cutter', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.937
# newTCF: 0.64725
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.887
# newTCF: 0.629
# ('Haumuri', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.025
# newTCF: 0.67575
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.792
# newTCF: 0.947
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.603
# newTCF: 0.9
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.317
# newTCF: 0.8294
# ('Nedax Racing', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.314
# newTCF: 0.8286
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.291
# newTCF: 0.823
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.552
# newTCF: 0.8886
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.775
# newTCF: 0.9448
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.339
# newTCF: 0.8362
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.862
# newTCF: 0.7142
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.056
# newTCF: 0.7638
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.994
# newTCF: 0.7476
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.994
# newTCF: 0.7492
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.944
# newTCF: 0.736
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.015
# newTCF: 0.7532
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.839
# newTCF: 0.7092
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.004
# newTCF: 0.7518
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.918
# newTCF: 0.7296
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.011
# newTCF: 0.7546
# ('Montego Bay III', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.827
# newTCF: 0.708
# ('Rosschild', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.909
# newTCF: 0.63475
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.527
# newTCF: 0.6312
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.766
# newTCF: 0.6914
# ('Blurred Image', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.055
# newTCF: 0.68475
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.008
# newTCF: 0.671
# ('Revenue Cutter', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.565
# newTCF: 0.6424
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.681
# newTCF: 0.6714
# ('White Cavalier', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.699
# newTCF: 0.56775
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.336
# newTCF: 0.833
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.615
# newTCF: 0.903
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.778
# newTCF: 0.9446
# ('Nedax Racing', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.311
# newTCF: 0.828
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.774
# newTCF: 0.9442
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.259
# newTCF: 0.8164
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.523
# newTCF: 0.8824
# ('Ran Tan II', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.978
# newTCF: 0.9945
# ('After Midnight', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.179
# newTCF: 0.7245
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.951
# newTCF: 0.7362
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.999
# newTCF: 0.7508
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.856
# newTCF: 0.713
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.983
# newTCF: 0.7464
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.025
# newTCF: 0.7556
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.868
# newTCF: 0.7164
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.995
# newTCF: 0.7486
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.923
# newTCF: 0.7318
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.973
# newTCF: 0.745
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.027
# newTCF: 0.7582
# ('Montego Bay III', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.795
# newTCF: 0.7006
# ('White Cavalier', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.754
# newTCF: 0.58325
# ('Titus Canby', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.057
# newTCF: 0.68425
# ('Whistler III', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.185
# newTCF: 0.727
# ('After Midnight', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.151
# newTCF: 0.71675
# ('Eat My Shorts', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.199
# newTCF: 0.733
# ('Testarossa', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.281
# newTCF: 0.7615
# ('Wai-Aniwa', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.057
# newTCF: 0.68675
# ('Gucci', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.239
# newTCF: 0.7475
# ('Montego Bay III', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.162
# newTCF: 0.7225
# ('Blink', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.911
# newTCF: 0.97275
# ('Ran Tan II', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 3.151
# newTCF: 1.04775
# ('Revs', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.682
# newTCF: 0.89175
# ('The Guarantee', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.56
# newTCF: 0.85125
# ('Wedgetail', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.863
# newTCF: 0.952
# ('Vendetta', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.121
# newTCF: 0.70525
# ('Montego Bay III', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.162
# newTCF: 0.7205
# ('Saucy Sausage', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.896
# newTCF: 0.632
# ('Wai-Aniwa', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.972
# newTCF: 0.659
# ('Blue Magic', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.174
# newTCF: 0.7265
# ('Eat My Shorts', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.207
# newTCF: 0.7375
# ('Wiseguy', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.085
# newTCF: 0.69675
# ('Blurred Image', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.049
# newTCF: 0.68475
# ('Gucci', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.239
# newTCF: 0.74825
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.54
# newTCF: 0.8844
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.796
# newTCF: 0.948
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.986
# newTCF: 0.996
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.345
# newTCF: 0.8356
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.621
# newTCF: 0.9048
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.775
# newTCF: 0.944
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.31
# newTCF: 0.8292
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.224
# newTCF: 0.808
# ('Montego Bay III', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.798
# newTCF: 0.6998
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.826
# newTCF: 0.7056
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.934
# newTCF: 0.7332
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.888
# newTCF: 0.7224
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.005
# newTCF: 0.7508
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.862
# newTCF: 0.7156
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.963
# newTCF: 0.7416
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.992
# newTCF: 0.7476
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.924
# newTCF: 0.732
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.83
# newTCF: 0.7086
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.993
# newTCF: 0.7498
# ('Charlie', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.755
# newTCF: 0.58375
# ('Rosschild', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.544
# newTCF: 0.6358
# ('Maranui', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.655
# newTCF: 0.55125
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.265
# newTCF: 0.5666
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.51
# newTCF: 0.6282
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.747
# newTCF: 0.6876
# ('Magic Trick', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.7
# newTCF: 0.89775
# ('Blink', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.918
# newTCF: 0.97025
# ('Montego Bay III', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.194
# newTCF: 0.7295
# ('Charlie', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.727
# newTCF: 0.57425
# ('Revs', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.636
# newTCF: 0.8765
# ('Floating Free', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.142
# newTCF: 0.71225
# ('Drinks Trolley', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.492
# newTCF: 0.829
# ('Eat My Shorts', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.208
# newTCF: 0.7345
# ('Wedgetail', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.821
# newTCF: 0.9385
# ('Rosschild', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.89
# newTCF: 0.62875
# ('Maranui', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.659
# newTCF: 0.55225
# ('After Midnight', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.108
# newTCF: 0.7025
# ('Blue Magic', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.232
# newTCF: 0.744
# ('White Cavalier', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.714
# newTCF: 0.5715
# ('Wiseguy', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.097
# newTCF: 0.6995
# ('Prime Mover', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.258
# newTCF: 0.7535
# ('Gucci', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.253
# newTCF: 0.752
# ('Whistler III', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.135
# newTCF: 0.71275
# ('Ran Tan II', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 3.109
# newTCF: 1.03825
# ('Incantare', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.087
# newTCF: 0.697
# ('The Guarantee', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.53
# newTCF: 0.845
# ('Saucy Sausage', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.879
# newTCF: 0.62775
# ('Airship', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.19
# newTCF: 0.73175
# ('Rocket Science', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.465
# newTCF: 0.82375
# ('Titus Canby', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.04
# newTCF: 0.68175
# ('St Laurence', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 3.121
# newTCF: 1.043
# ('Charlie', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.757
# newTCF: 0.58425
# ('Rosschild', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.918
# newTCF: 0.63775
# ('Eat My Shorts', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.966
# newTCF: 0.7406
# ('Erazer', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.136
# newTCF: 0.712
# ('White Cavalier', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.743
# newTCF: 0.581
# ('Wellington Spirit Bronze', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.275
# newTCF: 0.7595
# ('Gucci', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.965
# newTCF: 0.7426
# ('White Cavalier', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.588
# newTCF: 0.528
# ('Rosschild', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.897
# newTCF: 0.63075
# ('Marishka', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.863
# newTCF: 0.6195
# ('Floating Free', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.13
# newTCF: 0.70975
# ('After Midnight', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.157
# newTCF: 0.719
# ('Whistler III', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.175
# newTCF: 0.725
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.213
# newTCF: 0.7395
# ('Wiseguy', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.082
# newTCF: 0.69575
# ('Rocket Science', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.415
# newTCF: 0.807
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.355
# newTCF: 0.787
# ('Wai-Aniwa', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.03
# newTCF: 0.675
# ('Blue Magic', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.212
# newTCF: 0.7355
# ('Prime Mover', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.303
# newTCF: 0.76575
# ('Vendetta', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.151
# newTCF: 0.71525
# ('Gucci', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.259
# newTCF: 0.75125
# ('Montego Bay III', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.226
# newTCF: 0.74125
# ('Midnight Express', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.34
# newTCF: 0.78
# ('Revs', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.65
# newTCF: 0.8835
# ('Wedgetail', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.817
# newTCF: 0.94
# ('Nedax Racing', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.495
# newTCF: 0.83375
# ('The Guarantee', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.51
# newTCF: 0.83875
# ('Blink', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 3.0
# newTCF: 1.0025
# ('Ran Tan II', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 3.208
# newTCF: 1.072
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.876
# newTCF: 0.719
# ('Blue Magic', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.222
# newTCF: 0.73925
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.963
# newTCF: 0.7406
# ('Prime Mover', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.257
# newTCF: 0.75425
# ('Wellington Spirit Red', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.272
# newTCF: 0.75925
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.922
# newTCF: 0.7294
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.139
# newTCF: 0.7852
# ('Charlie', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.359
# newTCF: 0.5886
# ('Blurred Image', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.755
# newTCF: 0.688
# ('Rosschild', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.575
# newTCF: 0.6426
# ('Wai-Aniwa', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.631
# newTCF: 0.658
# ('Gucci', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.945
# newTCF: 0.7376
# ('Eat My Shorts', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.961
# newTCF: 0.7404
# ('Wellington Spirit Bronze', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.011
# newTCF: 0.754
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.851
# newTCF: 0.9598
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.982
# newTCF: 0.9956
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.618
# newTCF: 0.9046
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.204
# newTCF: 0.8024
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.891
# newTCF: 0.7226
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.009
# newTCF: 0.7518
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.977
# newTCF: 0.7456
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.021
# newTCF: 0.7538
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.795
# newTCF: 0.7008
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.989
# newTCF: 0.7462
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.971
# newTCF: 0.7444
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.916
# newTCF: 0.7296
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.837
# newTCF: 0.7106
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.688
# newTCF: 0.6718
# ('Marishka', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.842
# newTCF: 0.614
# ('Rosschild', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.562
# newTCF: 0.6396
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.49
# newTCF: 0.6236
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.74
# newTCF: 0.6856
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.699
# newTCF: 0.674
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.243
# newTCF: 0.562
# ('Blink', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.85
# newTCF: 0.95
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.155
# newTCF: 0.788
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.948
# newTCF: 0.7354
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.898
# newTCF: 0.7234
# ('Wellington Spirit Bronze', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.276
# newTCF: 0.76025
# ('Gucci', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.246
# newTCF: 0.749
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.959
# newTCF: 0.74
# ('Brix', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.153
# newTCF: 0.7195
# ('Incantare', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.091
# newTCF: 0.69875
# ('Saucy Sausage', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.888
# newTCF: 0.62775
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.204
# newTCF: 0.8012
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.56
# newTCF: 0.8888
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.312
# newTCF: 0.8282
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.78
# newTCF: 0.9448
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.978
# newTCF: 0.9948
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.333
# newTCF: 0.8338
# ('Nedax Racing', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.293
# newTCF: 0.8242
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.586
# newTCF: 0.8982
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.811
# newTCF: 0.9542
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.917
# newTCF: 0.728
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.956
# newTCF: 0.7372
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.046
# newTCF: 0.76
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.96
# newTCF: 0.7386
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.825
# newTCF: 0.7072
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.968
# newTCF: 0.7428
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.825
# newTCF: 0.7062
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.999
# newTCF: 0.7502
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.774
# newTCF: 0.695
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.948
# newTCF: 0.7384
# ('Brix', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.168
# newTCF: 0.7245
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.969
# newTCF: 0.743
# ('Revenue Cutter', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.574
# newTCF: 0.6432
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.75
# newTCF: 0.6872
# ('Rosschild', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.591
# newTCF: 0.6462
# ('Marishka', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.474
# newTCF: 0.6176
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.485
# newTCF: 0.6218
# ('Blurred Image', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.719
# newTCF: 0.6808
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.216
# newTCF: 0.5556
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.677
# newTCF: 0.6702
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.662
# newTCF: 0.6668
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.371
# newTCF: 0.841
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.605
# newTCF: 0.9006
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.862
# newTCF: 0.9632
# ('Nedax Racing', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.308
# newTCF: 0.8264
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.207
# newTCF: 0.8016
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.314
# newTCF: 0.8284
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.566
# newTCF: 0.891
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.965
# newTCF: 0.992
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.772
# newTCF: 0.9434
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.841
# newTCF: 0.7096
# ('Brix', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.915
# newTCF: 0.728
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.018
# newTCF: 0.7536
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.96
# newTCF: 0.7394
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.829
# newTCF: 0.707
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.904
# newTCF: 0.7264
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.734
# newTCF: 0.6858
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.96
# newTCF: 0.7406
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.937
# newTCF: 0.7352
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.032
# newTCF: 0.7584
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.924
# newTCF: 0.7324
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.949
# newTCF: 0.7384
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.966
# newTCF: 0.7402
# ('Blue Magic', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.965
# newTCF: 0.7408
# ('Gucci', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.998
# newTCF: 0.7494
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.902
# newTCF: 0.725
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.136
# newTCF: 0.7848
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.94
# newTCF: 0.736
# ('Wellington Spirit Bronze', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.015
# newTCF: 0.755
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.996
# newTCF: 0.7472
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.921
# newTCF: 0.7292
# ('Blue Magic', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.98
# newTCF: 0.7442
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.956
# newTCF: 0.7384
# ('Wellington Spirit Bronze', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.005
# newTCF: 0.752
# ('Blurred Image', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.047
# newTCF: 0.683
# ('Gucci', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.977
# newTCF: 0.7452
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.129
# newTCF: 0.7828
# ('Saucy Sausage', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.497
# newTCF: 0.625
# ('Blink', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.771
# newTCF: 0.9442
# ('Wai-Aniwa', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.634
# newTCF: 0.6584
# ('Wellington Spirit Bronze', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.006
# newTCF: 0.752
# ('Eat My Shorts', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.958
# newTCF: 0.7396
# ('Gucci', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.921
# newTCF: 0.7318
# ('Structural Analysis', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.357
# newTCF: 0.787
# ('Charlie', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.73
# newTCF: 0.57525
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.931
# newTCF: 0.732
# ('Wellington Spirit Bronze', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.986
# newTCF: 0.7476
# ('Brix', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.851
# newTCF: 0.7142
# ('Wai-Aniwa', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.725
# newTCF: 0.68
# ('Blink', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 4.032
# newTCF: 1.0068
# ('Prime Mover', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.092
# newTCF: 0.7716
# ('Young Nicholson', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.417
# newTCF: 0.80425
# ('Wedgetail', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.776
# newTCF: 0.9432
# ('Revs', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.542
# newTCF: 0.885
# ('Vendetta', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.871
# newTCF: 0.7172
# ('Khamsin', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.268
# newTCF: 0.756
# ('Blue Magic', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.947
# newTCF: 0.7364
# ('The Guarantee', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.344
# newTCF: 0.8366
# ('Sirrah', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.211
# newTCF: 0.73775
# ('Gucci', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.987
# newTCF: 0.7476
# ('Midnight Express', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.097
# newTCF: 0.7754
# ('Excel', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.141
# newTCF: 0.7155
# ('Ran Tan II', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 4.248
# newTCF: 1.064
# ('Flying Fox', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.32
# newTCF: 0.77525
# ('Am Meer', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.151
# newTCF: 0.71525
# ('Jet', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.212
# newTCF: 0.7355
# ('Gucci', 'Offshore')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.011
# newTCF: 0.7518
# ('Prime Mover', 'Offshore')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.104
# newTCF: 0.7752
# ('Clear Vision', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.354
# newTCF: 0.786
# ('Nedax Racing', 'Offshore')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.304
# newTCF: 0.8276
# ('The Guarantee', 'Offshore')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.311
# newTCF: 0.8296
# ('Jive Talkin', 'Offshore')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.584
# newTCF: 0.8635
# ('Wiseguy', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.799
# newTCF: 0.699
# ('Marishka', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.488
# newTCF: 0.6214
# ('Wellington Spirit Bronze', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.988
# newTCF: 0.7472
# ('Haumuri', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.934
# newTCF: 0.646
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.9
# newTCF: 0.7264
# ('Blue Magic', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.967
# newTCF: 0.7422
# ('Rona', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.757
# newTCF: 0.58425
# ('White Cavalier', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.341
# newTCF: 0.5844
# ('Blue Magic', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.9
# newTCF: 0.7252
# ('Saucy Sausage', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.528
# newTCF: 0.632
# ('Rosschild', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.584
# newTCF: 0.6454
# ('Wellington Spirit Bronze', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.972
# newTCF: 0.7448
# ('Vendetta', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.805
# newTCF: 0.702
# ('Haumuri', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.599
# newTCF: 0.649
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.966
# newTCF: 0.7408
# ('Wellington Spirit Bronze', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.015
# newTCF: 0.7524
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.136
# newTCF: 0.7838
# ('Blue Magic', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.961
# newTCF: 0.7406
# ('White Cavalier', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.118
# newTCF: 0.5292
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.903
# newTCF: 0.7258
# ('Wiseguy', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.776
# newTCF: 0.695
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.974
# newTCF: 0.7442
# ('Rosschild', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.509
# newTCF: 0.628
# ('Marishka', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.475
# newTCF: 0.6192
# ('Brix', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.819
# newTCF: 0.7066
# ('St Laurence', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 3.127
# newTCF: 1.045
# ('Saucy Sausage', 'Two-handed')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.909
# newTCF: 0.63475
# ('Eat My Shorts', 'Two-handed')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.954
# newTCF: 0.7374
# ('Titus Canby', 'Two-handed')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.753
# newTCF: 0.6874
# ('White Cavalier', 'Two-handed')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.337
# newTCF: 0.584
# ('Testarossa', 'Two-handed')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.041
# newTCF: 0.7606
# ('Whistler III', 'Two-handed')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.908
# newTCF: 0.727
# ('After Midnight', 'Two-handed')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.846
# newTCF: 0.7126
# ('Saucy Sausage', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.547
# newTCF: 0.6358
# ('Gucci', 'Rum')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.938
# newTCF: 0.734
# ('Illusions', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.05
# newTCF: 0.682
# ('Wellington Spirit Bronze', 'Rum')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.978
# newTCF: 0.7446
# ('Charlie', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.368
# newTCF: 0.5914
# ('Rona', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.333
# newTCF: 0.5834
# ('White Cavalier', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.328
# newTCF: 0.5824
# ('Eat My Shorts', 'Rum')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.955
# newTCF: 0.739
# ('Rosschild', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.577
# newTCF: 0.6444
# ('Vendetta', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.786
# newTCF: 0.6976
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.622
# newTCF: 0.9026
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.238
# newTCF: 0.808
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.382
# newTCF: 0.8446
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.606
# newTCF: 0.9014
# ('Structural Analysis', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.337
# newTCF: 0.781
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.919
# newTCF: 0.9822
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.297
# newTCF: 0.825
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.864
# newTCF: 0.7142
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.967
# newTCF: 0.7416
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.057
# newTCF: 0.763
# ('Testarossa', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.284
# newTCF: 0.76025
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.954
# newTCF: 0.7378
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.921
# newTCF: 0.7294
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.034
# newTCF: 0.7576
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.03
# newTCF: 0.7576
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.971
# newTCF: 0.742
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.833
# newTCF: 0.7086
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.707
# newTCF: 0.6786
# ('Brix', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.891
# newTCF: 0.7238
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.672
# newTCF: 0.6678
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.677
# newTCF: 0.6694
# ('Illusions', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.975
# newTCF: 0.65825
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.467
# newTCF: 0.6178
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.73
# newTCF: 0.6834
# ('Marishka', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.461
# newTCF: 0.6158
# ('Rosschild', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.569
# newTCF: 0.643
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.2
# newTCF: 0.5512
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.644
# newTCF: 0.9094
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.626
# newTCF: 0.9054
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.394
# newTCF: 0.8478
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.903
# newTCF: 0.977
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.252
# newTCF: 0.812
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.293
# newTCF: 0.8236
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.067
# newTCF: 0.7654
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.957
# newTCF: 0.739
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.061
# newTCF: 0.7648
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.862
# newTCF: 0.7152
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.947
# newTCF: 0.7378
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.928
# newTCF: 0.7314
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.844
# newTCF: 0.7106
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.017
# newTCF: 0.755
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.971
# newTCF: 0.7426
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.001
# newTCF: 0.7518
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.678
# newTCF: 0.6714
# ('Brix', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.863
# newTCF: 0.7174
# ('Wellington Spirit Bronze', 'Rum')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.006
# newTCF: 0.7502
# ('Eat My Shorts', 'Rum')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.945
# newTCF: 0.7368
# ('Blurred Image', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.753
# newTCF: 0.6882
# ('Black Diamond', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.377
# newTCF: 0.793
# ('Wai-Aniwa', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.608
# newTCF: 0.6532
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.71
# newTCF: 0.6758
# ('Marishka', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.48
# newTCF: 0.6192
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.684
# newTCF: 0.6704
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.737
# newTCF: 0.684
# ('Rosschild', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.561
# newTCF: 0.6408
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 3.069
# newTCF: 0.7668
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 3.041
# newTCF: 0.7592
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.971
# newTCF: 0.7428
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.957
# newTCF: 0.7392
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.083
# newTCF: 0.7696
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.961
# newTCF: 0.7398
# ('Wellington Spirit Bronze', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.893
# newTCF: 0.725
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.906
# newTCF: 0.7274
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.658
# newTCF: 0.6658
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.816
# newTCF: 0.7054
# ('Wellington Spirit Green', 'Championship')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.287
# newTCF: 0.76425
# ('Brix', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.85
# newTCF: 0.7134
# ('Blurred Image', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.772
# newTCF: 0.692
# ('Blue Magic', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.915
# newTCF: 0.728
# ('After Midnight', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.123
# newTCF: 0.70625
# ('Eat My Shorts', 'Rum')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.954
# newTCF: 0.7382
# ('Gucci', 'Rum')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.955
# newTCF: 0.7378
# ('Black Diamond', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.17
# newTCF: 0.7926
# ('Wellington Spirit Red', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.303
# newTCF: 0.76775
# ('Saucy Sausage', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.54
# newTCF: 0.6352
# ('Charlie', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.364
# newTCF: 0.591
# ('White Cavalier', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.312
# newTCF: 0.5788
# ('Vendetta', 'Rum')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.763
# newTCF: 0.6922
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.715
# newTCF: 0.6782
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.676
# newTCF: 0.6692
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.739
# newTCF: 0.6846
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.178
# newTCF: 0.5458
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.46
# newTCF: 0.6156
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.252
# newTCF: 0.8128
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.884
# newTCF: 0.9722
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.405
# newTCF: 0.8506
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.651
# newTCF: 0.9112
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 3.002
# newTCF: 0.7484
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.97
# newTCF: 0.7426
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.88
# newTCF: 0.719
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 3.105
# newTCF: 0.7744
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.098
# newTCF: 0.7736
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.98
# newTCF: 0.7438
# ('Brix', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.813
# newTCF: 0.7052
# ('Wellington Spirit Green', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.051
# newTCF: 0.763
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.899
# newTCF: 0.7252
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.638
# newTCF: 0.6608
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.955
# newTCF: 0.7414
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.916
# newTCF: 0.7308
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.772
# newTCF: 0.6954
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 3.005
# newTCF: 0.7528
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.966
# newTCF: 0.7414
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 3.115
# newTCF: 0.7778
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.906
# newTCF: 0.7262
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 2.993
# newTCF: 0.7472
# ('Brix', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.812
# newTCF: 0.7034
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.984
# newTCF: 0.7464
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.964
# newTCF: 0.7416
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 3.083
# newTCF: 0.7714
# ('Wellington Spirit Green', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.021
# newTCF: 0.7568
# ('Black Diamond', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.424
# newTCF: 0.806
# ('Rocket Science', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.463
# newTCF: 0.819
# ('C U', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.4
# newTCF: 0.8
# ('Magic Trick', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.7
# newTCF: 0.90225
# ('Revs', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.716
# newTCF: 0.90675
# ('Jive Talkin', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.643
# newTCF: 0.88325
# ('Whistler III', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.252
# newTCF: 0.74975
# ('Bacchante', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.164
# newTCF: 0.721
# ('Testarossa', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.334
# newTCF: 0.778
# ('After Midnight', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.183
# newTCF: 0.72725
# ('Airship', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.254
# newTCF: 0.75175
# ('Saucy Sausage', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.86
# newTCF: 0.619
# ('Blue Magic', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.197
# newTCF: 0.732
# ('Titus Canby', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.055
# newTCF: 0.685
# ('Gucci', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.29
# newTCF: 0.76525
# ('Prime Mover', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.238
# newTCF: 0.746
# ('Incantare', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.003
# newTCF: 0.666
# ('Wai-Aniwa', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.023
# newTCF: 0.67525
# ('Haumuri', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.987
# newTCF: 0.664
# ('Wiseguy', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.081
# newTCF: 0.694
# ('Brix', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.103
# newTCF: 0.7015
# ('White Cavalier', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.654
# newTCF: 0.55
# ('Slingshot', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.236
# newTCF: 0.74725
# ('Wellington Spirit Red', 'PNR')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.248
# newTCF: 0.75125
# ('Black Diamond', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.233
# newTCF: 0.8078
# ('C U', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.203
# newTCF: 0.8006
# ('Magic Trick', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.575
# newTCF: 0.8954
# ('Rocket Science', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.282
# newTCF: 0.8202
# ('Revs', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.596
# newTCF: 0.9006
# ('Jive Talkin', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.5
# newTCF: 0.8766
# ('Bacchante', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.907
# newTCF: 0.7256
# ('Prime Mover', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.006
# newTCF: 0.7504
# ('Whistler III', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.002
# newTCF: 0.7504
# ('Haumuri', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.666
# newTCF: 0.666
# ('Titus Canby', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.748
# newTCF: 0.6866
# ('Airship', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.99
# newTCF: 0.7484
# ('Saucy Sausage', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.481
# newTCF: 0.62
# ('Blue Magic', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.926
# newTCF: 0.7316
# ('Incantare', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.689
# newTCF: 0.671
# ('Gucci', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.032
# newTCF: 0.7594
# ('Testarossa', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.089
# newTCF: 0.7734
# ('Wiseguy', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.775
# newTCF: 0.6938
# ('After Midnight', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.888
# newTCF: 0.723
# ('Wai-Aniwa', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.678
# newTCF: 0.6706
# ('Brix', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.785
# newTCF: 0.6972
# ('White Cavalier', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.218
# newTCF: 0.5536
# ('Slingshot', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.961
# newTCF: 0.7416
# ('Wellington Spirit Red', 'PNR')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.976
# newTCF: 0.7454
# ('C U', 'PNR')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.222
# newTCF: 0.8046
# ('Black Diamond', 'PNR')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.241
# newTCF: 0.8098
# ('Magic Trick', 'PNR')
# numValuesUsed: 5
# fromIdx: 1
# ...
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.831
# newTCF: 0.7066
# ('Rocket Science', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.314
# newTCF: 0.8276
# ('Marishka', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.86
# newTCF: 0.6185
# ('Whistler III', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.869
# newTCF: 0.7164
# ('Revs', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.539
# newTCF: 0.8832
# ('Saucy Sausage', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.526
# newTCF: 0.6308
# ('Floating Free', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.867
# newTCF: 0.7158
# ('Airship', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.935
# newTCF: 0.7334
# ('Blurred Image', 'Island Bay')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.062
# newTCF: 0.6865
# ('Gucci', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.005
# newTCF: 0.7514
# ('Eat My Shorts', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.939
# newTCF: 0.7348
# ('Wiseguy', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.789
# newTCF: 0.6978
# ('Titus Canby', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.713
# newTCF: 0.679
# ('Charlie', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.284
# newTCF: 0.5716
# ('Rosschild', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.5
# newTCF: 0.6258
# ('The Guarantee', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.35
# newTCF: 0.839
# ('Ran Tan II', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 4.116
# newTCF: 1.0308
# ('St Laurence', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 4.133
# newTCF: 1.0352
# ('Blue Magic', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.954
# newTCF: 0.7396
# ('Prime Mover', 'Island Bay')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.989
# newTCF: 0.7486
# ('White Cavalier', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.139
# newTCF: 0.5336
# ('Wellington Spirit Red', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.04
# newTCF: 0.7598
# ('Magic Trick', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.658
# newTCF: 0.886
# ('Wiseguy', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.77
# newTCF: 0.693
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.886
# newTCF: 0.7224
# ('Maranui', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 1.636
# newTCF: 0.54675
# ('White Cavalier', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.165
# newTCF: 0.5398
# ('Wiseguy', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.804
# newTCF: 0.6994
# ('Gucci', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.987
# newTCF: 0.7464
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.971
# newTCF: 0.743
# ('Brix', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.801
# newTCF: 0.7016
# ('Airship', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.202
# newTCF: 0.73425
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.86
# newTCF: 0.7164
# ('Black Diamond', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.356
# newTCF: 0.78725
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.087
# newTCF: 0.7742
# ('Blue Magic', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.937
# newTCF: 0.7356
# ('White Cavalier', 'Rum')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.327
# newTCF: 0.5812
# ('Black Diamond', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.192
# newTCF: 0.797
# ('Wellington Spirit Purple', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.327
# newTCF: 0.77375
# ('Illusions', 'Rum')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.732
# newTCF: 0.6828
# ('Brix', 'Rum')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.109
# newTCF: 0.70475
# ('Gucci', 'Rum')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.937
# newTCF: 0.735
# ('Rona', 'Rum')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.319
# newTCF: 0.5804
# ('Testarossa', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.282
# newTCF: 0.75875
# ('Wellington Spirit Red', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.058
# newTCF: 0.7636
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.983
# newTCF: 0.7452
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.873
# newTCF: 0.7178
# ('Blue Magic', 'Fleet')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.923
# newTCF: 0.7318
# ('Prime Mover', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.006
# newTCF: 0.752
# ('Gucci', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.98
# newTCF: 0.7452
# ('Illusions', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.008
# newTCF: 0.671
# ('Marishka', 'Fleet')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.46
# newTCF: 0.6158
# ('The Guarantee', 'Fleet')
# numValuesUsed: 4
# fromIdx: 0
# sumTCFclmps: 2.53
# newTCF: 0.8455
# ('White Cavalier', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.181
# newTCF: 0.5442
# ('Gucci', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.983
# newTCF: 0.7456
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.972
# newTCF: 0.7426
# ('Airship', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.937
# newTCF: 0.7342
# ('Wiseguy', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.786
# newTCF: 0.697
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.853
# newTCF: 0.7142
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.951
# newTCF: 0.7392
# ('Incantare', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.769
# newTCF: 0.6936
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.064
# newTCF: 0.7676
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 3.307
# newTCF: 0.8254
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.402
# newTCF: 0.8506
# ('Structural Analysis', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.122
# newTCF: 0.7806
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.77
# newTCF: 0.9426
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.23
# newTCF: 0.8086
# ('Magic Trick', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.634
# newTCF: 0.9086
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.825
# newTCF: 0.9576
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 3.619
# newTCF: 0.9058
# ('Ran Tan II', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.838
# newTCF: 0.961
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 2.654
# newTCF: 0.663
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 2.99
# newTCF: 0.7464
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 3.13
# newTCF: 0.7816
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.888
# newTCF: 0.7226
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.963
# newTCF: 0.7408
# ('Brix', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.817
# newTCF: 0.704
# ('Montego Bay III', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.799
# newTCF: 0.6998
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.932
# newTCF: 0.7324
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 2.766
# newTCF: 0.6922
# ('Airship', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 2.988
# newTCF: 0.748
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.877
# newTCF: 0.7202
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 13
# sumTCFclmps: 2.983
# newTCF: 0.7468
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 13
# sumTCFclmps: 3.029
# newTCF: 0.7594
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.19
# newTCF: 0.5472
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.499
# newTCF: 0.6238
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.703
# newTCF: 0.6758
# ('Rosschild', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.511
# newTCF: 0.6292
# ('Revenue Cutter', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.554
# newTCF: 0.6394
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.741
# newTCF: 0.6852
# ('Marishka', 'Championship')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.469
# newTCF: 0.6184
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.673
# newTCF: 0.6684
# ('Structural Analysis', 'Fleet')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.093
# newTCF: 0.7722
# ('White Cavalier', 'Fleet')
# numValuesUsed: 5
# fromIdx: 4
# sumTCFclmps: 2.211
# newTCF: 0.551
# ('Black Diamond', 'Fleet')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 3.167
# newTCF: 0.7908
# ('Brix', 'Fleet')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.803
# newTCF: 0.701
# ('Airship', 'Fleet')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 2.936
# newTCF: 0.734
# ('Gucci', 'Fleet')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.996
# newTCF: 0.7484
# ('After Midnight', 'Fleet')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 2.825
# newTCF: 0.7078
# ('Whistler III', 'Fleet')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.943
# newTCF: 0.7364
# ('Eat My Shorts', 'Fleet')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.967
# newTCF: 0.742
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.904
# newTCF: 0.7254
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 13
# sumTCFclmps: 2.978
# newTCF: 0.7448
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 14
# sumTCFclmps: 2.979
# newTCF: 0.7452
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 14
# sumTCFclmps: 3.015
# newTCF: 0.7548
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 3.129
# newTCF: 0.7822
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.947
# newTCF: 0.7376
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 2.921
# newTCF: 0.7306
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.511
# newTCF: 0.627
# ('Marishka', 'Championship')
# numValuesUsed: 5
# fromIdx: 5
# sumTCFclmps: 2.486
# newTCF: 0.6208
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.69
# newTCF: 0.6732
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.716
# newTCF: 0.6802
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.26
# newTCF: 0.8138
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.799
# newTCF: 0.9484
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 3.605
# newTCF: 0.9022
# ('Structural Analysis', 'Championship')
# numValuesUsed: 5
# fromIdx: 1
# sumTCFclmps: 3.116
# newTCF: 0.7794
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 3.387
# newTCF: 0.8476
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 3.308
# newTCF: 0.8266
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.778
# newTCF: 0.9472
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 2.678
# newTCF: 0.6682
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 15
# sumTCFclmps: 3.035
# newTCF: 0.758
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 13
# sumTCFclmps: 2.782
# newTCF: 0.6948
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 15
# sumTCFclmps: 2.992
# newTCF: 0.7474
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 2.933
# newTCF: 0.7328
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 14
# sumTCFclmps: 2.983
# newTCF: 0.7456
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.902
# newTCF: 0.7254
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 3.125
# newTCF: 0.7814
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.858
# newTCF: 0.7156
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 2.916
# newTCF: 0.7308
# ('Wellington Spirit Red', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.934
# newTCF: 0.7344
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.208
# newTCF: 0.551
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.699
# newTCF: 0.6744
# ('Revenue Cutter', 'Championship')
# numValuesUsed: 5
# fromIdx: 3
# sumTCFclmps: 2.578
# newTCF: 0.6434
# ('Rosschild', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.53
# newTCF: 0.6318
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.7
# newTCF: 0.676
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.514
# newTCF: 0.6282
# ('Marishka', 'Championship')
# numValuesUsed: 5
# fromIdx: 6
# sumTCFclmps: 2.455
# newTCF: 0.6152
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.642
# newTCF: 0.662
# ('Maranui', 'Championship')
# numValuesUsed: 5
# fromIdx: 0
# sumTCFclmps: 2.189
# newTCF: 0.548
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 3.283
# newTCF: 0.8194
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 3.617
# newTCF: 0.9038
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.792
# newTCF: 0.948
# ('Rocket Science', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 3.309
# newTCF: 0.8272
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 3.38
# newTCF: 0.8456
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.766
# newTCF: 0.9426
# ('Structural Analysis', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 3.085
# newTCF: 0.7728
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 13
# sumTCFclmps: 2.706
# newTCF: 0.6748
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 15
# sumTCFclmps: 3.027
# newTCF: 0.7546
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 16
# sumTCFclmps: 3.041
# newTCF: 0.7598
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 14
# sumTCFclmps: 2.796
# newTCF: 0.6982
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 2.918
# newTCF: 0.7286
# ('Eat My Shorts', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 2.9
# newTCF: 0.7262
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 16
# sumTCFclmps: 2.975
# newTCF: 0.7444
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 13
# sumTCFclmps: 2.905
# newTCF: 0.7276
# ('Floating Free', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.833
# newTCF: 0.7098
# ('Testarossa', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 3.096
# newTCF: 0.7754
# ('White Cavalier', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.225
# newTCF: 0.5552
# ('Titus Canby', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 2.713
# newTCF: 0.6774
# ('Saucy Sausage', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 2.508
# newTCF: 0.6272
# ('Wai-Aniwa', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 2.682
# newTCF: 0.6716
# ('Marishka', 'Championship')
# numValuesUsed: 5
# fromIdx: 7
# sumTCFclmps: 2.428
# newTCF: 0.6086
# ('Haumuri', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 2.616
# newTCF: 0.6556
# ('The Guarantee', 'Championship')
# numValuesUsed: 5
# fromIdx: 10
# sumTCFclmps: 3.328
# newTCF: 0.8294
# ('Revs', 'Championship')
# numValuesUsed: 5
# fromIdx: 13
# sumTCFclmps: 3.637
# newTCF: 0.9082
# ('Blink', 'Championship')
# numValuesUsed: 5
# fromIdx: 9
# sumTCFclmps: 3.726
# newTCF: 0.9338
# ('Wedgetail', 'Championship')
# numValuesUsed: 5
# fromIdx: 8
# sumTCFclmps: 3.821
# newTCF: 0.9538
# ('Drinks Trolley', 'Championship')
# numValuesUsed: 5
# fromIdx: 11
# sumTCFclmps: 3.376
# newTCF: 0.8444
# ('Incantare', 'Championship')
# numValuesUsed: 5
# fromIdx: 14
# sumTCFclmps: 2.746
# newTCF: 0.6842
# ('Gucci', 'Championship')
# numValuesUsed: 5
# fromIdx: 17
# sumTCFclmps: 3.058
# newTCF: 0.7636
# ('Prime Mover', 'Championship')
# numValuesUsed: 5
# fromIdx: 16
# sumTCFclmps: 3.018
# newTCF: 0.7546
# ('Blue Magic', 'Championship')
# numValuesUsed: 5
# fromIdx: 12
# sumTCFclmps: 2.905
# newTCF: 0.7268
# ('After Midnight', 'Championship')
# numValuesUsed: 5
# fromIdx: 14
# sumTCFclmps: 2.887
# newTCF: 0.723
# ('Whistler III', 'Championship')
# numValuesUsed: 5
# fromIdx: 17
# sumTCFclmps: 2.973
# newTCF: 0.7434
# ('Wiseguy', 'Championship')
# numValuesUsed: 5
# fromIdx: 15
# sumTCFclmps: 2.774
# newTCF: 0.6944
# ('Wellington Spirit Green', 'Championship')
# numValuesUsed: 5
# fromIdx: 2
# sumTCFclmps: 2.985
# newTCF: 0.7484

# %%
dfTCF.tail(20)
# Out:
#                                                    Boat name Elapsed time  ETsecs  corrSecs  refTime  RankAppld  Rank rankDiff   PHRF    IRC  TCFapplied  TCFactual  TCFdiff  TCFst  pctMvmt  TCFclmp  newTCF
# Date   Handicap     Series Race Div
# 12 Apr Championship Autumn r4   3                  Wai-Aniwa      1:59:34    7174      4849     4802          4     4        -  0.690    NaN       0.676      0.676   -0.000  0.669    -1.04    0.669   0.672
#                                 3                   Marishka      2:12:42    7962      4896     4802          5     5        -  0.650    NaN       0.615      0.615    0.000  0.603    -1.95    0.603   0.609
#                                 3                    Haumuri      2:13:16    7996      5293     4802          6     6        -  0.665    NaN       0.662      0.662    0.000  0.601    -9.21    0.642   0.656
#                            r5   1             Rocket Science        <dnf>     NaN       NaN      NaN        NaN   NaN      NaN    NaN    NaN         NaN        NaN      NaN    NaN      NaN      NaN     NaN
#                                 1        Structural Analysis        <dnf>     NaN       NaN      NaN        NaN   NaN      NaN    NaN    NaN         NaN        NaN      NaN    NaN      NaN      NaN     NaN
#                                 1              The Guarantee      2:22:54    8574      7022     7572          1     1        -  0.845    NaN       0.819      0.819    0.000  0.883     7.81    0.844   0.829
#                                 1                       Revs      2:13:11    7991      7223     7572          2     2        -  0.890  1.234       0.903      0.904   -0.001  0.948     4.87    0.931   0.908
#                                 1                      Blink      2:13:50    8030      7572     7572          3     3        -  0.960    NaN       0.943      0.943    0.000  0.943     0.00    0.943   0.934
#                                 1                  Wedgetail      2:13:23    8003      7586     7572          4     4        -  0.950  1.208       0.948      0.948    0.000  0.946    -0.21    0.946   0.954
#                                 1             Drinks Trolley      2:29:47    8987      7603     7572          5     5        -  0.840    NaN       0.845      0.846   -0.001  0.843    -0.35    0.843   0.844
#                                 2              Eat My Shorts        <dnf>     NaN       NaN      NaN        NaN   NaN      NaN    NaN    NaN         NaN        NaN      NaN    NaN      NaN      NaN     NaN
#                                 2                 Testarossa        <dnf>     NaN       NaN      NaN        NaN   NaN      NaN    NaN    NaN         NaN        NaN      NaN    NaN      NaN      NaN     NaN
#                                 2                  Incantare      2:17:42    8262      5576     5735          1     1        -  0.725    NaN       0.676      0.675    0.001  0.694     2.81    0.694   0.684
#                                 2                      Gucci      2:05:23    7523      5717     5735          2     2        -  0.755  0.963       0.761      0.760    0.001  0.762     0.26    0.762   0.764
#                                 2                Prime Mover      2:06:35    7595      5734     5735          3     3        -  0.765  0.964       0.756      0.755    0.001  0.755     0.00    0.755   0.755
#                                 2                 Blue Magic      2:11:07    7867      5735     5735          4     4        -  0.740  0.955       0.730      0.729    0.001  0.729     0.00    0.729   0.727
#                                 2             After Midnight      2:14:14    8054      5863     5735          5     5        -  0.720    NaN       0.729      0.728    0.001  0.712    -2.20    0.712   0.723
#                                 2               Whistler III      2:11:37    7897      5875     5735          6     6        -  0.730  0.950       0.746      0.744    0.002  0.726    -2.42    0.726   0.743
#                                 2                    Wiseguy      2:25:53    8753      6109     5735          7     7        -  0.725    NaN       0.699      0.698    0.001  0.655    -6.16    0.677   0.694
#                                 2    Wellington Spirit Green      2:18:45    8325      6302     5735          8     8        -  0.790    NaN       0.765      0.757    0.008  0.689    -8.98    0.734   0.748

# %%
dfTCF[cols].to_csv('AllTCFs.csv', sep = ',')

# %%
TCFclampHistoryAndSeeds
# Out:
# {('After Midnight', 'Championship'): [0.719,
#   0.719,
#   0.741,
#   0.709,
#   0.722,
#   0.745,
#   0.728,
#   0.726,
#   0.729,
#   0.723,
#   0.721,
#   0.733,
#   0.748,
#   0.73,
#   0.71,
#   0.745,
#   0.72,
#   0.712],
#  ('After Midnight', 'Fleet'): [0.719,
#   0.719,
#   0.719,
#   0.719,
#   0.741,
#   0.723,
#   0.738,
#   0.729,
#   0.71,
#   0.726,
#   0.721,
#   0.703,
#   0.723,
#   0.706,
#   0.693],
#  ('After Midnight', 'Island Bay'): [0.702, 0.702, 0.704, 0.723],
#  ('After Midnight', 'PNR'): [0.726,
#   0.726,
#   0.731,
#   0.705,
#   0.745,
#   0.725,
#   0.704,
#   0.701,
#   0.719,
#   0.714],
#  ('After Midnight', 'Rum'): [0.702, 0.702, 0.719],
#  ('After Midnight', 'Two-handed'): [0.716, 0.716, 0.719, 0.695],
#  ('Airship', 'Championship'): [0.743,
#   0.743,
#   0.765,
#   0.756,
#   0.751,
#   0.753,
#   0.733,
#   0.772,
#   0.741,
#   0.772,
#   0.749,
#   0.755,
#   0.765,
#   0.736,
#   0.753,
#   0.734],
#  ('Airship', 'Fleet'): [0.735, 0.735, 0.732, 0.735, 0.734],
#  ('Airship', 'Island Bay'): [0.737, 0.737, 0.716, 0.745],
#  ('Airship', 'PNR'): [0.753,
#   0.753,
#   0.748,
#   0.736,
#   0.747,
#   0.724,
#   0.74,
#   0.724,
#   0.753],
#  ('Alice Bee', 'Rum'): [],
#  ('Am Meer', 'Offshore'): [0.71, 0.71, 0.731],
#  ('Bacchante', 'PNR'): [0.72,
#   0.72,
#   0.724,
#   0.743,
#   0.748,
#   0.754,
#   0.762,
#   0.752,
#   0.776,
#   0.771],
#  ('Badonkadonk', 'PNR'): [0.867, 0.867, 0.841, 0.835],
#  ('Black Diamond', 'Fleet'): [0.793, 0.793, 0.77, 0.811],
#  ('Black Diamond', 'PNR'): [0.8,
#   0.8,
#   0.824,
#   0.809,
#   0.808,
#   0.817,
#   0.82,
#   0.837,
#   0.809],
#  ('Black Diamond', 'Rum'): [0.795, 0.795, 0.787, 0.793, 0.817],
#  ('Blink', 'Championship'): [0.95,
#   0.95,
#   0.921,
#   0.971,
#   0.932,
#   0.972,
#   0.976,
#   0.931,
#   0.983,
#   0.935,
#   0.929,
#   0.919,
#   0.943],
#  ('Blink', 'Fleet'): [0.95, 0.95, 0.95, 0.921],
#  ('Blink', 'Island Bay'): [0.963, 0.963, 0.992],
#  ('Blink', 'Offshore'): [1.01, 1.01, 0.98, 1.032],
#  ('Blink', 'Two-handed'): [0.98, 0.98, 0.951],
#  ('Blue Magic', 'Championship'): [0.739,
#   0.739,
#   0.761,
#   0.755,
#   0.74,
#   0.749,
#   0.733,
#   0.746,
#   0.721,
#   0.716,
#   0.709,
#   0.742,
#   0.737,
#   0.714,
#   0.725,
#   0.729],
#  ('Blue Magic', 'Fleet'): [0.735,
#   0.735,
#   0.752,
#   0.743,
#   0.75,
#   0.722,
#   0.746,
#   0.719,
#   0.736],
#  ('Blue Magic', 'Island Bay'): [0.744, 0.744, 0.744, 0.722],
#  ('Blue Magic', 'Offshore'): [0.73, 0.73, 0.752, 0.735],
#  ('Blue Magic', 'PNR'): [0.731,
#   0.731,
#   0.735,
#   0.729,
#   0.723,
#   0.725,
#   0.717,
#   0.746,
#   0.72,
#   0.732],
#  ('Blue Magic', 'Rum'): [0.732, 0.732, 0.71, 0.726, 0.747],
#  ('Blurred Image', 'Championship'): [0.684, 0.684, 0.687, 0.664, 0.681],
#  ('Blurred Image', 'Fleet'): [0.685, 0.685, 0.677],
#  ('Blurred Image', 'Island Bay'): [0.684, 0.684, 0.694],
#  ('Blurred Image', 'Rum'): [0.69, 0.69, 0.669, 0.706, 0.688, 0.709],
#  ('Brix', 'Championship'): [0.73,
#   0.73,
#   0.708,
#   0.747,
#   0.706,
#   0.702,
#   0.695,
#   0.71,
#   0.705,
#   0.707],
#  ('Brix', 'Fleet'): [0.725, 0.725, 0.703, 0.698, 0.693, 0.707, 0.705],
#  ('Brix', 'PNR'): [0.703, 0.703, 0.697, 0.682, 0.676, 0.676, 0.663, 0.675],
#  ('Brix', 'Rum'): [0.71, 0.71, 0.689],
#  ('C U', 'PNR'): [0.8, 0.8, 0.8, 0.803, 0.819, 0.805, 0.806, 0.816],
#  ('Cantilena', 'Championship'): [],
#  ('Charlie', 'Championship'): [0.58, 0.58, 0.595, 0.566],
#  ('Charlie', 'Fleet'): [0.571, 0.571, 0.588],
#  ('Charlie', 'Island Bay'): [0.57, 0.57, 0.587, 0.557],
#  ('Charlie', 'Rum'): [0.58, 0.58, 0.597, 0.602, 0.589, 0.576],
#  ('Clear Vision', 'Offshore'): [0.79, 0.79, 0.774],
#  ('Drinks Trolley', 'Championship'): [0.824,
#   0.824,
#   0.848,
#   0.821,
#   0.843,
#   0.833,
#   0.836,
#   0.859,
#   0.854,
#   0.845,
#   0.847,
#   0.856,
#   0.839,
#   0.838,
#   0.843],
#  ('Drinks Trolley', 'Island Bay'): [0.824, 0.824, 0.844],
#  ('Drinks Trolley', 'PNR'): [0.851, 0.851, 0.829, 0.845, 0.844],
#  ('Eat My Shorts', 'Championship'): [0.742,
#   0.742,
#   0.72,
#   0.74,
#   0.721,
#   0.753,
#   0.746,
#   0.717,
#   0.738,
#   0.756,
#   0.746,
#   0.74,
#   0.722,
#   0.738,
#   0.716,
#   0.724],
#  ('Eat My Shorts', 'Fleet'): [0.745,
#   0.745,
#   0.723,
#   0.75,
#   0.741,
#   0.726,
#   0.739,
#   0.76,
#   0.747,
#   0.721],
#  ('Eat My Shorts', 'Island Bay'): [0.73, 0.73, 0.748, 0.731],
#  ('Eat My Shorts', 'Rum'): [0.743,
#   0.743,
#   0.721,
#   0.759,
#   0.738,
#   0.74,
#   0.718,
#   0.749,
#   0.747],
#  ('Eat My Shorts', 'Two-handed'): [0.733, 0.733, 0.733, 0.755],
#  ('Erazer', 'Rum'): [0.712, 0.712, 0.712],
#  ('Excel', 'Offshore'): [0.721, 0.721, 0.699],
#  ('Floating Free', 'Championship'): [0.705,
#   0.705,
#   0.693,
#   0.723,
#   0.704,
#   0.709,
#   0.728,
#   0.721,
#   0.722,
#   0.732,
#   0.702,
#   0.702,
#   0.697],
#  ('Floating Free', 'Fleet'): [0.709, 0.709, 0.712],
#  ('Floating Free', 'Island Bay'): [0.707, 0.707, 0.728, 0.725],
#  ('Flying Fox', 'Offshore'): [0.781, 0.781, 0.758],
#  ('Gucci', 'Championship'): [0.762,
#   0.762,
#   0.739,
#   0.741,
#   0.752,
#   0.751,
#   0.748,
#   0.77,
#   0.777,
#   0.737,
#   0.773,
#   0.774,
#   0.785,
#   0.773,
#   0.751,
#   0.76,
#   0.745,
#   0.759,
#   0.771,
#   0.766,
#   0.762],
#  ('Gucci', 'Fleet'): [0.75,
#   0.75,
#   0.746,
#   0.752,
#   0.729,
#   0.76,
#   0.739,
#   0.755,
#   0.742],
#  ('Gucci', 'Island Bay'): [0.755, 0.755, 0.743, 0.752],
#  ('Gucci', 'Offshore'): [0.746, 0.746, 0.767, 0.728, 0.77],
#  ('Gucci', 'PNR'): [0.771,
#   0.771,
#   0.748,
#   0.742,
#   0.741,
#   0.762,
#   0.727,
#   0.722,
#   0.73,
#   0.714],
#  ('Gucci', 'Rum'): [0.754,
#   0.754,
#   0.731,
#   0.726,
#   0.734,
#   0.73,
#   0.748,
#   0.743,
#   0.716],
#  ('Gucci', 'Two-handed'): [0.751, 0.751, 0.737],
#  ('Haumuri', 'Championship'): [0.678,
#   0.678,
#   0.669,
#   0.656,
#   0.685,
#   0.652,
#   0.679,
#   0.668,
#   0.677,
#   0.649,
#   0.648,
#   0.642],
#  ('Haumuri', 'Fleet'): [0.65, 0.65, 0.634, 0.665],
#  ('Haumuri', 'Island Bay'): [],
#  ('Haumuri', 'PNR'): [0.669,
#   0.669,
#   0.649,
#   0.679,
#   0.669,
#   0.666,
#   0.646,
#   0.65,
#   0.672],
#  ('Illusions', 'Championship'): [0.658, 0.658, 0.659],
#  ('Illusions', 'Fleet'): [0.676, 0.676, 0.656],
#  ('Illusions', 'Offshore'): [],
#  ('Illusions', 'PNR'): [0.658, 0.658, 0.658, 0.678, 0.68, 0.676],
#  ('Illusions', 'Rum'): [0.678, 0.678, 0.694, 0.682],
#  ('Incantare', 'Championship'): [0.697,
#   0.697,
#   0.718,
#   0.723,
#   0.701,
#   0.714,
#   0.692,
#   0.688,
#   0.68,
#   0.674,
#   0.665,
#   0.659,
#   0.66,
#   0.654,
#   0.681,
#   0.683,
#   0.688,
#   0.694],
#  ('Incantare', 'Fleet'): [0.704, 0.704, 0.683, 0.678],
#  ('Incantare', 'Island Bay'): [0.701, 0.701, 0.685],
#  ('Incantare', 'PNR'): [0.661,
#   0.661,
#   0.681,
#   0.686,
#   0.685,
#   0.697,
#   0.706,
#   0.71,
#   0.703,
#   0.706],
#  ('Jet', 'Offshore'): [0.73, 0.73, 0.752],
#  ('Jive Talkin', 'Offshore'): [0.87, 0.87, 0.844],
#  ('Jive Talkin', 'PNR'): [0.89,
#   0.89,
#   0.863,
#   0.857,
#   0.851,
#   0.858,
#   0.859,
#   0.843,
#   0.842],
#  ('Khamsin', 'Offshore'): [0.756, 0.756, 0.756],
#  ('Lizzie', 'Classics'): [],
#  ('Loloma', 'Classics'): [],
#  ('Magic Trick', 'Championship'): [0.891,
#   0.891,
#   0.891,
#   0.879,
#   0.862,
#   0.908,
#   0.911,
#   0.885,
#   0.918,
#   0.93,
#   0.901],
#  ('Magic Trick', 'Fleet'): [0.886, 0.886, 0.886],
#  ('Magic Trick', 'Island Bay'): [0.891, 0.891, 0.918],
#  ('Magic Trick', 'PNR'): [0.909,
#   0.909,
#   0.882,
#   0.875,
#   0.885,
#   0.88,
#   0.893,
#   0.87],
#  ('Marangi', 'Championship'): [],
#  ('Maranui', 'Championship'): [0.55, 0.55, 0.555, 0.534],
#  ('Maranui', 'Fleet'): [0.551, 0.551, 0.534],
#  ('Maranui', 'Island Bay'): [0.55, 0.55, 0.559],
#  ('Marishka', 'Championship'): [0.614,
#   0.614,
#   0.614,
#   0.632,
#   0.601,
#   0.633,
#   0.63,
#   0.605,
#   0.618,
#   0.602,
#   0.603],
#  ('Marishka', 'Fleet'): [0.615, 0.615, 0.633, 0.625, 0.602, 0.6],
#  ('Marishka', 'Island Bay'): [0.614, 0.614, 0.632],
#  ('Marishka', 'Rum'): [],
#  ('Midnight Express', 'Offshore'): [0.78, 0.78, 0.78, 0.757],
#  ('Montego Bay III', 'Championship'): [0.719,
#   0.719,
#   0.697,
#   0.692,
#   0.687,
#   0.722,
#   0.698],
#  ('Montego Bay III', 'Fleet'): [],
#  ('Montego Bay III', 'Island Bay'): [0.724, 0.724, 0.746],
#  ('Montego Bay III', 'Offshore'): [0.739, 0.739, 0.748],
#  ('Montego Bay III', 'Rum'): [0.72, 0.72, 0.722],
#  ('Montego Bay III', 'Two-handed'): [0.728, 0.728, 0.706],
#  ('Nedax Racing', 'Championship'): [0.832,
#   0.832,
#   0.821,
#   0.829,
#   0.829,
#   0.814,
#   0.836],
#  ('Nedax Racing', 'Offshore'): [0.84, 0.84, 0.815, 0.809],
#  ('Oreti', 'Classics'): [],
#  ('Port Nic 1', 'Fleet'): [],
#  ('Port Nic 2', 'Fleet'): [],
#  ('Prime Mover', 'Championship'): [0.761,
#   0.761,
#   0.738,
#   0.744,
#   0.73,
#   0.751,
#   0.764,
#   0.724,
#   0.721,
#   0.758,
#   0.744,
#   0.738,
#   0.762,
#   0.74,
#   0.724,
#   0.764,
#   0.75,
#   0.745,
#   0.768,
#   0.755],
#  ('Prime Mover', 'Fleet'): [0.76, 0.76, 0.737, 0.749],
#  ('Prime Mover', 'Island Bay'): [0.756, 0.756, 0.746, 0.731],
#  ('Prime Mover', 'Offshore'): [0.76, 0.76, 0.783, 0.789, 0.772],
#  ('Prime Mover', 'PNR'): [0.746,
#   0.746,
#   0.746,
#   0.768,
#   0.728,
#   0.75,
#   0.764,
#   0.775,
#   0.748],
#  ('Ran Tan II', 'Championship'): [1.0,
#   1.0,
#   0.978,
#   1.008,
#   0.996,
#   0.996,
#   0.965,
#   0.962,
#   0.98,
#   0.977,
#   0.943,
#   0.938],
#  ('Ran Tan II', 'Island Bay'): [1.044, 1.044, 1.021, 1.007],
#  ('Ran Tan II', 'Offshore'): [1.08, 1.08, 1.048, 1.04],
#  ('Ran Tan II', 'Rum'): [1.04, 1.04, 1.071],
#  ('Revenue Cutter', 'Championship'): [0.652,
#   0.652,
#   0.633,
#   0.628,
#   0.661,
#   0.632,
#   0.657],
#  ('Revs', 'Championship'): [0.894,
#   0.894,
#   0.905,
#   0.91,
#   0.906,
#   0.9,
#   0.902,
#   0.878,
#   0.925,
#   0.901,
#   0.922,
#   0.903,
#   0.911,
#   0.883,
#   0.908,
#   0.915,
#   0.931],
#  ('Revs', 'Island Bay'): [0.87, 0.87, 0.896, 0.903],
#  ('Revs', 'Offshore'): [0.884, 0.884, 0.882, 0.892],
#  ('Revs', 'PNR'): [0.911,
#   0.911,
#   0.894,
#   0.88,
#   0.893,
#   0.908,
#   0.921,
#   0.895,
#   0.93],
#  ('Revs', 'Rum'): [0.885, 0.885, 0.912],
#  ('Rocket Science', 'Championship'): [0.83,
#   0.83,
#   0.805,
#   0.826,
#   0.798,
#   0.795,
#   0.785,
#   0.826,
#   0.801,
#   0.826,
#   0.799,
#   0.826,
#   0.837,
#   0.845,
#   0.8,
#   0.827],
#  ('Rocket Science', 'Fleet'): [0.813, 0.813, 0.789],
#  ('Rocket Science', 'Island Bay'): [0.83, 0.83, 0.805, 0.849],
#  ('Rocket Science', 'PNR'): [0.813, 0.813, 0.837, 0.819, 0.827, 0.815, 0.849],
#  ('Rona', 'Classics'): [],
#  ('Rona', 'Rum'): [0.58, 0.58, 0.597, 0.576, 0.566],
#  ('Rosschild', 'Championship'): [0.63,
#   0.63,
#   0.649,
#   0.635,
#   0.648,
#   0.659,
#   0.627,
#   0.627,
#   0.622,
#   0.635,
#   0.646],
#  ('Rosschild', 'Fleet'): [0.626, 0.626, 0.645, 0.612],
#  ('Rosschild', 'Island Bay'): [0.625, 0.625, 0.64, 0.61],
#  ('Rosschild', 'Rum'): [0.633, 0.633, 0.652, 0.657, 0.642, 0.626],
#  ('Rosschild', 'Two-handed'): [],
#  ('Saucy Sausage', 'Championship'): [0.629,
#   0.629,
#   0.629,
#   0.64,
#   0.612,
#   0.609,
#   0.624,
#   0.622,
#   0.605,
#   0.634,
#   0.638,
#   0.634,
#   0.608,
#   0.628],
#  ('Saucy Sausage', 'Fleet'): [0.623, 0.623, 0.642, 0.609],
#  ('Saucy Sausage', 'Island Bay'): [0.632, 0.632, 0.615, 0.647],
#  ('Saucy Sausage', 'PNR'): [0.616,
#   0.616,
#   0.628,
#   0.621,
#   0.622,
#   0.607,
#   0.607,
#   0.633,
#   0.636,
#   0.62],
#  ('Saucy Sausage', 'Rum'): [0.632, 0.632, 0.632, 0.632, 0.651, 0.625],
#  ('Saucy Sausage', 'Two-handed'): [0.63, 0.63, 0.649],
#  ('Sirrah', 'Offshore'): [0.74, 0.74, 0.731],
#  ('Slingshot', 'PNR'): [0.753,
#   0.753,
#   0.73,
#   0.725,
#   0.72,
#   0.712,
#   0.714,
#   0.741,
#   0.743,
#   0.729],
#  ('St Laurence', 'Championship'): [],
#  ('St Laurence', 'Fleet'): [1.053, 1.053, 1.021],
#  ('St Laurence', 'Island Bay'): [1.051, 1.051, 1.019, 1.012],
#  ('Structural Analysis', 'Championship'): [0.787,
#   0.787,
#   0.763,
#   0.785,
#   0.781,
#   0.756],
#  ('Structural Analysis', 'Fleet'): [0.793,
#   0.793,
#   0.769,
#   0.784,
#   0.809,
#   0.774,
#   0.762,
#   0.791,
#   0.76,
#   0.751,
#   0.791],
#  ('Structural Analysis', 'Rum'): [0.791, 0.791, 0.775],
#  ('Testarossa', 'Championship'): [0.757,
#   0.757,
#   0.77,
#   0.783,
#   0.773,
#   0.772,
#   0.787,
#   0.798,
#   0.772,
#   0.768,
#   0.758],
#  ('Testarossa', 'Fleet'): [0.753, 0.753, 0.776],
#  ('Testarossa', 'PNR'): [0.778,
#   0.778,
#   0.778,
#   0.755,
#   0.796,
#   0.753,
#   0.755,
#   0.761,
#   0.782,
#   0.74],
#  ('Testarossa', 'Two-handed'): [0.765, 0.765, 0.751, 0.76],
#  ('The Guarantee', 'Championship'): [0.848,
#   0.848,
#   0.823,
#   0.82,
#   0.819,
#   0.85,
#   0.825,
#   0.803,
#   0.815,
#   0.799,
#   0.813,
#   0.833,
#   0.838,
#   0.844],
#  ('The Guarantee', 'Fleet'): [0.852, 0.852, 0.826],
#  ('The Guarantee', 'Island Bay'): [0.85, 0.85, 0.83, 0.82],
#  ('The Guarantee', 'Offshore'): [0.845, 0.845, 0.82, 0.834, 0.812],
#  ('The Guarantee', 'PNR'): [0.824, 0.824, 0.849, 0.855, 0.854],
#  ('The Guarantee', 'Rum'): [0.845, 0.845, 0.87],
#  ('Titus Canby', 'Championship'): [0.689,
#   0.689,
#   0.697,
#   0.691,
#   0.67,
#   0.682,
#   0.707,
#   0.671,
#   0.677,
#   0.684,
#   0.664,
#   0.678,
#   0.664,
#   0.693,
#   0.678],
#  ('Titus Canby', 'Island Bay'): [0.687, 0.687, 0.666, 0.673],
#  ('Titus Canby', 'PNR'): [0.685,
#   0.685,
#   0.685,
#   0.693,
#   0.68,
#   0.687,
#   0.665,
#   0.662,
#   0.672,
#   0.676],
#  ('Titus Canby', 'Two-handed'): [0.68, 0.68, 0.697, 0.696],
#  ('Vendetta', 'Offshore'): [0.71, 0.71, 0.731, 0.72],
#  ('Vendetta', 'Rum'): [0.7, 0.7, 0.721, 0.684, 0.681, 0.677],
#  ('Wai-Aniwa', 'Championship'): [0.676,
#   0.676,
#   0.656,
#   0.691,
#   0.654,
#   0.676,
#   0.689,
#   0.696,
#   0.687,
#   0.669,
#   0.664,
#   0.68,
#   0.669],
#  ('Wai-Aniwa', 'Island Bay'): [0.659, 0.659, 0.679],
#  ('Wai-Aniwa', 'Offshore'): [0.67, 0.67, 0.69, 0.695],
#  ('Wai-Aniwa', 'PNR'): [0.678,
#   0.678,
#   0.667,
#   0.655,
#   0.671,
#   0.67,
#   0.686,
#   0.662,
#   0.669,
#   0.67],
#  ('Wai-Aniwa', 'Rum'): [0.664, 0.664, 0.644, 0.659, 0.667, 0.638],
#  ('Wai-Aniwa', 'Two-handed'): [0.69, 0.69, 0.677],
#  ('Wedgetail', 'Championship'): [0.945,
#   0.945,
#   0.96,
#   0.925,
#   0.948,
#   0.942,
#   0.965,
#   0.917,
#   0.946,
#   0.971,
#   0.958,
#   0.946],
#  ('Wedgetail', 'Island Bay'): [0.933, 0.933, 0.955],
#  ('Wedgetail', 'Offshore'): [0.943, 0.943, 0.931, 0.959],
#  ('Wedgetail', 'Rum'): [0.945, 0.945, 0.973],
#  ('Wellington Spirit Bronze', 'Championship'): [0.77,
#   0.77,
#   0.756,
#   0.745,
#   0.74,
#   0.758,
#   0.728,
#   0.722,
#   0.716,
#   0.727],
#  ('Wellington Spirit Bronze', 'Fleet'): [0.765,
#   0.765,
#   0.746,
#   0.739,
#   0.755,
#   0.746,
#   0.748,
#   0.766],
#  ('Wellington Spirit Bronze', 'Rum'): [0.763,
#   0.763,
#   0.749,
#   0.736,
#   0.758,
#   0.729,
#   0.755,
#   0.764],
#  ('Wellington Spirit Green', 'Championship'): [0.77,
#   0.77,
#   0.747,
#   0.764,
#   0.74,
#   0.734],
#  ('Wellington Spirit Purple', 'Rum'): [0.768, 0.768, 0.791],
#  ('Wellington Spirit Red', 'Championship'): [0.77,
#   0.77,
#   0.747,
#   0.764,
#   0.775,
#   0.741,
#   0.75,
#   0.735,
#   0.729,
#   0.752,
#   0.747,
#   0.719,
#   0.716],
#  ('Wellington Spirit Red', 'Fleet'): [0.765, 0.765, 0.742, 0.768, 0.783],
#  ('Wellington Spirit Red', 'PNR'): [0.757,
#   0.757,
#   0.734,
#   0.728,
#   0.723,
#   0.715,
#   0.708,
#   0.698,
#   0.692],
#  ('Wellington Spirit Red', 'Rum'): [0.768, 0.768, 0.767],
#  ('Whistler III', 'Championship'): [0.719,
#   0.719,
#   0.741,
#   0.746,
#   0.712,
#   0.752,
#   0.714,
#   0.738,
#   0.752,
#   0.756,
#   0.725,
#   0.738,
#   0.752,
#   0.755,
#   0.748,
#   0.752,
#   0.728,
#   0.751,
#   0.761,
#   0.735,
#   0.726],
#  ('Whistler III', 'Fleet'): [0.725,
#   0.725,
#   0.725,
#   0.747,
#   0.751,
#   0.743,
#   0.755,
#   0.725,
#   0.748,
#   0.755,
#   0.723,
#   0.717],
#  ('Whistler III', 'Island Bay'): [0.716, 0.716, 0.703, 0.734],
#  ('Whistler III', 'PNR'): [0.747,
#   0.747,
#   0.758,
#   0.75,
#   0.728,
#   0.737,
#   0.766,
#   0.762,
#   0.76,
#   0.736],
#  ('Whistler III', 'Two-handed'): [0.723, 0.723, 0.739, 0.723],
#  ('White Cavalier', 'Championship'): [0.572,
#   0.572,
#   0.555,
#   0.566,
#   0.55,
#   0.545,
#   0.539,
#   0.544,
#   0.562,
#   0.563,
#   0.556],
#  ('White Cavalier', 'Fleet'): [0.524,
#   0.524,
#   0.54,
#   0.53,
#   0.545,
#   0.55,
#   0.556,
#   0.56],
#  ('White Cavalier', 'Island Bay'): [0.572, 0.572, 0.57],
#  ('White Cavalier', 'PNR'): [0.546,
#   0.546,
#   0.562,
#   0.564,
#   0.571,
#   0.572,
#   0.583,
#   0.588,
#   0.583],
#  ('White Cavalier', 'Rum'): [0.581, 0.581, 0.581, 0.598, 0.568, 0.565, 0.596],
#  ('White Cavalier', 'Two-handed'): [0.579, 0.579, 0.596, 0.583],
#  ('Wiseguy', 'Championship'): [0.706,
#   0.706,
#   0.706,
#   0.72,
#   0.73,
#   0.712,
#   0.7,
#   0.695,
#   0.718,
#   0.728,
#   0.692,
#   0.706,
#   0.69,
#   0.684,
#   0.699,
#   0.693,
#   0.706,
#   0.698,
#   0.677],
#  ('Wiseguy', 'Fleet'): [0.701, 0.701, 0.68, 0.717, 0.678, 0.695, 0.714, 0.699],
#  ('Wiseguy', 'Island Bay'): [0.701, 0.701, 0.695, 0.692],
#  ('Wiseguy', 'PNR'): [0.695,
#   0.695,
#   0.691,
#   0.694,
#   0.711,
#   0.705,
#   0.691,
#   0.679,
#   0.694],
#  ('Wiseguy', 'Rum'): [0.702, 0.702, 0.681],
#  ('Young Nicholson', 'Offshore'): [0.8, 0.8, 0.817]}

# %%
# !tail -n 20 AllTCFs.csv
# Out:
# 12 Apr,Championship,Autumn,r4,3,Wai-Aniwa,1:59:34,7174.0,4849.0,4802.0,4.0,4.0,-,0.69,,0.6759999999999999,0.676,-0.0,0.669,-1.04,0.669,0.672
# 12 Apr,Championship,Autumn,r4,3,Marishka,2:12:42,7962.0,4896.0,4802.0,5.0,5.0,-,0.65,,0.615,0.615,0.0,0.603,-1.95,0.603,0.609
# 12 Apr,Championship,Autumn,r4,3,Haumuri,2:13:16,7996.0,5293.0,4802.0,6.0,6.0,-,0.665,,0.662,0.662,0.0,0.601,-9.21,0.642,0.656
# 12 Apr,Championship,Autumn,r5,1,Rocket Science,<dnf>,,,,,,,,,,,,,,,
# 12 Apr,Championship,Autumn,r5,1,Structural Analysis,<dnf>,,,,,,,,,,,,,,,
# 12 Apr,Championship,Autumn,r5,1,The Guarantee,2:22:54,8574.0,7022.0,7572.0,1.0,1.0,-,0.845,,0.8190000000000001,0.819,0.0,0.883,7.81,0.844,0.829
# 12 Apr,Championship,Autumn,r5,1,Revs,2:13:11,7991.0,7223.0,7572.0,2.0,2.0,-,0.89,1.234,0.903,0.904,-0.001,0.948,4.87,0.931,0.908
# 12 Apr,Championship,Autumn,r5,1,Blink,2:13:50,8030.0,7572.0,7572.0,3.0,3.0,-,0.96,,0.943,0.943,0.0,0.943,0.0,0.943,0.934
# 12 Apr,Championship,Autumn,r5,1,Wedgetail,2:13:23,8003.0,7586.0,7572.0,4.0,4.0,-,0.95,1.208,0.948,0.948,0.0,0.946,-0.21,0.946,0.954
# 12 Apr,Championship,Autumn,r5,1,Drinks Trolley,2:29:47,8987.0,7603.0,7572.0,5.0,5.0,-,0.84,,0.845,0.846,-0.001,0.843,-0.35,0.843,0.844
# 12 Apr,Championship,Autumn,r5,2,Eat My Shorts,<dnf>,,,,,,,,,,,,,,,
# 12 Apr,Championship,Autumn,r5,2,Testarossa,<dnf>,,,,,,,,,,,,,,,
# 12 Apr,Championship,Autumn,r5,2,Incantare,2:17:42,8262.0,5576.0,5735.0,1.0,1.0,-,0.725,,0.6759999999999999,0.675,0.001,0.694,2.81,0.694,0.684
# 12 Apr,Championship,Autumn,r5,2,Gucci,2:05:23,7523.0,5717.0,5735.0,2.0,2.0,-,0.755,0.963,0.7609999999999999,0.76,0.001,0.762,0.26,0.762,0.764
# 12 Apr,Championship,Autumn,r5,2,Prime Mover,2:06:35,7595.0,5734.0,5735.0,3.0,3.0,-,0.765,0.9640000000000001,0.7559999999999999,0.755,0.001,0.755,0.0,0.755,0.755
# 12 Apr,Championship,Autumn,r5,2,Blue Magic,2:11:07,7867.0,5735.0,5735.0,4.0,4.0,-,0.74,0.955,0.73,0.729,0.001,0.729,0.0,0.729,0.727
# 12 Apr,Championship,Autumn,r5,2,After Midnight,2:14:14,8054.0,5863.0,5735.0,5.0,5.0,-,0.72,,0.7290000000000001,0.728,0.001,0.712,-2.2,0.712,0.723
# 12 Apr,Championship,Autumn,r5,2,Whistler III,2:11:37,7897.0,5875.0,5735.0,6.0,6.0,-,0.73,0.95,0.746,0.744,0.002,0.726,-2.42,0.726,0.743
# 12 Apr,Championship,Autumn,r5,2,Wiseguy,2:25:53,8753.0,6109.0,5735.0,7.0,7.0,-,0.725,,0.6990000000000001,0.698,0.001,0.655,-6.16,0.677,0.694
# 12 Apr,Championship,Autumn,r5,2,Wellington Spirit Green,2:18:45,8325.0,6302.0,5735.0,8.0,8.0,-,0.79,,0.765,0.757,0.008,0.689,-8.98,0.734,0.748
