# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import re

pd.set_option('display.line_width',10000)
pd.set_option('display.precision', 4)

#datapath = "C:\\Phil\\My Dropbox\\Sailing cmte\\Handicapping\\2012-13 season\\Proc'd CSVs\\"
datapath = "/Users/PhilBishop/Dropbox/Sailing cmte/Handicapping/2012-13 season/Proc'd CSVs/"

# %%
id9  = pd.read_csv(datapath + 'ManaPicton_id9_TCF.csv', sep=',')
id30 = pd.read_csv(datapath + 'UnderwoodChetMana_id30_TCF.csv', sep=',')
id35 = pd.read_csv(datapath + 'Nelson_id35_TCF.csv', sep=',')
id41 = pd.read_csv(datapath + 'KapitiShipCove_id41_TCF.csv', sep=',')
id61 = pd.read_csv(datapath + 'Brothers_id61_TCF.csv', sep=',')

# %%
new1 = pd.merge(id9, id30, how='outer')
new2 = pd.merge(new1, id35, how='outer')
new3 = pd.merge(new2, id41, how='outer')
new4 = pd.merge(new3, id61, how='outer')
new4
# Out:
#           Boat name  TCF_id9  TCF_id30  TCF_id35  TCF_id41  TCF_id61
# 0   Montego Bay III    0.740      0.74     0.740     0.740     0.736
# 1             Gucci    0.745       NaN     0.745       NaN     0.749
# 2            Fulmar    0.770       NaN       NaN     0.770     0.766
# 3       Prime Mover      NaN       NaN       NaN       NaN       NaN
# 4              Revs      NaN      0.88     0.885     0.883     0.888
# 5         Wedgetail      NaN      0.94     0.946       NaN       NaN
# 6      Nedax Racing      NaN      0.84     0.839       NaN     0.840
# 7     The Guarantee      NaN      0.85     0.846     0.840       NaN
# 8      Clear Vision      NaN       NaN       NaN       NaN     0.790
# 9         Wai-Aniwa      NaN       NaN     0.670       NaN       NaN
# 10              Jet      NaN       NaN     0.730       NaN       NaN
# 11         Blackout      NaN       NaN     0.805       NaN       NaN
# 12       Oldsmobile      NaN       NaN     0.815       NaN       NaN
# ...

# %%
new4.to_csv(datapath  + 'Offshore TCFs' + '.csv', sep = ',')

# %%
id10 = pd.read_csv(datapath + 'Rum_id10_TCF.csv', sep=',')
id11 = pd.read_csv(datapath + 'Rum_id11_TCF.csv', sep=',')
id12 = pd.read_csv(datapath + 'Rum_id12_TCF.csv', sep=',')
id16 = pd.read_csv(datapath + 'Rum_id16_TCF.csv', sep=',')
id19 = pd.read_csv(datapath + 'Rum_id19_TCF.csv', sep=',')
id22 = pd.read_csv(datapath + 'Rum_id22_TCF.csv', sep=',')
id28 = pd.read_csv(datapath + 'Rum_id28_TCF.csv', sep=',')
id34 = pd.read_csv(datapath + 'Rum_id34_TCF.csv', sep=',')
id36 = pd.read_csv(datapath + 'Rum_id36_TCF.csv', sep=',')
id39 = pd.read_csv(datapath + 'Rum_id39_TCF.csv', sep=',')
id42 = pd.read_csv(datapath + 'Rum_id42_TCF.csv', sep=',')
id47 = pd.read_csv(datapath + 'Rum_id47_TCF.csv', sep=',')
id53 = pd.read_csv(datapath + 'Rum_id53_TCF.csv', sep=',')
id57 = pd.read_csv(datapath + 'Rum_id57_TCF.csv', sep=',')
id60 = pd.read_csv(datapath + 'Rum_id60_TCF.csv', sep=',')
id63 = pd.read_csv(datapath + 'Rum_id63_TCF.csv', sep=',')

# %%
new1 = pd.merge(id10, id11, how='outer')
new2 = pd.merge(new1, id12, how='outer')
new3 = pd.merge(new2, id16, how='outer')
new4 = pd.merge(new3, id19, how='outer')
new5 = pd.merge(new4, id22, how='outer')
new6 = pd.merge(new5, id28, how='outer')
new7 = pd.merge(new6, id34, how='outer')
new8 = pd.merge(new7, id36, how='outer')
new9 = pd.merge(new8, id39, how='outer')
new10 = pd.merge(new9, id42, how='outer')
new11 = pd.merge(new10, id47, how='outer')
new12 = pd.merge(new11, id53, how='outer')
new13 = pd.merge(new12, id57, how='outer')
new14 = pd.merge(new13, id60, how='outer')
new15 = pd.merge(new14, id63, how='outer')

# %%
new15
# Out:
#                       Boat name  TCF_id10  TCF_id11  TCF_id12  TCF_id16  TCF_id19  TCF_id22  TCF_id28  TCF_id34  TCF_id36  TCF_id39  TCF_id42  TCF_id47  TCF_id53  TCF_id57  TCF_id60  TCF_id63
# 0                White Cavalier     0.572       NaN     0.572       NaN     0.575       NaN       NaN     0.577     0.577     0.582     0.588     0.588     0.592     0.590       NaN       NaN
# 1                     Rosschild     0.625       NaN     0.625       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN     0.629     0.634       NaN
# 2                After Midnight       NaN     0.702       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      Wellington Spirit Bronze       NaN     0.770     0.770       NaN       NaN     0.769       NaN     0.769     0.769     0.768     0.764       NaN       NaN       NaN       NaN       NaN
# ...

# %%
new15.to_csv(datapath  + 'Rum race TCFs' + '.csv', sep = ',')
