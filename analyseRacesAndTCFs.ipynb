# %% [markdown]
# ### analyseRacesAndTCFs - This notebook is a work in progress - it takes the output from computeTCFs and does a bunch of race and TCF analysis

# %%
inputFile = 'AllTCFs - without IB and veterans duplicated.csv'

handicapFilter = ''
divisionFilter = ''
#handicapFilter = 'Championship'
#divisionFilter = ''
# enter '' for no filter
# Handicap types in 2013-14 season: Championship, Classics, Fleet, Island Bay, Offshore, PNR, Rum, and Two-handed.
# Division types in 2013-14 season: 1, 2, 3, A, B, Combined, and Open.

ostype = 'windows'        # Enter mac or windows
rotateThreshold = 9  # rotate x-axis labels if more labels than threshold 

import pandas as pd
import datetime as dt
import dateutil
#import eaplots.plots as eap
#import eaplots.reportwriter as eaprw
#import matplotlib.pyplot as plt
#import matplotlib.ticker as tkr
import cStringIO
import math
import os

if ostype == 'windows':
    ostype = 'C:\\Users\\bishopp\\Dropbox'
else:
    ostype = '/Users/PhilBishop/Dropbox'

datapath = os.path.join(ostype, 'Python', 'Sailing')
outputDir = os.path.join(datapath, 'Plots', handicapFilter)

# Make output folder if it doesn't already exist
if not os.path.exists(outputDir):
    os.makedirs(outputDir)

pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.line_width',10000)
pd.set_option('display.max_columns',10000)
pd.set_option('display.max_rows',10000)
pd.set_option('display.max_colwidth',10000)
pd.set_option('display.max_info_columns',10000)
pd.set_option('display.height',1000)
pd.set_option('display.max_seq_items',100)
pd.set_option('display.multi_sparse', True)

todaysDate = dt.datetime.strftime(dt.datetime.now(), "%d %B %Y")
#reportTitle = 'TCF report - ' + handicapFilter + ' - Div ' + divisionFilter
#reportTitle = 'TCF report - ' + 'Port Nicholson Regatta - Div ' + divisionFilter
reportTitle = 'TCF report - ' + handicapFilter + ' - Combined Fleet'
subtitle = todaysDate
secondPageTitle = "Notes"
footerText = reportTitle
bullets = ["Applied TCF is the TCF that was used on race day to compute corrected times on club handicap",
           "Actual TCF is the value the Applied TCF should have been if the race scoring software was programmed \
            precisely according to the TCF update formula",
           "Sailed-to TCF is a measure of how a boat performed on the day relative to the reference, or median, \
            boat for the fleet",
           "Clamped TCF is the clamped sailed-to TCF that feeds into the formula used to adjust TCFs ahead of \
            the next race. The clamps for 2013-14 were +/- 3.0%",
           "In the plots below, there are some boats that have no TCF data on particular days. This indicates that \
            the boat raced, or at least showed up to race, but was not given a score, e.g. the boat retired after \
            finishing, was not entered, etc."]

# Read in the TCF data from a CSV file
TCFdata = pd.read_csv(os.path.join(datapath,inputFile),sep=',',parse_dates=True,dayfirst=True)
TCFdata.head()
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)
#
# height has been deprecated.
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-bd4d655f7279> in <module>()
#      64
#      65 # Read in the TCF data from a CSV file
# ---> 66 TCFdata = pd.read_csv(os.path.join(datapath,inputFile),sep=',',parse_dates=True,dayfirst=True)
#      67 TCFdata.head()
#
# C:\Python27\lib\site-packages\pandas-0.14.1-py2.7-win-amd64.egg\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# C:\Python27\lib\site-packages\pandas-0.14.1-py2.7-win-amd64.egg\pandas\io\parsers.pyc in _read(filepath_or_buffer, kwds)
#     232
#     233     # Create the parser.
# --> 234     parser = TextFileReader(filepath_or_buffer, **kwds)
#     235
#     236     if (nrows is not None) and (chunksize is not None):
#
# C:\Python27\lib\site-packages\pandas-0.14.1-py2.7-win-amd64.egg\pandas\io\parsers.pyc in __init__(self, f, engine, **kwds)
#     540             self.options['has_index_names'] = kwds['has_index_names']
#     541
# --> 542         self._make_engine(self.engine)
#     543
#     544     def _get_options_with_defaults(self, engine):
#
# C:\Python27\lib\site-packages\pandas-0.14.1-py2.7-win-amd64.egg\pandas\io\parsers.pyc in _make_engine(self, engine)
#     677     def _make_engine(self, engine='c'):
#     678         if engine == 'c':
# --> 679             self._engine = CParserWrapper(self.f, **self.options)
#     680         else:
#     681             if engine == 'python':
#
# C:\Python27\lib\site-packages\pandas-0.14.1-py2.7-win-amd64.egg\pandas\io\parsers.pyc in __init__(self, src, **kwds)
#    1039         kwds['allow_leading_cols'] = self.index_col is not False
#    1040
# -> 1041         self._reader = _parser.TextReader(src, **kwds)
#    1042
#    1043         # XXX
#
# C:\Python27\lib\site-packages\pandas-0.14.1-py2.7-win-amd64.egg\pandas\parser.pyd in pandas.parser.TextReader.__cinit__ (pandas\parser.c:3218)()
#
# C:\Python27\lib\site-packages\pandas-0.14.1-py2.7-win-amd64.egg\pandas\parser.pyd in pandas.parser.TextReader._setup_parser_source (pandas\parser.c:5594)()
#
# IOError: File C:\Users\bishopp\Dropbox\Python\Sailing\AllTCFs - without IB and veterans duplicated.csv does not exist

# %%
# Filter out all but the specified handicap and division types
if not handicapFilter:
    TCFdata = TCFdata
else:
    if not divisionFilter:
        TCFdata = TCFdata[TCFdata['Handicap']==handicapFilter]
    else:
        TCFdata = TCFdata[TCFdata['Handicap']==handicapFilter][TCFdata['Div']==divisionFilter]

# Replace the nan's with zeroes
TCFdata.fillna(value=0)

# Get a unique list of boats from TCFdata and sort boats alphabetically
boats = list(set(TCFdata['Boat name']))
boats.sort()

# Rename some columns in TCFdata so that filed names look prettier
TCFdata.rename(columns={'TCFapplied': 'Applied TCF', 'TCFactual': 'Actual TCF', \
                        'TCFst': 'Sailed-to TCF',    'TCFclmp': 'Clamped TCF'}, inplace=True)

# Select columns to pull out of TCFdata and put into boatData
boatcols = ['Date','PHRF','Applied TCF','Actual TCF','Sailed-to TCF','Clamped TCF','Series','Race']

TCFdata[boatcols].head(5)
#TCFdata[boatcols].tail(5)
# Out:
#      Date   PHRF  Applied TCF  Actual TCF  Sailed-to TCF  Clamped TCF  Series Race
# 0  22-Mar  0.950        0.943       0.943          0.946        0.946  Autumn   r1
# 1  22-Mar  0.960        0.964       0.963          0.935        0.935  Autumn   r1
# 2  22-Mar  0.875        0.910       0.909          0.901        0.901  Autumn   r1
# 3  22-Mar  1.040        0.967       0.967          0.886        0.938  Autumn   r1
# 4  22-Mar  0.890        0.909       0.910          0.881        0.883  Autumn   r1

# %%
# Count race days and races
countShowUps  = TCFdata['Date'].count()
countRaceDays = TCFdata['Date'].drop_duplicates().count()

print \
'Number boats showing up to race:', countShowUps, '\n' \
'Number of race days:            ', countRaceDays
# Out:
# Number boats showing up to race: 969
# Number of race days:             45

# %%
# Count boats
boatCounts = TCFdata.groupby(['Series','Race','Div']).count()
boatCounts['Showed up'] = boatCounts['Boat name']
boatCounts['Scored']    = boatCounts['ETsecs']
boatCounts['No result'] = boatCounts['Showed up'] - boatCounts['Scored']
boatCounts['No result %'] = 100 * boatCounts['No result'] / boatCounts['Showed up']
bcCols = ['Showed up', 'Scored', 'No result', 'No result %']

boatCounts[bcCols].to_csv('boatCounts.csv', sep = ',')
boatCounts[bcCols]
# Out:
#                                          Showed up  Scored  No result  No result %
# Series     Race                Div
# At Home    r1                  Combined         10      10          0            0
#            r2                  Combined          4       4          0            0
#            r3                  Combined          6       6          0            0
#            r4                  Combined         13      13          0            0
#            r5                  Combined          8       6          2           25
# Autumn     r1                  1                 9       9          0            0
#                                2                13      13          0            0
#                                3                 8       8          0            0
#            r2                  1                 3       1          2           66
#                                2                 8       7          1           12
#                                3                 4       4          0            0
#            r3                  1                 7       7          0            0
#                                2                11      11          0            0
#                                3                 9       9          0            0
#            r4                  1                 7       7          0            0
#                                2                10      10          0            0
#                                3                 7       6          1           14
#            r5                  1                 7       5          2           28
#                                2                10       8          2           20
# Christmas  r1                  1                 6       4          2           33
#                                2                 9       9          0            0
#                                3                 8       7          1           12
#            r2                  1                 9       9          0            0
#                                2                12      12          0            0
#                                3                 9       9          0            0
#            r3                  1                 9       9          0            0
#                                2                12      12          0            0
# Classics   r1                  Combined          3       3          0            0
#            r2                  Combined          2       1          1           50
#            r3                  Combined          2       2          0            0
#            r4                  Combined          3       3          0            0
#            r5                  Combined          2       2          0            0
#            r6                  Combined          4       4          0            0
# Island Bay r1                  1                 8       8          0            0
#                                2                11      11          0            0
#                                3                 7       6          1           14
#                                Open              1       1          0            0
#            r2                  1                 4       4          0            0
#                                2                 9       9          0            0
#                                3                 7       7          0            0
#                                Open              1       1          0            0
# New Year   r1                  1                 7       7          0            0
#                                2                12      12          0            0
#                                3                 8       8          0            0
#            r2                  1                 7       6          1           14
#                                2                12      12          0            0
#                                3                 6       5          1           16
#            r3                  1                 3       1          2           66
#                                2                12      12          0            0
#                                3                 5       5          0            0
#            r4                  1                 6       4          2           33
#                                2                14      14          0            0
#            r5                  1                 2       2          0            0
#                                2                10       9          1           10
# Offshore   Bay of Many Coves   Combined          5       1          4           80
#            Brothers            Combined         13      13          0            0
#            Cook Strait Classic Combined         16      16          0            0
#            Nelson              Combined          9       8          1           11
# PNR        r1                  A                 9       6          3           33
#                                B                19      18          1            5
#            r2                  A                 9       6          3           33
#                                B                19      18          1            5
#            r3                  A                 9       6          3           33
#                                B                19      18          1            5
#            r4                  A                 9       5          4           44
#                                B                19      18          1            5
#            r5                  A                 9       4          5           55
#                                B                19      14          5           26
#            r6                  A                 9       9          0            0
#                                B                19      19          0            0
#            r7                  A                 9       9          0            0
#                                B                19      18          1            5
#            r8                  A                 9       5          4           44
#                                B                19      17          2           10
# Rum        r1                  Combined         18      13          5           27
#            r10                 Combined          8       7          1           12
#            r2                  Combined          7       7          0            0
#            r3                  Combined          7       7          0            0
#            r4                  Combined          5       5          0            0
#            r5                  Combined          8       7          1           12
#            r6                  Combined         10      10          0            0
#            r7                  Combined          5       5          0            0
#            r8                  Combined         11      11          0            0
#            r9                  Combined          7       3          4           57
# Special    Anzac               Combined          5       3          2           40
#            Commodore's Trophy  Combined         24      24          0            0
#            Crews               Combined         10      10          0            0
# Spring     r1                  1                 2       2          0            0
#                                2                 7       7          0            0
#                                3                 4       3          1           25
#                                Open              1       1          0            0
#            r2                  1                 8       8          0            0
#                                2                12      12          0            0
#                                3                 5       4          1           20
#                                Open              1       1          0            0
#            r3                  1                 8       8          0            0
#                                2                11      11          0            0
#                                3                 8       8          0            0
#            r4                  1                 8       8          0            0
#                                2                12      12          0            0
# Twilight 1 r1                  Combined          2       2          0            0
#            r2                  Combined          7       7          0            0
#            r3                  Combined         10      10          0            0
#            r4                  Combined          7       7          0            0
#            r5                  Combined         10      10          0            0
# Twilight 2 r1                  Combined         11      10          1            9
#            r2                  Combined         11       9          2           18
#            r3                  Combined         10       9          1           10
# Two-handed r1                  Combined         10      10          0            0
#            r2                  Combined          7       7          0            0
#            r3                  Combined          9       3          6           66

# %%
# More counts - counts apply to a filtered dataframe

if not handicapFilter:
    print 'All handicaps'
else:
    print 'Handicap:', handicapFilter
if not divisionFilter:
    print 'All divisions', '\n'
else:
    print 'Division:', divisionFilter, '\n'

# Count of unique boats
boatCount = int(TCFdata['Boat name'].drop_duplicates().count())
print 'Unique count of boats: ' + str(boatCount) + '\n'

# Get boat count by handicap 
filtercols = ['Handicap','Boat name'] ;
boatsByHandicap = TCFdata[filtercols]
countsByHandicap = boatsByHandicap.drop_duplicates().groupby('Handicap').count()['Boat name']
print 'Unique boat count by:', countsByHandicap, '\n'

# Figure out the list of unique <xxx> codes assigned to boats not scored
filtercols = ['Handicap','Boat name','Elapsed time']
raced = TCFdata[filtercols]
codes = [] # Collect list of all unique <xxx> codes
for code in TCFdata['Elapsed time'].drop_duplicates():
    if code.startswith('<'):
        codes.append(code)    

# Loop through each code type and print out boats for that code
print 'Count of boats not scored by code:'
for code in codes:
    nonRaced = raced[raced['Elapsed time'].isin([code])]
    print '\n', code
    print 'Unique count of boats:', nonRaced['Boat name'].drop_duplicates().count()
    uniqueNonRacedCounts = pd.DataFrame(nonRaced.groupby(['Handicap','Boat name']).count()['Elapsed time'])  
    uniqueNonRacedCounts.columns = ['Count']
    #print uniqueNonRacedCounts.reset_index().to_string(index=False),'\n'
    print uniqueNonRacedCounts
# Out:
# All handicaps
# All divisions
#
# Unique count of boats: 67
#
# Unique boat count by: Handicap
# Championship    41
# Classics         5
# Fleet           38
# Offshore        23
# PNR             28
# Rum             28
# Two-handed      12
# Name: Boat name, dtype: int64
#
# Count of boats not scored by code:
#
# <dnf>
# Unique count of boats: 23
#                                   Count
# Handicap     Boat name
# Championship Airship                  1
#              Eat My Shorts            1
#              Haumuri                  1
#              Illusions                1
#              Magic Trick              1
#              Ran Tan II               2
#              Rocket Science           2
#              Structural Analysis      4
#              Testarossa               1
#              The Guarantee            1
#              Wedgetail                1
#              White Cavalier           2
# Classics     Loloma                   1
# Fleet        After Midnight           1
#              Bacchante                1
# Offshore     Am Meer                  1
#              Gucci                    1
#              Illusions                1
#              Revs                     1
#              Wai-Aniwa                1
# PNR          Badonkadonk              1
#              Haumuri                  1
#              Rocket Science           1
# Rum          Charlie                  1
#              Illusions                1
#              Marishka                 1
#              Rosschild                1
#              White Cavalier           2
#
# <dns>
# Unique count of boats: 9
#                              Count
# Handicap     Boat name
# Championship Maranui             1
#              Wiseguy             1
# PNR          White Cavalier      1
# Rum          Alice Bee           1
# Two-handed   Gucci               1
#              Rosschild           1
#              Saucy Sausage       1
#              Testarossa          1
#              Titus Canby         1
#              White Cavalier      1
#
# <no entry>
# Unique count of boats: 4
#                               Count
# Handicap     Boat name
# Championship Marangi              1
# Fleet        Montego Bay III      1
#              Port Nic 1           1
#              Port Nic 2           2
# Rum          Montego Bay III      2
#
# <raf>
# Unique count of boats: 1
#                          Count
# Handicap Boat name
# Fleet    Rocket Science      1
# <ocs>
# Unique count of boats: 1
#                         Count
# Handicap Boat name
# Fleet    Black Diamond      1
#
# <dnc>
# Unique count of boats: 11
#                                 Count
# Handicap Boat name
# PNR      Airship                    1
#          Badonkadonk                5
#          Brix                       2
#          C U                        1
#          Drinks Trolley             5
#          Illusions                  4
#          Magic Trick                2
#          Rocket Science             2
#          The Guarantee              5
#          Wellington Spirit Red      1
#          Wiseguy                    1
#
# <dsq>
# Unique count of boats: 3
#                                    Count
# Handicap Boat name
# PNR      Prime Mover                   1
# Rum      Eat My Shorts                 1
#          Wellington Spirit Bronze      1

# %%
# Histograms

# Define function to generate bins - returns a list
def generateBins(start=None,interval=None,bins=None):
    binList = []; binList.append(start)
    for i in arange(1,bins+1):
        binList.append(start + i*interval)
    return binList   

# Histogram for the whole season (ie TCFdata)
#eap.plotHist(TCFdata, columnToPlot='Boat name', numBins=generateBins(start=0,interval=2,bins=10), figstyle=2)
eap.plotHist(TCFdata, columnToPlot='Boat name', numBins=10, figstyle=2)

ax = plt.gca()
ymajorLocator = tkr.MultipleLocator(base=1)
ax.yaxis.set_major_locator(ymajorLocator)

# Get list of handicaps existing in the dataframe
handicaps = TCFdata['Handicap'] ;
handicaps = list(handicaps.drop_duplicates())
print handicaps
# Out:
# ['Championship', 'Classics', 'Fleet', 'Offshore', 'PNR', 'Rum', 'Two-handed']

# %%
# Histograms for Championship, Fleet, Offshore, PNR, Rum and Two-Handed

# Create new dataframe indexed by handicap
TCFdataByHandicap = TCFdata.set_index('Handicap')

#Set up a figure with 6 subplots:    
#for i in range(6):
#    plt.subplot(2,3,i+1) 
#fig, axes = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True)

# Create dataframes for each handicap and plot the histogram
if 'Championship' in handicaps:
    TCFdataChampionship = TCFdataByHandicap.loc['Championship']
    eap.plotHist(TCFdataChampionship, 
                 columnToPlot='Boat name', 
                 numBins=generateBins(start=0,interval=4,bins=5), 
                 figstyle=2)
if 'Fleet' in handicaps:
    TCFdataFleet = TCFdataByHandicap.loc['Fleet']
    eap.plotHist(TCFdataFleet, 
                 columnToPlot='Boat name', 
                 numBins=generateBins(start=0,interval=4,bins=5), 
                 figstyle=2)
if 'Offshore' in handicaps:
    TCFdataOffshore = TCFdataByHandicap.loc['Offshore']
    eap.plotHist(TCFdataOffshore, 
                 columnToPlot='Boat name', 
                 numBins=generateBins(start=0,interval=4,bins=5), 
                 figstyle=2)
if 'PNR' in handicaps:
    TCFdataPNR = TCFdataByHandicap.loc['PNR']
    eap.plotHist(TCFdataPNR, 
                 columnToPlot='Boat name', 
                 numBins=generateBins(start=0,interval=4,bins=5), 
                 figstyle=2)
if 'Rum' in handicaps:
    TCFdataRum = TCFdataByHandicap.loc['Rum']
    eap.plotHist(TCFdataRum, 
                 columnToPlot='Boat name', 
                 numBins=generateBins(start=0,interval=4,bins=5), 
                 figstyle=2)
if 'Two-handed' in handicaps:
    TCFdataTwoHanded = TCFdataByHandicap.loc['Two-handed']
    eap.plotHist(TCFdataTwoHanded, 
                 columnToPlot='Boat name', 
                 numBins=generateBins(start=0,interval=4,bins=5), 
                 figstyle=2)
